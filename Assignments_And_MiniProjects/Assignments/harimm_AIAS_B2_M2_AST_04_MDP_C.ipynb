# %% [markdown]
# # Machine Learning and AI for Autonomous Systems
# ## A program by IISc and TalentSprint
# ### Assignment : Markov Decision Process

# %% [markdown]
# ## Learning Objectives

# %% [markdown]
# At the end of the experiment, you will be able to
#
# * understand Markov Property and Markov Chain.
# * understand and solve Markov Reward Process.
# * understand theMarkov Decision Process.
# * Apply MDP in grid search enviroment.

# %% [markdown]
# ### Setup Steps:

# %%
#@title Please enter your registration id to start: { run: "auto", display-mode: "form" }
Id = "2302794" #@param {type:"string"}

# %%
#@title Please enter your password (your registered phone number) to continue: { run: "auto", display-mode: "form" }
password = "9008710123" #@param {type:"string"}

# %%
#@title Run this cell to complete the setup for this Notebook
from IPython import get_ipython

ipython = get_ipython()

notebook= "AIAS_B2_M2_AST_04_MDP_C" #name of the notebook

def setup():
#  ipython.magic("sx pip3 install torch")
    from IPython.display import HTML, display
    display(HTML('<script src="https://dashboard.talentsprint.com/aiml/record_ip.html?traineeId={0}&recordId={1}"></script>'.format(getId(),submission_id)))
    print("Setup completed successfully")
    return

def submit_notebook():
    ipython.magic("notebook -e "+ notebook + ".ipynb")

    import requests, json, base64, datetime

    url = "https://dashboard.talentsprint.com/xp/app/save_notebook_attempts"
    if not submission_id:
      data = {"id" : getId(), "notebook" : notebook, "mobile" : getPassword()}
      r = requests.post(url, data = data)
      r = json.loads(r.text)

      if r["status"] == "Success":
          return r["record_id"]
      elif "err" in r:
        print(r["err"])
        return None
      else:
        print ("Something is wrong, the notebook will not be submitted for grading")
        return None

    elif getAnswer() and getComplexity() and getAdditional() and getConcepts() and getComments() and getMentorSupport():
      f = open(notebook + ".ipynb", "rb")
      file_hash = base64.b64encode(f.read())

      data = {"complexity" : Complexity, "additional" :Additional,
              "concepts" : Concepts, "record_id" : submission_id,
              "answer" : Answer, "id" : Id, "file_hash" : file_hash,
              "notebook" : notebook,
              "feedback_experiments_input" : Comments,
              "feedback_mentor_support": Mentor_support}
      r = requests.post(url, data = data)
      r = json.loads(r.text)
      if "err" in r:
        print(r["err"])
        return None
      else:
        print("Your submission is successful.")
        print("Ref Id:", submission_id)
        print("Date of submission: ", r["date"])
        print("Time of submission: ", r["time"])
        print("View your submissions: https://aias-iisc.talentsprint.com/notebook_submissions")
        #print("For any queries/discrepancies, please connect with mentors through the chat icon in LMS dashboard.")
        return submission_id
    else: submission_id


def getAdditional():
  try:
    if not Additional:
      raise NameError
    else:
      return Additional
  except NameError:
    print ("Please answer Additional Question")
    return None

def getComplexity():
  try:
    if not Complexity:
      raise NameError
    else:
      return Complexity
  except NameError:
    print ("Please answer Complexity Question")
    return None

def getConcepts():
  try:
    if not Concepts:
      raise NameError
    else:
      return Concepts
  except NameError:
    print ("Please answer Concepts Question")
    return None


# def getWalkthrough():
#   try:
#     if not Walkthrough:
#       raise NameError
#     else:
#       return Walkthrough
#   except NameError:
#     print ("Please answer Walkthrough Question")
#     return None

def getComments():
  try:
    if not Comments:
      raise NameError
    else:
      return Comments
  except NameError:
    print ("Please answer Comments Question")
    return None


def getMentorSupport():
  try:
    if not Mentor_support:
      raise NameError
    else:
      return Mentor_support
  except NameError:
    print ("Please answer Mentor support Question")
    return None

def getAnswer():
  try:
    if not Answer:
      raise NameError
    else:
      return Answer
  except NameError:
    print ("Please answer Question")
    return None


def getId():
  try:
    return Id if Id else None
  except NameError:
    return None

def getPassword():
  try:
    return password if password else None
  except NameError:
    return None

submission_id = None
### Setup
if getPassword() and getId():
  submission_id = submit_notebook()
  if submission_id:
    setup()
else:
  print ("Please complete Id and Password cells before running setup")
# Out:
# <script src="https://dashboard.talentsprint.com/aiml/record_ip.html?traineeId=2302794&recordId=803"></script>
# Setup completed successfully

# %% [markdown]
# ## Markov Decision Processes

# %% [markdown]
# The Markov Decision Process (MDP) is a mathematical framework for solving reinforcement learning (RL) problems. Almost all RL problems can be modeled as an MDP. MDPs are also widely used for solving other optimization problems.
#
# In this section, we will define what an MDP is and how it is used in RL. To understand an MDP, we first need to understand the Markov property and Markov chains.
#
# The Markov property states that the future state of a system depends only on its current state, not on its past history. This property is what makes MDPs so powerful for modeling RL problems.
#
# A Markov chain is a stochastic process that satisfies the Markov property. In other words, a Markov chain is a sequence of states where the probability of transitioning to a particular state only depends on the current state, not on any previous states.
#
# An MDP is a Markov chain with the addition of actions. In an MDP, the agent can take actions to influence the state transitions. The goal of the agent is to find a policy that maximizes the expected reward over time.
#
# Moving from one state to another is called a transition, and its probability is called a transition probability. We denote the transition probability by $P(s'|s)$
# . It indicates the probability of moving from the state $s$
#  to the next state $s'$
# .

# %% [markdown]
# ### Markov Reward Process

# %% [markdown]
# The Markov Reward Process (MRP) is an extension of the Markov chain with the reward function. That is, we learned that the Markov chain consists of states and a transition probability. The MRP consists of states, a transition probability, and also a reward function.
#
# A reward function tells us the reward we obtain in each state. For instance, based on our previous weather example, the reward function tells us the reward we obtain in the state cloudy, the reward we obtain in the state windy, and so on. The reward function is usually denoted by $R(s)$.
#
# Thus, the MRP consists of states $s$, a transition probability $P(s'|s)$  function $R(s)$.

# %% [markdown]
# ### MDP(markov Decision Process)
#
# Markov decision process (MDP) is a mathematical tool used for decision-making problems where the outcomes are partially random and partially controllable.
#
# **Agent:** A reinforcement learning agent is the entity which we are training to make correct decisions. For example, a robot that is being trained to move around a house without crashing.
#
# **Environment:** The environment is the surroundings with which the agent interacts. For example, the house where the robot moves. The agent cannot manipulate the environment; it can only control its own actions. In other words, the robot can’t control where a table is in the house, but it can walk around it. In this notebook we are considering the **GRID WORLD**
#
# **State:** The state defines the current situation of the agent This can be the exact position of the robot in the house, the alignment of its two legs or its current posture. It all depends on how you address the problem.
#
# **Action:** The choice that the agent makes at the current time step. For example, the robot can move its right or left leg, raise its arm, lift an object or turn right/left, etc. We know the set of actions (decisions) that the agent can perform in advance.
#
# **Policy:** A policy is the thought process behind picking an action. In practice, it’s a probability distribution assigned to the set of actions. Highly rewarding actions will have a high probability and vice versa. If an action has a low probability, it doesn’t mean it won’t be picked at all. It’s just less likely to be picked.

# %% [markdown]
# ### Importing Libraries and Packages

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from time import time

# %% [markdown]
# ### GRID WORLD

# %%
class GridWorld:
    def __init__(self, filename, reward, random_rate, time_limit=1000):
        file = open(filename)
        self.map = np.array(
            [list(map(float, s.strip().split(","))) for s in file.readlines()]
        )
        file.close()
        self.num_rows = self.map.shape[0]
        self.num_cols = self.map.shape[1]
        self.num_states = self.num_rows * self.num_cols
        self.num_actions = 4
        self.reward = reward
        self.random_rate = random_rate
        self.time_limit = time_limit
        self.reward_function = self.get_reward_function()
        self.transition_model = self.get_transition_model()

    def get_state_from_pos(self, pos):
        return pos[0] * self.num_cols + pos[1]

    def get_pos_from_state(self, state):
        return state // self.num_cols, state % self.num_cols

    def get_reward_function(self):
        reward_table = np.zeros(self.num_states)
        for r in range(self.num_rows):
            for c in range(self.num_cols):
                s = self.get_state_from_pos((r, c))
                reward_table[s] = self.reward[self.map[r, c]]
        return reward_table

    def get_transition_model(self):
        transition_model = np.zeros((self.num_states, self.num_actions, self.num_states))
        for r in range(self.num_rows):
            for c in range(self.num_cols):
                s = self.get_state_from_pos((r, c))
                neighbor_s = np.zeros(self.num_actions)
                if self.map[r, c] == 0:
                    for a in range(self.num_actions):
                        new_r, new_c = r, c
                        if a == 0:
                            new_r = max(r - 1, 0)
                        elif a == 1:
                            new_c = min(c + 1, self.num_cols - 1)
                        elif a == 2:
                            new_r = min(r + 1, self.num_rows - 1)
                        elif a == 3:
                            new_c = max(c - 1, 0)
                        if self.map[new_r, new_c] == 3:
                            new_r, new_c = r, c
                        s_prime = self.get_state_from_pos((new_r, new_c))
                        neighbor_s[a] = s_prime
                else:
                    neighbor_s = np.ones(self.num_actions) * s
                for a in range(self.num_actions):
                    transition_model[s, a, int(neighbor_s[a])] += 1 - self.random_rate
                    transition_model[s, a, int(neighbor_s[(a + 1) % self.num_actions])] += self.random_rate / 2.0
                    transition_model[s, a, int(neighbor_s[(a - 1) % self.num_actions])] += self.random_rate / 2.0
        return transition_model

    def generate_random_policy(self):
        return np.random.randint(self.num_actions, size=self.num_states)

    def execute_policy(self, policy, start_pos):
        s = self.get_state_from_pos(start_pos)
        r = self.reward_function[s]
        total_reward = r

        start_time = int(round(time() * 1000))
        overtime = False

        while r != self.reward[1] and r != self.reward[2]:
            s = np.random.choice(self.num_states, p=self.transition_model[s, policy[s]])
            r = self.reward_function[s]
            total_reward += r
            cur_time = int(round(time() * 1000)) - start_time
            if cur_time > self.time_limit:
                overtime = True
                break
        if overtime is True:
            return float('-inf')
        else:
            return total_reward

    def random_start_policy(self, policy, start_pos, n=100, plot=True):
        start_time = int(round(time() * 1000))
        overtime = False
        scores = np.zeros(n)
        i = 0
        while i < n:
            temp = self.execute_policy(policy=policy, start_pos=start_pos)
            print(f'i = {i} Random start result: {temp}')
            if temp > float('-inf'):
                scores[i] = temp
                i += 1
            cur_time = int(round(time() * 1000)) - start_time
            if cur_time > n * self.time_limit:
                overtime = True
                break

        print(f'max = {np.max(scores)}')
        print(f'min = {np.min(scores)}')
        print(f'mean = {np.mean(scores)}')
        print(f'std = {np.std(scores)}')

        if overtime is False and plot is True:
            bins = 100
            fig, ax = plt.subplots(1, 1, figsize=(6, 4), dpi=300)
            ax.set_xlabel('Total rewards in a single game')
            ax.set_ylabel('Frequency')
            ax.hist(scores, bins=bins, color='#1f77b4', edgecolor='black')
            plt.show()

        if overtime is True:
            print('Overtime!')
            return None
        else:
            return np.max(scores), np.min(scores), np.mean(scores)

    def blackbox_move(self, s, a):
        temp = self.transition_model[s, a]
        s_prime = np.random.choice(self.num_states, p=temp)
        r = self.reward_function[s_prime]
        return s_prime, r

    def plot_map(self, fig_size=(8, 6)):
        unit = min(fig_size[1] // self.num_rows, fig_size[0] // self.num_cols)
        unit = max(1, unit)
        fig, ax = plt.subplots(1, 1, figsize=fig_size)
        ax.axis('off')
        for i in range(self.num_cols + 1):
            if i == 0 or i == self.num_cols:
                ax.plot([i * unit, i * unit], [0, self.num_rows * unit],
                        color='black')
            else:
                ax.plot([i * unit, i * unit], [0, self.num_rows * unit],
                        alpha=0.7, color='grey', linestyle='dashed')
        for i in range(self.num_rows + 1):
            if i == 0 or i == self.num_rows:
                ax.plot([0, self.num_cols * unit], [i * unit, i * unit],
                        color='black')
            else:
                ax.plot([0, self.num_cols * unit], [i * unit, i * unit],
                        alpha=0.7, color='grey', linestyle='dashed')

        for i in range(self.num_rows):
            for j in range(self.num_cols):
                y = (self.num_rows - 1 - i) * unit
                x = j * unit
                if self.map[i, j] == 3:
                    rect = patches.Rectangle((x, y), unit, unit, edgecolor='none', facecolor='black',
                                             alpha=0.6)
                    ax.add_patch(rect)
                elif self.map[i, j] == 2:
                    rect = patches.Rectangle((x, y), unit, unit, edgecolor='none', facecolor='red',
                                             alpha=0.6)
                    ax.add_patch(rect)
                elif self.map[i, j] == 1:
                    rect = patches.Rectangle((x, y), unit, unit, edgecolor='none', facecolor='green',
                                             alpha=0.6)
                    ax.add_patch(rect)

        plt.tight_layout()
        plt.show()

    def plot_policy(self, policy, fig_size=(8, 6)):
        unit = min(fig_size[1] // self.num_rows, fig_size[0] // self.num_cols)
        unit = max(1, unit)
        fig, ax = plt.subplots(1, 1, figsize=fig_size)
        ax.axis('off')
        for i in range(self.num_cols + 1):
            if i == 0 or i == self.num_cols:
                ax.plot([i * unit, i * unit], [0, self.num_rows * unit],
                        color='black')
            else:
                ax.plot([i * unit, i * unit], [0, self.num_rows * unit],
                        alpha=0.7, color='grey', linestyle='dashed')
        for i in range(self.num_rows + 1):
            if i == 0 or i == self.num_rows:
                ax.plot([0, self.num_cols * unit], [i * unit, i * unit],
                        color='black')
            else:
                ax.plot([0, self.num_cols * unit], [i * unit, i * unit],
                        alpha=0.7, color='grey', linestyle='dashed')

        for i in range(self.num_rows):
            for j in range(self.num_cols):
                y = (self.num_rows - 1 - i) * unit
                x = j * unit
                if self.map[i, j] == 3:
                    rect = patches.Rectangle((x, y), unit, unit, edgecolor='none', facecolor='black',
                                             alpha=0.6)
                    ax.add_patch(rect)
                elif self.map[i, j] == 2:
                    rect = patches.Rectangle((x, y), unit, unit, edgecolor='none', facecolor='red',
                                             alpha=0.6)
                    ax.add_patch(rect)
                elif self.map[i, j] == 1:
                    rect = patches.Rectangle((x, y), unit, unit, edgecolor='none', facecolor='green',
                                             alpha=0.6)
                    ax.add_patch(rect)
                s = self.get_state_from_pos((i, j))
                if self.map[i, j] == 0:
                    a = policy[s]
                    symbol = ['^', '>', 'v', '<']
                    ax.plot([x + 0.5 * unit], [y + 0.5 * unit], marker=symbol[a],
                            linestyle='none', markersize=max(fig_size)*unit, color='#1f77b4')

        plt.tight_layout()
        plt.show()

    def visualize_value_policy(self, policy, values, fig_size=(8, 6)):
        unit = min(fig_size[1] // self.num_rows, fig_size[0] // self.num_cols)
        unit = max(1, unit)
        fig, ax = plt.subplots(1, 1, figsize=fig_size)
        ax.axis('off')

        for i in range(self.num_cols + 1):
            if i == 0 or i == self.num_cols:
                ax.plot([i * unit, i * unit], [0, self.num_rows * unit],
                        color='black')
            else:
                ax.plot([i * unit, i * unit], [0, self.num_rows * unit],
                        alpha=0.7, color='grey', linestyle='dashed')
        for i in range(self.num_rows + 1):
            if i == 0 or i == self.num_rows:
                ax.plot([0, self.num_cols * unit], [i * unit, i * unit],
                        color='black')
            else:
                ax.plot([0, self.num_cols * unit], [i * unit, i * unit],
                        alpha=0.7, color='grey', linestyle='dashed')

        for i in range(self.num_rows):
            for j in range(self.num_cols):
                y = (self.num_rows - 1 - i) * unit
                x = j * unit
                s = self.get_state_from_pos((i, j))
                if self.map[i, j] == 3:
                    rect = patches.Rectangle((x, y), unit, unit, edgecolor='none', facecolor='black',
                                             alpha=0.6)
                    ax.add_patch(rect)
                elif self.map[i, j] == 2:
                    rect = patches.Rectangle((x, y), unit, unit, edgecolor='none', facecolor='red',
                                             alpha=0.6)
                    ax.add_patch(rect)
                elif self.map[i, j] == 1:
                    rect = patches.Rectangle((x, y), unit, unit, edgecolor='none', facecolor='green',
                                             alpha=0.6)
                    ax.add_patch(rect)
                if self.map[i, j] != 3:
                    ax.text(x + 0.5 * unit, y + 0.5 * unit, f'{values[s]:.4f}',
                            horizontalalignment='center', verticalalignment='center',
                            fontsize=max(fig_size)*unit*0.6)
                if policy is not None:
                    if self.map[i, j] == 0:
                        a = policy[s]
                        symbol = ['^', '>', 'v', '<']
                        ax.plot([x + 0.5 * unit], [y + 0.5 * unit], marker=symbol[a], alpha=0.4,
                                linestyle='none', markersize=max(fig_size)*unit, color='#1f77b4')

        plt.tight_layout()
        plt.show()

# %% [markdown]
# #### Loading Data and creating Gridworld

# %%
# !gdown "1dbTpjYl6eF28JiWYKmlHkpa_Ey0Jgiwk"
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1dbTpjYl6eF28JiWYKmlHkpa_Ey0Jgiwk
# To: /content/world00.csv
# 100% 24.0/24.0 [00:00<00:00, 87.3kB/s]

# %% [markdown]
# #### Plot the Gridworld

# %%
mdp = GridWorld('/content/world00.csv', reward={0: -0.04, 1: 1.0, 2: -1.0, 3: np.NaN}, random_rate=0.3)

mdp.plot_map(fig_size=(10, 8))

# %% [markdown]
# #### Generate random policy

# %%
init_policy = mdp.generate_random_policy()
mdp.plot_policy(init_policy, fig_size=(20, 10))
mdp.visualize_value_policy(init_policy, np.zeros(mdp.num_states), fig_size=(10, 8))
# Out:
# <ipython-input-5-ece47fdee11e>:261: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()

# %% [markdown]
# #### Print the reward function

# %%
reward_function = mdp.reward_function
print(f'reward function =')
for s in range(len(reward_function)):
    print(f'State s = {s}, Reward R({s}) = {reward_function[s]}')
# Out:
# reward function =
# State s = 0, Reward R(0) = -0.04
# State s = 1, Reward R(1) = -0.04
# State s = 2, Reward R(2) = -0.04
# State s = 3, Reward R(3) = 1.0
# State s = 4, Reward R(4) = -0.04
# State s = 5, Reward R(5) = nan
# State s = 6, Reward R(6) = -0.04
# State s = 7, Reward R(7) = -1.0
# State s = 8, Reward R(8) = -0.04
# State s = 9, Reward R(9) = -0.04
# State s = 10, Reward R(10) = -0.04
# State s = 11, Reward R(11) = -0.04

# %% [markdown]
# #### Define transition model

# %%
transition_model = mdp.transition_model
print(f'transition model =')
for s in range(transition_model.shape[0]):
    print('======================================')
    for a in range(transition_model.shape[1]):
        print('--------------------------------------')
        for s_prime in range(transition_model.shape[2]):
            print(f's = {s}, a = {a}, s\' = {s_prime}, p = {transition_model[s, a, s_prime]}')
# Out:
# transition model =
# ======================================
# --------------------------------------
# s = 0, a = 0, s' = 0, p = 0.85
# s = 0, a = 0, s' = 1, p = 0.15
# s = 0, a = 0, s' = 2, p = 0.0
# s = 0, a = 0, s' = 3, p = 0.0
# s = 0, a = 0, s' = 4, p = 0.0
# s = 0, a = 0, s' = 5, p = 0.0
# s = 0, a = 0, s' = 6, p = 0.0
# s = 0, a = 0, s' = 7, p = 0.0
# s = 0, a = 0, s' = 8, p = 0.0
# s = 0, a = 0, s' = 9, p = 0.0
# s = 0, a = 0, s' = 10, p = 0.0
# s = 0, a = 0, s' = 11, p = 0.0
# --------------------------------------
# s = 0, a = 1, s' = 0, p = 0.15
# s = 0, a = 1, s' = 1, p = 0.7
# s = 0, a = 1, s' = 2, p = 0.0
# s = 0, a = 1, s' = 3, p = 0.0
# s = 0, a = 1, s' = 4, p = 0.15
# s = 0, a = 1, s' = 5, p = 0.0
# s = 0, a = 1, s' = 6, p = 0.0
# s = 0, a = 1, s' = 7, p = 0.0
# s = 0, a = 1, s' = 8, p = 0.0
# s = 0, a = 1, s' = 9, p = 0.0
# s = 0, a = 1, s' = 10, p = 0.0
# s = 0, a = 1, s' = 11, p = 0.0
# --------------------------------------
# s = 0, a = 2, s' = 0, p = 0.15
# s = 0, a = 2, s' = 1, p = 0.15
# s = 0, a = 2, s' = 2, p = 0.0
# s = 0, a = 2, s' = 3, p = 0.0
# s = 0, a = 2, s' = 4, p = 0.7
# s = 0, a = 2, s' = 5, p = 0.0
# s = 0, a = 2, s' = 6, p = 0.0
# s = 0, a = 2, s' = 7, p = 0.0
# s = 0, a = 2, s' = 8, p = 0.0
# s = 0, a = 2, s' = 9, p = 0.0
# s = 0, a = 2, s' = 10, p = 0.0
# s = 0, a = 2, s' = 11, p = 0.0
# --------------------------------------
# s = 0, a = 3, s' = 0, p = 0.85
# s = 0, a = 3, s' = 1, p = 0.0
# s = 0, a = 3, s' = 2, p = 0.0
# s = 0, a = 3, s' = 3, p = 0.0
# s = 0, a = 3, s' = 4, p = 0.15
# s = 0, a = 3, s' = 5, p = 0.0
# s = 0, a = 3, s' = 6, p = 0.0
# s = 0, a = 3, s' = 7, p = 0.0
# s = 0, a = 3, s' = 8, p = 0.0
# s = 0, a = 3, s' = 9, p = 0.0
# s = 0, a = 3, s' = 10, p = 0.0
# s = 0, a = 3, s' = 11, p = 0.0
# ======================================
# --------------------------------------
# s = 1, a = 0, s' = 0, p = 0.15
# s = 1, a = 0, s' = 1, p = 0.7
# s = 1, a = 0, s' = 2, p = 0.15
# s = 1, a = 0, s' = 3, p = 0.0
# s = 1, a = 0, s' = 4, p = 0.0
# s = 1, a = 0, s' = 5, p = 0.0
# s = 1, a = 0, s' = 6, p = 0.0
# s = 1, a = 0, s' = 7, p = 0.0
# s = 1, a = 0, s' = 8, p = 0.0
# s = 1, a = 0, s' = 9, p = 0.0
# s = 1, a = 0, s' = 10, p = 0.0
# s = 1, a = 0, s' = 11, p = 0.0
# --------------------------------------
# s = 1, a = 1, s' = 0, p = 0.0
# s = 1, a = 1, s' = 1, p = 0.3
# s = 1, a = 1, s' = 2, p = 0.7
# s = 1, a = 1, s' = 3, p = 0.0
# s = 1, a = 1, s' = 4, p = 0.0
# s = 1, a = 1, s' = 5, p = 0.0
# s = 1, a = 1, s' = 6, p = 0.0
# s = 1, a = 1, s' = 7, p = 0.0
# s = 1, a = 1, s' = 8, p = 0.0
# s = 1, a = 1, s' = 9, p = 0.0
# s = 1, a = 1, s' = 10, p = 0.0
# s = 1, a = 1, s' = 11, p = 0.0
# --------------------------------------
# s = 1, a = 2, s' = 0, p = 0.15
# s = 1, a = 2, s' = 1, p = 0.7
# s = 1, a = 2, s' = 2, p = 0.15
# s = 1, a = 2, s' = 3, p = 0.0
# s = 1, a = 2, s' = 4, p = 0.0
# s = 1, a = 2, s' = 5, p = 0.0
# s = 1, a = 2, s' = 6, p = 0.0
# s = 1, a = 2, s' = 7, p = 0.0
# s = 1, a = 2, s' = 8, p = 0.0
# s = 1, a = 2, s' = 9, p = 0.0
# s = 1, a = 2, s' = 10, p = 0.0
# s = 1, a = 2, s' = 11, p = 0.0
# --------------------------------------
# s = 1, a = 3, s' = 0, p = 0.7
# s = 1, a = 3, s' = 1, p = 0.3
# s = 1, a = 3, s' = 2, p = 0.0
# s = 1, a = 3, s' = 3, p = 0.0
# s = 1, a = 3, s' = 4, p = 0.0
# s = 1, a = 3, s' = 5, p = 0.0
# s = 1, a = 3, s' = 6, p = 0.0
# s = 1, a = 3, s' = 7, p = 0.0
# s = 1, a = 3, s' = 8, p = 0.0
# s = 1, a = 3, s' = 9, p = 0.0
# s = 1, a = 3, s' = 10, p = 0.0
# s = 1, a = 3, s' = 11, p = 0.0
# ======================================
# --------------------------------------
# s = 2, a = 0, s' = 0, p = 0.0
# s = 2, a = 0, s' = 1, p = 0.15
# s = 2, a = 0, s' = 2, p = 0.7
# s = 2, a = 0, s' = 3, p = 0.15
# s = 2, a = 0, s' = 4, p = 0.0
# s = 2, a = 0, s' = 5, p = 0.0
# s = 2, a = 0, s' = 6, p = 0.0
# s = 2, a = 0, s' = 7, p = 0.0
# s = 2, a = 0, s' = 8, p = 0.0
# s = 2, a = 0, s' = 9, p = 0.0
# s = 2, a = 0, s' = 10, p = 0.0
# s = 2, a = 0, s' = 11, p = 0.0
# --------------------------------------
# s = 2, a = 1, s' = 0, p = 0.0
# s = 2, a = 1, s' = 1, p = 0.0
# s = 2, a = 1, s' = 2, p = 0.15
# s = 2, a = 1, s' = 3, p = 0.7
# s = 2, a = 1, s' = 4, p = 0.0
# s = 2, a = 1, s' = 5, p = 0.0
# s = 2, a = 1, s' = 6, p = 0.15
# s = 2, a = 1, s' = 7, p = 0.0
# s = 2, a = 1, s' = 8, p = 0.0
# s = 2, a = 1, s' = 9, p = 0.0
# s = 2, a = 1, s' = 10, p = 0.0
# s = 2, a = 1, s' = 11, p = 0.0
# --------------------------------------
# s = 2, a = 2, s' = 0, p = 0.0
# s = 2, a = 2, s' = 1, p = 0.15
# s = 2, a = 2, s' = 2, p = 0.0
# s = 2, a = 2, s' = 3, p = 0.15
# s = 2, a = 2, s' = 4, p = 0.0
# s = 2, a = 2, s' = 5, p = 0.0
# s = 2, a = 2, s' = 6, p = 0.7
# s = 2, a = 2, s' = 7, p = 0.0
# s = 2, a = 2, s' = 8, p = 0.0
# s = 2, a = 2, s' = 9, p = 0.0
# s = 2, a = 2, s' = 10, p = 0.0
# s = 2, a = 2, s' = 11, p = 0.0
# --------------------------------------
# s = 2, a = 3, s' = 0, p = 0.0
# s = 2, a = 3, s' = 1, p = 0.7
# s = 2, a = 3, s' = 2, p = 0.15
# s = 2, a = 3, s' = 3, p = 0.0
# s = 2, a = 3, s' = 4, p = 0.0
# s = 2, a = 3, s' = 5, p = 0.0
# s = 2, a = 3, s' = 6, p = 0.15
# s = 2, a = 3, s' = 7, p = 0.0
# s = 2, a = 3, s' = 8, p = 0.0
# s = 2, a = 3, s' = 9, p = 0.0
# s = 2, a = 3, s' = 10, p = 0.0
# s = 2, a = 3, s' = 11, p = 0.0
# ======================================
# --------------------------------------
# s = 3, a = 0, s' = 0, p = 0.0
# s = 3, a = 0, s' = 1, p = 0.0
# s = 3, a = 0, s' = 2, p = 0.0
# s = 3, a = 0, s' = 3, p = 1.0
# s = 3, a = 0, s' = 4, p = 0.0
# s = 3, a = 0, s' = 5, p = 0.0
# s = 3, a = 0, s' = 6, p = 0.0
# s = 3, a = 0, s' = 7, p = 0.0
# s = 3, a = 0, s' = 8, p = 0.0
# s = 3, a = 0, s' = 9, p = 0.0
# s = 3, a = 0, s' = 10, p = 0.0
# s = 3, a = 0, s' = 11, p = 0.0
# --------------------------------------
# s = 3, a = 1, s' = 0, p = 0.0
# s = 3, a = 1, s' = 1, p = 0.0
# s = 3, a = 1, s' = 2, p = 0.0
# s = 3, a = 1, s' = 3, p = 1.0
# s = 3, a = 1, s' = 4, p = 0.0
# s = 3, a = 1, s' = 5, p = 0.0
# s = 3, a = 1, s' = 6, p = 0.0
# s = 3, a = 1, s' = 7, p = 0.0
# s = 3, a = 1, s' = 8, p = 0.0
# s = 3, a = 1, s' = 9, p = 0.0
# s = 3, a = 1, s' = 10, p = 0.0
# s = 3, a = 1, s' = 11, p = 0.0
# --------------------------------------
# s = 3, a = 2, s' = 0, p = 0.0
# s = 3, a = 2, s' = 1, p = 0.0
# s = 3, a = 2, s' = 2, p = 0.0
# s = 3, a = 2, s' = 3, p = 1.0
# s = 3, a = 2, s' = 4, p = 0.0
# s = 3, a = 2, s' = 5, p = 0.0
# s = 3, a = 2, s' = 6, p = 0.0
# s = 3, a = 2, s' = 7, p = 0.0
# s = 3, a = 2, s' = 8, p = 0.0
# s = 3, a = 2, s' = 9, p = 0.0
# s = 3, a = 2, s' = 10, p = 0.0
# s = 3, a = 2, s' = 11, p = 0.0
# --------------------------------------
# s = 3, a = 3, s' = 0, p = 0.0
# s = 3, a = 3, s' = 1, p = 0.0
# s = 3, a = 3, s' = 2, p = 0.0
# s = 3, a = 3, s' = 3, p = 1.0
# s = 3, a = 3, s' = 4, p = 0.0
# s = 3, a = 3, s' = 5, p = 0.0
# s = 3, a = 3, s' = 6, p = 0.0
# s = 3, a = 3, s' = 7, p = 0.0
# s = 3, a = 3, s' = 8, p = 0.0
# s = 3, a = 3, s' = 9, p = 0.0
# s = 3, a = 3, s' = 10, p = 0.0
# s = 3, a = 3, s' = 11, p = 0.0
# ======================================
# --------------------------------------
# s = 4, a = 0, s' = 0, p = 0.7
# s = 4, a = 0, s' = 1, p = 0.0
# s = 4, a = 0, s' = 2, p = 0.0
# s = 4, a = 0, s' = 3, p = 0.0
# s = 4, a = 0, s' = 4, p = 0.3
# s = 4, a = 0, s' = 5, p = 0.0
# s = 4, a = 0, s' = 6, p = 0.0
# s = 4, a = 0, s' = 7, p = 0.0
# s = 4, a = 0, s' = 8, p = 0.0
# s = 4, a = 0, s' = 9, p = 0.0
# s = 4, a = 0, s' = 10, p = 0.0
# s = 4, a = 0, s' = 11, p = 0.0
# --------------------------------------
# s = 4, a = 1, s' = 0, p = 0.15
# s = 4, a = 1, s' = 1, p = 0.0
# s = 4, a = 1, s' = 2, p = 0.0
# s = 4, a = 1, s' = 3, p = 0.0
# s = 4, a = 1, s' = 4, p = 0.7
# s = 4, a = 1, s' = 5, p = 0.0
# s = 4, a = 1, s' = 6, p = 0.0
# s = 4, a = 1, s' = 7, p = 0.0
# s = 4, a = 1, s' = 8, p = 0.15
# s = 4, a = 1, s' = 9, p = 0.0
# s = 4, a = 1, s' = 10, p = 0.0
# s = 4, a = 1, s' = 11, p = 0.0
# --------------------------------------
# s = 4, a = 2, s' = 0, p = 0.0
# s = 4, a = 2, s' = 1, p = 0.0
# s = 4, a = 2, s' = 2, p = 0.0
# s = 4, a = 2, s' = 3, p = 0.0
# s = 4, a = 2, s' = 4, p = 0.3
# s = 4, a = 2, s' = 5, p = 0.0
# s = 4, a = 2, s' = 6, p = 0.0
# s = 4, a = 2, s' = 7, p = 0.0
# s = 4, a = 2, s' = 8, p = 0.7
# s = 4, a = 2, s' = 9, p = 0.0
# s = 4, a = 2, s' = 10, p = 0.0
# s = 4, a = 2, s' = 11, p = 0.0
# --------------------------------------
# s = 4, a = 3, s' = 0, p = 0.15
# s = 4, a = 3, s' = 1, p = 0.0
# s = 4, a = 3, s' = 2, p = 0.0
# s = 4, a = 3, s' = 3, p = 0.0
# s = 4, a = 3, s' = 4, p = 0.7
# s = 4, a = 3, s' = 5, p = 0.0
# s = 4, a = 3, s' = 6, p = 0.0
# s = 4, a = 3, s' = 7, p = 0.0
# s = 4, a = 3, s' = 8, p = 0.15
# s = 4, a = 3, s' = 9, p = 0.0
# s = 4, a = 3, s' = 10, p = 0.0
# s = 4, a = 3, s' = 11, p = 0.0
# ======================================
# --------------------------------------
# s = 5, a = 0, s' = 0, p = 0.0
# s = 5, a = 0, s' = 1, p = 0.0
# s = 5, a = 0, s' = 2, p = 0.0
# s = 5, a = 0, s' = 3, p = 0.0
# s = 5, a = 0, s' = 4, p = 0.0
# s = 5, a = 0, s' = 5, p = 1.0
# s = 5, a = 0, s' = 6, p = 0.0
# s = 5, a = 0, s' = 7, p = 0.0
# s = 5, a = 0, s' = 8, p = 0.0
# s = 5, a = 0, s' = 9, p = 0.0
# s = 5, a = 0, s' = 10, p = 0.0
# s = 5, a = 0, s' = 11, p = 0.0
# --------------------------------------
# s = 5, a = 1, s' = 0, p = 0.0
# s = 5, a = 1, s' = 1, p = 0.0
# s = 5, a = 1, s' = 2, p = 0.0
# s = 5, a = 1, s' = 3, p = 0.0
# s = 5, a = 1, s' = 4, p = 0.0
# s = 5, a = 1, s' = 5, p = 1.0
# s = 5, a = 1, s' = 6, p = 0.0
# s = 5, a = 1, s' = 7, p = 0.0
# s = 5, a = 1, s' = 8, p = 0.0
# s = 5, a = 1, s' = 9, p = 0.0
# s = 5, a = 1, s' = 10, p = 0.0
# s = 5, a = 1, s' = 11, p = 0.0
# --------------------------------------
# s = 5, a = 2, s' = 0, p = 0.0
# s = 5, a = 2, s' = 1, p = 0.0
# s = 5, a = 2, s' = 2, p = 0.0
# s = 5, a = 2, s' = 3, p = 0.0
# s = 5, a = 2, s' = 4, p = 0.0
# s = 5, a = 2, s' = 5, p = 1.0
# s = 5, a = 2, s' = 6, p = 0.0
# s = 5, a = 2, s' = 7, p = 0.0
# s = 5, a = 2, s' = 8, p = 0.0
# s = 5, a = 2, s' = 9, p = 0.0
# s = 5, a = 2, s' = 10, p = 0.0
# s = 5, a = 2, s' = 11, p = 0.0
# --------------------------------------
# s = 5, a = 3, s' = 0, p = 0.0
# s = 5, a = 3, s' = 1, p = 0.0
# s = 5, a = 3, s' = 2, p = 0.0
# s = 5, a = 3, s' = 3, p = 0.0
# s = 5, a = 3, s' = 4, p = 0.0
# s = 5, a = 3, s' = 5, p = 1.0
# s = 5, a = 3, s' = 6, p = 0.0
# s = 5, a = 3, s' = 7, p = 0.0
# s = 5, a = 3, s' = 8, p = 0.0
# s = 5, a = 3, s' = 9, p = 0.0
# s = 5, a = 3, s' = 10, p = 0.0
# s = 5, a = 3, s' = 11, p = 0.0
# ======================================
# --------------------------------------
# s = 6, a = 0, s' = 0, p = 0.0
# s = 6, a = 0, s' = 1, p = 0.0
# s = 6, a = 0, s' = 2, p = 0.7
# s = 6, a = 0, s' = 3, p = 0.0
# s = 6, a = 0, s' = 4, p = 0.0
# s = 6, a = 0, s' = 5, p = 0.0
# s = 6, a = 0, s' = 6, p = 0.15
# s = 6, a = 0, s' = 7, p = 0.15
# s = 6, a = 0, s' = 8, p = 0.0
# s = 6, a = 0, s' = 9, p = 0.0
# s = 6, a = 0, s' = 10, p = 0.0
# s = 6, a = 0, s' = 11, p = 0.0
# --------------------------------------
# s = 6, a = 1, s' = 0, p = 0.0
# s = 6, a = 1, s' = 1, p = 0.0
# s = 6, a = 1, s' = 2, p = 0.15
# s = 6, a = 1, s' = 3, p = 0.0
# s = 6, a = 1, s' = 4, p = 0.0
# s = 6, a = 1, s' = 5, p = 0.0
# s = 6, a = 1, s' = 6, p = 0.0
# s = 6, a = 1, s' = 7, p = 0.7
# s = 6, a = 1, s' = 8, p = 0.0
# s = 6, a = 1, s' = 9, p = 0.0
# s = 6, a = 1, s' = 10, p = 0.15
# s = 6, a = 1, s' = 11, p = 0.0
# --------------------------------------
# s = 6, a = 2, s' = 0, p = 0.0
# s = 6, a = 2, s' = 1, p = 0.0
# s = 6, a = 2, s' = 2, p = 0.0
# s = 6, a = 2, s' = 3, p = 0.0
# s = 6, a = 2, s' = 4, p = 0.0
# s = 6, a = 2, s' = 5, p = 0.0
# s = 6, a = 2, s' = 6, p = 0.15
# s = 6, a = 2, s' = 7, p = 0.15
# s = 6, a = 2, s' = 8, p = 0.0
# s = 6, a = 2, s' = 9, p = 0.0
# s = 6, a = 2, s' = 10, p = 0.7
# s = 6, a = 2, s' = 11, p = 0.0
# --------------------------------------
# s = 6, a = 3, s' = 0, p = 0.0
# s = 6, a = 3, s' = 1, p = 0.0
# s = 6, a = 3, s' = 2, p = 0.15
# s = 6, a = 3, s' = 3, p = 0.0
# s = 6, a = 3, s' = 4, p = 0.0
# s = 6, a = 3, s' = 5, p = 0.0
# s = 6, a = 3, s' = 6, p = 0.7
# s = 6, a = 3, s' = 7, p = 0.0
# s = 6, a = 3, s' = 8, p = 0.0
# s = 6, a = 3, s' = 9, p = 0.0
# s = 6, a = 3, s' = 10, p = 0.15
# s = 6, a = 3, s' = 11, p = 0.0
# ======================================
# --------------------------------------
# s = 7, a = 0, s' = 0, p = 0.0
# s = 7, a = 0, s' = 1, p = 0.0
# s = 7, a = 0, s' = 2, p = 0.0
# s = 7, a = 0, s' = 3, p = 0.0
# s = 7, a = 0, s' = 4, p = 0.0
# s = 7, a = 0, s' = 5, p = 0.0
# s = 7, a = 0, s' = 6, p = 0.0
# s = 7, a = 0, s' = 7, p = 1.0
# s = 7, a = 0, s' = 8, p = 0.0
# s = 7, a = 0, s' = 9, p = 0.0
# s = 7, a = 0, s' = 10, p = 0.0
# s = 7, a = 0, s' = 11, p = 0.0
# --------------------------------------
# s = 7, a = 1, s' = 0, p = 0.0
# s = 7, a = 1, s' = 1, p = 0.0
# s = 7, a = 1, s' = 2, p = 0.0
# s = 7, a = 1, s' = 3, p = 0.0
# s = 7, a = 1, s' = 4, p = 0.0
# s = 7, a = 1, s' = 5, p = 0.0
# s = 7, a = 1, s' = 6, p = 0.0
# s = 7, a = 1, s' = 7, p = 1.0
# s = 7, a = 1, s' = 8, p = 0.0
# s = 7, a = 1, s' = 9, p = 0.0
# s = 7, a = 1, s' = 10, p = 0.0
# s = 7, a = 1, s' = 11, p = 0.0
# --------------------------------------
# s = 7, a = 2, s' = 0, p = 0.0
# s = 7, a = 2, s' = 1, p = 0.0
# s = 7, a = 2, s' = 2, p = 0.0
# s = 7, a = 2, s' = 3, p = 0.0
# s = 7, a = 2, s' = 4, p = 0.0
# s = 7, a = 2, s' = 5, p = 0.0
# s = 7, a = 2, s' = 6, p = 0.0
# s = 7, a = 2, s' = 7, p = 1.0
# s = 7, a = 2, s' = 8, p = 0.0
# s = 7, a = 2, s' = 9, p = 0.0
# s = 7, a = 2, s' = 10, p = 0.0
# s = 7, a = 2, s' = 11, p = 0.0
# --------------------------------------
# s = 7, a = 3, s' = 0, p = 0.0
# s = 7, a = 3, s' = 1, p = 0.0
# s = 7, a = 3, s' = 2, p = 0.0
# s = 7, a = 3, s' = 3, p = 0.0
# s = 7, a = 3, s' = 4, p = 0.0
# s = 7, a = 3, s' = 5, p = 0.0
# s = 7, a = 3, s' = 6, p = 0.0
# s = 7, a = 3, s' = 7, p = 1.0
# s = 7, a = 3, s' = 8, p = 0.0
# s = 7, a = 3, s' = 9, p = 0.0
# s = 7, a = 3, s' = 10, p = 0.0
# s = 7, a = 3, s' = 11, p = 0.0
# ======================================
# --------------------------------------
# s = 8, a = 0, s' = 0, p = 0.0
# s = 8, a = 0, s' = 1, p = 0.0
# s = 8, a = 0, s' = 2, p = 0.0
# s = 8, a = 0, s' = 3, p = 0.0
# s = 8, a = 0, s' = 4, p = 0.7
# s = 8, a = 0, s' = 5, p = 0.0
# s = 8, a = 0, s' = 6, p = 0.0
# s = 8, a = 0, s' = 7, p = 0.0
# s = 8, a = 0, s' = 8, p = 0.15
# s = 8, a = 0, s' = 9, p = 0.15
# s = 8, a = 0, s' = 10, p = 0.0
# s = 8, a = 0, s' = 11, p = 0.0
# --------------------------------------
# s = 8, a = 1, s' = 0, p = 0.0
# s = 8, a = 1, s' = 1, p = 0.0
# s = 8, a = 1, s' = 2, p = 0.0
# s = 8, a = 1, s' = 3, p = 0.0
# s = 8, a = 1, s' = 4, p = 0.15
# s = 8, a = 1, s' = 5, p = 0.0
# s = 8, a = 1, s' = 6, p = 0.0
# s = 8, a = 1, s' = 7, p = 0.0
# s = 8, a = 1, s' = 8, p = 0.15
# s = 8, a = 1, s' = 9, p = 0.7
# s = 8, a = 1, s' = 10, p = 0.0
# s = 8, a = 1, s' = 11, p = 0.0
# --------------------------------------
# s = 8, a = 2, s' = 0, p = 0.0
# s = 8, a = 2, s' = 1, p = 0.0
# s = 8, a = 2, s' = 2, p = 0.0
# s = 8, a = 2, s' = 3, p = 0.0
# s = 8, a = 2, s' = 4, p = 0.0
# s = 8, a = 2, s' = 5, p = 0.0
# s = 8, a = 2, s' = 6, p = 0.0
# s = 8, a = 2, s' = 7, p = 0.0
# s = 8, a = 2, s' = 8, p = 0.85
# s = 8, a = 2, s' = 9, p = 0.15
# s = 8, a = 2, s' = 10, p = 0.0
# s = 8, a = 2, s' = 11, p = 0.0
# --------------------------------------
# s = 8, a = 3, s' = 0, p = 0.0
# s = 8, a = 3, s' = 1, p = 0.0
# s = 8, a = 3, s' = 2, p = 0.0
# s = 8, a = 3, s' = 3, p = 0.0
# s = 8, a = 3, s' = 4, p = 0.15
# s = 8, a = 3, s' = 5, p = 0.0
# s = 8, a = 3, s' = 6, p = 0.0
# s = 8, a = 3, s' = 7, p = 0.0
# s = 8, a = 3, s' = 8, p = 0.85
# s = 8, a = 3, s' = 9, p = 0.0
# s = 8, a = 3, s' = 10, p = 0.0
# s = 8, a = 3, s' = 11, p = 0.0
# ======================================
# --------------------------------------
# s = 9, a = 0, s' = 0, p = 0.0
# s = 9, a = 0, s' = 1, p = 0.0
# s = 9, a = 0, s' = 2, p = 0.0
# s = 9, a = 0, s' = 3, p = 0.0
# s = 9, a = 0, s' = 4, p = 0.0
# s = 9, a = 0, s' = 5, p = 0.0
# s = 9, a = 0, s' = 6, p = 0.0
# s = 9, a = 0, s' = 7, p = 0.0
# s = 9, a = 0, s' = 8, p = 0.15
# s = 9, a = 0, s' = 9, p = 0.7
# s = 9, a = 0, s' = 10, p = 0.15
# s = 9, a = 0, s' = 11, p = 0.0
# --------------------------------------
# s = 9, a = 1, s' = 0, p = 0.0
# s = 9, a = 1, s' = 1, p = 0.0
# s = 9, a = 1, s' = 2, p = 0.0
# s = 9, a = 1, s' = 3, p = 0.0
# s = 9, a = 1, s' = 4, p = 0.0
# s = 9, a = 1, s' = 5, p = 0.0
# s = 9, a = 1, s' = 6, p = 0.0
# s = 9, a = 1, s' = 7, p = 0.0
# s = 9, a = 1, s' = 8, p = 0.0
# s = 9, a = 1, s' = 9, p = 0.3
# s = 9, a = 1, s' = 10, p = 0.7
# s = 9, a = 1, s' = 11, p = 0.0
# --------------------------------------
# s = 9, a = 2, s' = 0, p = 0.0
# s = 9, a = 2, s' = 1, p = 0.0
# s = 9, a = 2, s' = 2, p = 0.0
# s = 9, a = 2, s' = 3, p = 0.0
# s = 9, a = 2, s' = 4, p = 0.0
# s = 9, a = 2, s' = 5, p = 0.0
# s = 9, a = 2, s' = 6, p = 0.0
# s = 9, a = 2, s' = 7, p = 0.0
# s = 9, a = 2, s' = 8, p = 0.15
# s = 9, a = 2, s' = 9, p = 0.7
# s = 9, a = 2, s' = 10, p = 0.15
# s = 9, a = 2, s' = 11, p = 0.0
# --------------------------------------
# s = 9, a = 3, s' = 0, p = 0.0
# s = 9, a = 3, s' = 1, p = 0.0
# s = 9, a = 3, s' = 2, p = 0.0
# s = 9, a = 3, s' = 3, p = 0.0
# s = 9, a = 3, s' = 4, p = 0.0
# s = 9, a = 3, s' = 5, p = 0.0
# s = 9, a = 3, s' = 6, p = 0.0
# s = 9, a = 3, s' = 7, p = 0.0
# s = 9, a = 3, s' = 8, p = 0.7
# s = 9, a = 3, s' = 9, p = 0.3
# s = 9, a = 3, s' = 10, p = 0.0
# s = 9, a = 3, s' = 11, p = 0.0
# ======================================
# --------------------------------------
# s = 10, a = 0, s' = 0, p = 0.0
# s = 10, a = 0, s' = 1, p = 0.0
# s = 10, a = 0, s' = 2, p = 0.0
# s = 10, a = 0, s' = 3, p = 0.0
# s = 10, a = 0, s' = 4, p = 0.0
# s = 10, a = 0, s' = 5, p = 0.0
# s = 10, a = 0, s' = 6, p = 0.7
# s = 10, a = 0, s' = 7, p = 0.0
# s = 10, a = 0, s' = 8, p = 0.0
# s = 10, a = 0, s' = 9, p = 0.15
# s = 10, a = 0, s' = 10, p = 0.0
# s = 10, a = 0, s' = 11, p = 0.15
# --------------------------------------
# s = 10, a = 1, s' = 0, p = 0.0
# s = 10, a = 1, s' = 1, p = 0.0
# s = 10, a = 1, s' = 2, p = 0.0
# s = 10, a = 1, s' = 3, p = 0.0
# s = 10, a = 1, s' = 4, p = 0.0
# s = 10, a = 1, s' = 5, p = 0.0
# s = 10, a = 1, s' = 6, p = 0.15
# s = 10, a = 1, s' = 7, p = 0.0
# s = 10, a = 1, s' = 8, p = 0.0
# s = 10, a = 1, s' = 9, p = 0.0
# s = 10, a = 1, s' = 10, p = 0.15
# s = 10, a = 1, s' = 11, p = 0.7
# --------------------------------------
# s = 10, a = 2, s' = 0, p = 0.0
# s = 10, a = 2, s' = 1, p = 0.0
# s = 10, a = 2, s' = 2, p = 0.0
# s = 10, a = 2, s' = 3, p = 0.0
# s = 10, a = 2, s' = 4, p = 0.0
# s = 10, a = 2, s' = 5, p = 0.0
# s = 10, a = 2, s' = 6, p = 0.0
# s = 10, a = 2, s' = 7, p = 0.0
# s = 10, a = 2, s' = 8, p = 0.0
# s = 10, a = 2, s' = 9, p = 0.15
# s = 10, a = 2, s' = 10, p = 0.7
# s = 10, a = 2, s' = 11, p = 0.15
# --------------------------------------
# s = 10, a = 3, s' = 0, p = 0.0
# s = 10, a = 3, s' = 1, p = 0.0
# s = 10, a = 3, s' = 2, p = 0.0
# s = 10, a = 3, s' = 3, p = 0.0
# s = 10, a = 3, s' = 4, p = 0.0
# s = 10, a = 3, s' = 5, p = 0.0
# s = 10, a = 3, s' = 6, p = 0.15
# s = 10, a = 3, s' = 7, p = 0.0
# s = 10, a = 3, s' = 8, p = 0.0
# s = 10, a = 3, s' = 9, p = 0.7
# s = 10, a = 3, s' = 10, p = 0.15
# s = 10, a = 3, s' = 11, p = 0.0
# ======================================
# --------------------------------------
# s = 11, a = 0, s' = 0, p = 0.0
# s = 11, a = 0, s' = 1, p = 0.0
# s = 11, a = 0, s' = 2, p = 0.0
# s = 11, a = 0, s' = 3, p = 0.0
# s = 11, a = 0, s' = 4, p = 0.0
# s = 11, a = 0, s' = 5, p = 0.0
# s = 11, a = 0, s' = 6, p = 0.0
# s = 11, a = 0, s' = 7, p = 0.7
# s = 11, a = 0, s' = 8, p = 0.0
# s = 11, a = 0, s' = 9, p = 0.0
# s = 11, a = 0, s' = 10, p = 0.15
# s = 11, a = 0, s' = 11, p = 0.15
# --------------------------------------
# s = 11, a = 1, s' = 0, p = 0.0
# s = 11, a = 1, s' = 1, p = 0.0
# s = 11, a = 1, s' = 2, p = 0.0
# s = 11, a = 1, s' = 3, p = 0.0
# s = 11, a = 1, s' = 4, p = 0.0
# s = 11, a = 1, s' = 5, p = 0.0
# s = 11, a = 1, s' = 6, p = 0.0
# s = 11, a = 1, s' = 7, p = 0.15
# s = 11, a = 1, s' = 8, p = 0.0
# s = 11, a = 1, s' = 9, p = 0.0
# s = 11, a = 1, s' = 10, p = 0.0
# s = 11, a = 1, s' = 11, p = 0.85
# --------------------------------------
# s = 11, a = 2, s' = 0, p = 0.0
# s = 11, a = 2, s' = 1, p = 0.0
# s = 11, a = 2, s' = 2, p = 0.0
# s = 11, a = 2, s' = 3, p = 0.0
# s = 11, a = 2, s' = 4, p = 0.0
# s = 11, a = 2, s' = 5, p = 0.0
# s = 11, a = 2, s' = 6, p = 0.0
# s = 11, a = 2, s' = 7, p = 0.0
# s = 11, a = 2, s' = 8, p = 0.0
# s = 11, a = 2, s' = 9, p = 0.0
# s = 11, a = 2, s' = 10, p = 0.15
# s = 11, a = 2, s' = 11, p = 0.85
# --------------------------------------
# s = 11, a = 3, s' = 0, p = 0.0
# s = 11, a = 3, s' = 1, p = 0.0
# s = 11, a = 3, s' = 2, p = 0.0
# s = 11, a = 3, s' = 3, p = 0.0
# s = 11, a = 3, s' = 4, p = 0.0
# s = 11, a = 3, s' = 5, p = 0.0
# s = 11, a = 3, s' = 6, p = 0.0
# s = 11, a = 3, s' = 7, p = 0.15
# s = 11, a = 3, s' = 8, p = 0.0
# s = 11, a = 3, s' = 9, p = 0.0
# s = 11, a = 3, s' = 10, p = 0.7
# s = 11, a = 3, s' = 11, p = 0.15

# %% [markdown]
# #### Policy:
#  A policy is the thought process behind picking an action. In practice, it’s a probability distribution assigned to the set of actions. Highly rewarding actions will have a high probability and vice versa. If an action has a low probability, it doesn’t mean it won’t be picked at all. It’s just less likely to be picked.

# %%
class PolicyIteration:
    def __init__(self, reward_function, transition_model, gamma, init_policy=None, init_value=None):
        self.num_states = transition_model.shape[0]
        self.num_actions = transition_model.shape[1]
        self.reward_function = np.nan_to_num(reward_function)

        self.transition_model = transition_model
        self.gamma = gamma

        if init_value is None:
            self.values = np.zeros(self.num_states)
        else:
            self.values = init_value
        if init_policy is None:
            self.policy = np.random.randint(0, self.num_actions, self.num_states)
        else:
            self.policy = init_policy

    def one_policy_evaluation(self):
        delta = 0
        for s in range(self.num_states):
            temp = self.values[s]
            a = self.policy[s]
            p = self.transition_model[s, a]
            self.values[s] = self.reward_function[s] + self.gamma * np.sum(p * self.values)
            delta = max(delta, abs(temp - self.values[s]))
        return delta

    def run_policy_evaluation(self, tol=1e-3):
        epoch = 0
        delta = self.one_policy_evaluation()
        delta_history = [delta]
        while epoch < 500:
            delta = self.one_policy_evaluation()
            delta_history.append(delta)
            if delta < tol:
                break
        return len(delta_history)

    def run_policy_improvement(self):
        update_policy_count = 0
        for s in range(self.num_states):
            temp = self.policy[s]
            v_list = np.zeros(self.num_actions)
            for a in range(self.num_actions):
                p = self.transition_model[s, a]
                v_list[a] = np.sum(p * self.values)
            self.policy[s] = np.argmax(v_list)
            if temp != self.policy[s]:
                update_policy_count += 1
        return update_policy_count

    def train(self, tol=1e-3, plot=True):
        epoch = 0
        eval_count_history = []
        policy_change_history = []
        while epoch < 500:
            epoch += 1
            eval_count = self.run_policy_evaluation(tol)
            policy_change = self.run_policy_improvement()
            eval_count_history.append(eval_count)
            policy_change_history.append(policy_change)
            if policy_change == 0:
                break


        if plot is True:
            fig, axes = plt.subplots(2, 1, figsize=(3.5, 4), sharex='all', dpi=200)
            axes[0].plot(np.arange(len(eval_count_history)), eval_count_history, marker='o', markersize=4, alpha=0.7,
                         color='#2ca02c', label='# sweep in \npolicy evaluation\n' + r'$\gamma =$' + f'{self.gamma}')
            axes[0].legend()

            axes[1].plot(np.arange(len(policy_change_history)), policy_change_history, marker='o',
                         markersize=4, alpha=0.7, color='#d62728',
                         label='# policy updates in \npolicy improvement\n' + r'$\gamma =$' + f'{self.gamma}')
            axes[1].set_xlabel('Epoch')
            axes[1].legend()
            plt.tight_layout()
            plt.show()

            print(f'# epoch: {len(policy_change_history)}')
            print(f'eval count = {eval_count_history}')
            print(f'policy change = {policy_change_history}')

# %% [markdown]
# Implementation of Policy iteration in MDP

# %%
mdp = GridWorld('/content/world00.csv', reward={0: -0.04, 1: 1.0, 2: -1.0, 3: np.NaN}, random_rate=0.2)
#policy = [1, 1, 3, 1, 0, 0, 2, 0, 1, 2, 1, 0]

solver = PolicyIteration(mdp.reward_function, mdp.transition_model, gamma=0.9, init_policy=None)
solver.train()
# Out:
# # epoch: 4
# eval count = [67, 28, 10, 5]
# policy change = [9, 1, 1, 0]

# %%
mdp.visualize_value_policy(policy=solver.policy, values=solver.values)
# Out:
# <ipython-input-5-ece47fdee11e>:261: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()

# %%
mdp.random_start_policy(policy=solver.policy, start_pos=(2, 1), n=1000)
# Out:
# i = 0 Random start result: 0.56
# i = 1 Random start result: 0.6000000000000001
# i = 2 Random start result: 0.6799999999999999
# i = 3 Random start result: 0.64
# i = 4 Random start result: 0.76
# i = 5 Random start result: 0.76
# i = 6 Random start result: 0.4
# i = 7 Random start result: 0.6799999999999999
# i = 8 Random start result: 0.72
# i = 9 Random start result: 0.76
# i = 10 Random start result: 0.76
# i = 11 Random start result: 0.6000000000000001
# i = 12 Random start result: 0.76
# i = 13 Random start result: 0.76
# i = 14 Random start result: 0.76
# i = 15 Random start result: 0.4800000000000001
# i = 16 Random start result: 0.76
# i = 17 Random start result: 0.76
# i = 18 Random start result: 0.52
# i = 19 Random start result: 0.44000000000000006
# i = 20 Random start result: 0.72
# i = 21 Random start result: 0.64
# i = 22 Random start result: 0.6799999999999999
# i = 23 Random start result: 0.76
# i = 24 Random start result: 0.44000000000000006
# i = 25 Random start result: 0.72
# i = 26 Random start result: 0.76
# i = 27 Random start result: 0.6799999999999999
# i = 28 Random start result: 0.6799999999999999
# i = 29 Random start result: 0.72
# i = 30 Random start result: 0.72
# i = 31 Random start result: 0.64
# i = 32 Random start result: 0.72
# i = 33 Random start result: 0.6000000000000001
# i = 34 Random start result: 0.76
# i = 35 Random start result: 0.64
# i = 36 Random start result: 0.76
# i = 37 Random start result: -1.32
# i = 38 Random start result: 0.72
# i = 39 Random start result: 0.52
# i = 40 Random start result: 0.72
# i = 41 Random start result: 0.64
# i = 42 Random start result: 0.6799999999999999
# i = 43 Random start result: 0.52
# i = 44 Random start result: 0.72
# i = 45 Random start result: 0.6000000000000001
# i = 46 Random start result: -1.32
# i = 47 Random start result: 0.76
# i = 48 Random start result: 0.6799999999999999
# i = 49 Random start result: 0.76
# i = 50 Random start result: 0.6799999999999999
# i = 51 Random start result: 0.6799999999999999
# i = 52 Random start result: 0.6799999999999999
# i = 53 Random start result: 0.64
# i = 54 Random start result: 0.64
# i = 55 Random start result: 0.6799999999999999
# i = 56 Random start result: 0.6799999999999999
# i = 57 Random start result: 0.72
# i = 58 Random start result: 0.6799999999999999
# i = 59 Random start result: 0.6799999999999999
# i = 60 Random start result: 0.72
# i = 61 Random start result: 0.52
# i = 62 Random start result: 0.76
# i = 63 Random start result: 0.64
# i = 64 Random start result: 0.6799999999999999
# i = 65 Random start result: 0.76
# i = 66 Random start result: 0.72
# i = 67 Random start result: 0.4800000000000001
# i = 68 Random start result: 0.72
# i = 69 Random start result: 0.6000000000000001
# i = 70 Random start result: 0.76
# i = 71 Random start result: 0.76
# i = 72 Random start result: 0.6799999999999999
# i = 73 Random start result: 0.72
# i = 74 Random start result: 0.6000000000000001
# i = 75 Random start result: 0.72
# i = 76 Random start result: 0.6799999999999999
# i = 77 Random start result: 0.64
# i = 78 Random start result: 0.6000000000000001
# i = 79 Random start result: 0.76
# i = 80 Random start result: 0.6799999999999999
# i = 81 Random start result: 0.6799999999999999
# i = 82 Random start result: 0.76
# i = 83 Random start result: 0.72
# i = 84 Random start result: 0.76
# i = 85 Random start result: 0.72
# i = 86 Random start result: 0.6000000000000001
# i = 87 Random start result: 0.64
# i = 88 Random start result: 0.76
# i = 89 Random start result: 0.72
# i = 90 Random start result: 0.76
# i = 91 Random start result: 0.76
# i = 92 Random start result: 0.72
# i = 93 Random start result: 0.72
# i = 94 Random start result: 0.4800000000000001
# i = 95 Random start result: 0.52
# i = 96 Random start result: 0.52
# i = 97 Random start result: 0.36
# i = 98 Random start result: 0.6799999999999999
# i = 99 Random start result: 0.64
# i = 100 Random start result: 0.6799999999999999
# i = 101 Random start result: 0.76
# i = 102 Random start result: 0.72
# i = 103 Random start result: 0.72
# i = 104 Random start result: 0.6799999999999999
# i = 105 Random start result: 0.72
# i = 106 Random start result: 0.6000000000000001
# i = 107 Random start result: 0.76
# i = 108 Random start result: 0.72
# i = 109 Random start result: 0.64
# i = 110 Random start result: 0.72
# i = 111 Random start result: 0.52
# i = 112 Random start result: 0.64
# i = 113 Random start result: 0.6000000000000001
# i = 114 Random start result: 0.76
# i = 115 Random start result: 0.4800000000000001
# i = 116 Random start result: 0.4800000000000001
# i = 117 Random start result: 0.6799999999999999
# i = 118 Random start result: -1.28
# i = 119 Random start result: 0.76
# i = 120 Random start result: 0.6000000000000001
# i = 121 Random start result: 0.6799999999999999
# i = 122 Random start result: 0.6799999999999999
# i = 123 Random start result: 0.76
# i = 124 Random start result: 0.6799999999999999
# i = 125 Random start result: 0.6799999999999999
# i = 126 Random start result: 0.76
# i = 127 Random start result: 0.76
# i = 128 Random start result: 0.76
# i = 129 Random start result: 0.56
# i = 130 Random start result: -1.28
# i = 131 Random start result: 0.72
# i = 132 Random start result: 0.6000000000000001
# i = 133 Random start result: 0.72
# i = 134 Random start result: 0.76
# i = 135 Random start result: 0.72
# i = 136 Random start result: -1.48
# i = 137 Random start result: 0.72
# i = 138 Random start result: 0.6799999999999999
# i = 139 Random start result: 0.56
# i = 140 Random start result: 0.76
# i = 141 Random start result: 0.76
# i = 142 Random start result: 0.76
# i = 143 Random start result: 0.76
# i = 144 Random start result: 0.6799999999999999
# i = 145 Random start result: 0.76
# i = 146 Random start result: 0.52
# i = 147 Random start result: 0.72
# i = 148 Random start result: 0.64
# i = 149 Random start result: 0.6799999999999999
# i = 150 Random start result: 0.6799999999999999
# i = 151 Random start result: 0.76
# i = 152 Random start result: 0.64
# i = 153 Random start result: 0.6799999999999999
# i = 154 Random start result: 0.72
# i = 155 Random start result: 0.64
# i = 156 Random start result: 0.76
# i = 157 Random start result: 0.6799999999999999
# i = 158 Random start result: 0.76
# i = 159 Random start result: 0.76
# i = 160 Random start result: 0.64
# i = 161 Random start result: 0.6799999999999999
# i = 162 Random start result: 0.6000000000000001
# i = 163 Random start result: 0.76
# i = 164 Random start result: 0.72
# i = 165 Random start result: 0.56
# i = 166 Random start result: 0.76
# i = 167 Random start result: 0.6799999999999999
# i = 168 Random start result: 0.64
# i = 169 Random start result: 0.72
# i = 170 Random start result: 0.6000000000000001
# i = 171 Random start result: 0.72
# i = 172 Random start result: 0.76
# i = 173 Random start result: 0.72
# i = 174 Random start result: 0.64
# i = 175 Random start result: 0.64
# i = 176 Random start result: 0.6000000000000001
# i = 177 Random start result: 0.6799999999999999
# i = 178 Random start result: 0.6799999999999999
# i = 179 Random start result: 0.64
# i = 180 Random start result: 0.44000000000000006
# i = 181 Random start result: 0.6000000000000001
# i = 182 Random start result: 0.6799999999999999
# i = 183 Random start result: 0.6000000000000001
# i = 184 Random start result: 0.6799999999999999
# i = 185 Random start result: 0.76
# i = 186 Random start result: 0.6000000000000001
# i = 187 Random start result: 0.6799999999999999
# i = 188 Random start result: 0.56
# i = 189 Random start result: 0.72
# i = 190 Random start result: 0.76
# i = 191 Random start result: 0.44000000000000006
# i = 192 Random start result: 0.56
# i = 193 Random start result: 0.76
# i = 194 Random start result: 0.76
# i = 195 Random start result: 0.76
# i = 196 Random start result: 0.64
# i = 197 Random start result: 0.6799999999999999
# i = 198 Random start result: 0.64
# i = 199 Random start result: 0.6799999999999999
# i = 200 Random start result: 0.72
# i = 201 Random start result: 0.72
# i = 202 Random start result: 0.72
# i = 203 Random start result: 0.56
# i = 204 Random start result: 0.76
# i = 205 Random start result: 0.76
# i = 206 Random start result: 0.72
# i = 207 Random start result: 0.6799999999999999
# i = 208 Random start result: 0.76
# i = 209 Random start result: 0.72
# i = 210 Random start result: 0.6799999999999999
# i = 211 Random start result: 0.76
# i = 212 Random start result: 0.76
# i = 213 Random start result: 0.6000000000000001
# i = 214 Random start result: 0.56
# i = 215 Random start result: 0.6000000000000001
# i = 216 Random start result: 0.76
# i = 217 Random start result: 0.6799999999999999
# i = 218 Random start result: 0.76
# i = 219 Random start result: 0.72
# i = 220 Random start result: 0.6799999999999999
# i = 221 Random start result: 0.72
# i = 222 Random start result: 0.72
# i = 223 Random start result: 0.64
# i = 224 Random start result: 0.72
# i = 225 Random start result: 0.6799999999999999
# i = 226 Random start result: 0.6799999999999999
# i = 227 Random start result: 0.72
# i = 228 Random start result: 0.56
# i = 229 Random start result: 0.76
# i = 230 Random start result: 0.72
# i = 231 Random start result: 0.76
# i = 232 Random start result: 0.6000000000000001
# i = 233 Random start result: 0.76
# i = 234 Random start result: 0.6000000000000001
# i = 235 Random start result: 0.6799999999999999
# i = 236 Random start result: 0.6000000000000001
# i = 237 Random start result: 0.76
# i = 238 Random start result: 0.64
# i = 239 Random start result: 0.64
# i = 240 Random start result: 0.56
# i = 241 Random start result: 0.64
# i = 242 Random start result: 0.64
# i = 243 Random start result: 0.6000000000000001
# i = 244 Random start result: 0.56
# i = 245 Random start result: 0.64
# i = 246 Random start result: 0.44000000000000006
# i = 247 Random start result: 0.76
# i = 248 Random start result: 0.76
# i = 249 Random start result: 0.76
# i = 250 Random start result: 0.52
# i = 251 Random start result: 0.76
# i = 252 Random start result: 0.72
# i = 253 Random start result: 0.76
# i = 254 Random start result: 0.64
# i = 255 Random start result: 0.64
# i = 256 Random start result: 0.72
# i = 257 Random start result: -1.3599999999999999
# i = 258 Random start result: 0.6000000000000001
# i = 259 Random start result: 0.72
# i = 260 Random start result: 0.76
# i = 261 Random start result: 0.64
# i = 262 Random start result: 0.76
# i = 263 Random start result: 0.72
# i = 264 Random start result: 0.76
# i = 265 Random start result: 0.72
# i = 266 Random start result: 0.64
# i = 267 Random start result: 0.6799999999999999
# i = 268 Random start result: 0.6000000000000001
# i = 269 Random start result: 0.6799999999999999
# i = 270 Random start result: 0.52
# i = 271 Random start result: 0.76
# i = 272 Random start result: 0.76
# i = 273 Random start result: 0.64
# i = 274 Random start result: 0.6799999999999999
# i = 275 Random start result: 0.6799999999999999
# i = 276 Random start result: 0.6799999999999999
# i = 277 Random start result: 0.64
# i = 278 Random start result: 0.72
# i = 279 Random start result: 0.76
# i = 280 Random start result: 0.72
# i = 281 Random start result: 0.52
# i = 282 Random start result: 0.76
# i = 283 Random start result: 0.72
# i = 284 Random start result: 0.44000000000000006
# i = 285 Random start result: 0.6799999999999999
# i = 286 Random start result: 0.76
# i = 287 Random start result: 0.72
# i = 288 Random start result: 0.64
# i = 289 Random start result: 0.76
# i = 290 Random start result: 0.6799999999999999
# i = 291 Random start result: 0.64
# i = 292 Random start result: 0.76
# i = 293 Random start result: 0.64
# i = 294 Random start result: 0.6799999999999999
# i = 295 Random start result: 0.64
# i = 296 Random start result: 0.72
# i = 297 Random start result: 0.64
# i = 298 Random start result: 0.64
# i = 299 Random start result: 0.6799999999999999
# i = 300 Random start result: 0.76
# i = 301 Random start result: 0.6799999999999999
# i = 302 Random start result: 0.56
# i = 303 Random start result: 0.6799999999999999
# i = 304 Random start result: 0.72
# i = 305 Random start result: 0.6799999999999999
# i = 306 Random start result: 0.6799999999999999
# i = 307 Random start result: 0.64
# i = 308 Random start result: 0.52
# i = 309 Random start result: 0.6000000000000001
# i = 310 Random start result: 0.72
# i = 311 Random start result: 0.64
# i = 312 Random start result: 0.76
# i = 313 Random start result: 0.72
# i = 314 Random start result: 0.72
# i = 315 Random start result: 0.72
# i = 316 Random start result: 0.72
# i = 317 Random start result: 0.64
# i = 318 Random start result: 0.6799999999999999
# i = 319 Random start result: 0.6799999999999999
# i = 320 Random start result: 0.72
# i = 321 Random start result: 0.76
# i = 322 Random start result: 0.6799999999999999
# i = 323 Random start result: 0.76
# i = 324 Random start result: 0.6799999999999999
# i = 325 Random start result: 0.72
# i = 326 Random start result: 0.76
# i = 327 Random start result: 0.72
# i = 328 Random start result: 0.6799999999999999
# i = 329 Random start result: 0.72
# i = 330 Random start result: 0.64
# i = 331 Random start result: 0.6000000000000001
# i = 332 Random start result: 0.76
# i = 333 Random start result: 0.76
# i = 334 Random start result: 0.56
# i = 335 Random start result: 0.6000000000000001
# i = 336 Random start result: 0.6000000000000001
# i = 337 Random start result: 0.76
# i = 338 Random start result: 0.6799999999999999
# i = 339 Random start result: 0.76
# i = 340 Random start result: 0.6000000000000001
# i = 341 Random start result: 0.76
# i = 342 Random start result: 0.52
# i = 343 Random start result: 0.6799999999999999
# i = 344 Random start result: 0.72
# i = 345 Random start result: 0.64
# i = 346 Random start result: 0.56
# i = 347 Random start result: 0.4
# i = 348 Random start result: 0.6799999999999999
# i = 349 Random start result: 0.52
# i = 350 Random start result: 0.56
# i = 351 Random start result: 0.6799999999999999
# i = 352 Random start result: 0.72
# i = 353 Random start result: 0.76
# i = 354 Random start result: 0.64
# i = 355 Random start result: 0.76
# i = 356 Random start result: 0.6799999999999999
# i = 357 Random start result: 0.6799999999999999
# i = 358 Random start result: 0.72
# i = 359 Random start result: 0.76
# i = 360 Random start result: 0.44000000000000006
# i = 361 Random start result: 0.76
# i = 362 Random start result: 0.76
# i = 363 Random start result: 0.6799999999999999
# i = 364 Random start result: 0.76
# i = 365 Random start result: 0.72
# i = 366 Random start result: 0.72
# i = 367 Random start result: 0.6799999999999999
# i = 368 Random start result: 0.72
# i = 369 Random start result: 0.64
# i = 370 Random start result: 0.76
# i = 371 Random start result: 0.72
# i = 372 Random start result: 0.72
# i = 373 Random start result: 0.56
# i = 374 Random start result: 0.76
# i = 375 Random start result: 0.72
# i = 376 Random start result: 0.6799999999999999
# i = 377 Random start result: 0.76
# i = 378 Random start result: 0.6799999999999999
# i = 379 Random start result: 0.64
# i = 380 Random start result: 0.6799999999999999
# i = 381 Random start result: 0.76
# i = 382 Random start result: 0.6799999999999999
# i = 383 Random start result: 0.76
# i = 384 Random start result: 0.64
# i = 385 Random start result: 0.6799999999999999
# i = 386 Random start result: 0.6000000000000001
# i = 387 Random start result: 0.64
# i = 388 Random start result: 0.72
# i = 389 Random start result: 0.64
# i = 390 Random start result: 0.72
# i = 391 Random start result: 0.6000000000000001
# i = 392 Random start result: 0.6799999999999999
# i = 393 Random start result: 0.72
# i = 394 Random start result: 0.76
# i = 395 Random start result: 0.72
# i = 396 Random start result: 0.76
# i = 397 Random start result: 0.6799999999999999
# i = 398 Random start result: 0.6799999999999999
# i = 399 Random start result: 0.64
# i = 400 Random start result: 0.76
# i = 401 Random start result: 0.64
# i = 402 Random start result: 0.76
# i = 403 Random start result: 0.6799999999999999
# i = 404 Random start result: 0.52
# i = 405 Random start result: 0.76
# i = 406 Random start result: 0.64
# i = 407 Random start result: 0.76
# i = 408 Random start result: 0.64
# i = 409 Random start result: 0.76
# i = 410 Random start result: 0.6799999999999999
# i = 411 Random start result: 0.72
# i = 412 Random start result: 0.72
# i = 413 Random start result: 0.6799999999999999
# i = 414 Random start result: 0.76
# i = 415 Random start result: 0.6799999999999999
# i = 416 Random start result: 0.6000000000000001
# i = 417 Random start result: 0.76
# i = 418 Random start result: 0.76
# i = 419 Random start result: 0.76
# i = 420 Random start result: 0.56
# i = 421 Random start result: 0.6000000000000001
# i = 422 Random start result: 0.76
# i = 423 Random start result: 0.6799999999999999
# i = 424 Random start result: 0.6799999999999999
# i = 425 Random start result: 0.76
# i = 426 Random start result: 0.72
# i = 427 Random start result: 0.76
# i = 428 Random start result: 0.76
# i = 429 Random start result: 0.64
# i = 430 Random start result: 0.76
# i = 431 Random start result: 0.76
# i = 432 Random start result: 0.64
# i = 433 Random start result: 0.76
# i = 434 Random start result: 0.76
# i = 435 Random start result: 0.6000000000000001
# i = 436 Random start result: 0.6799999999999999
# i = 437 Random start result: 0.64
# i = 438 Random start result: 0.72
# i = 439 Random start result: 0.72
# i = 440 Random start result: 0.6799999999999999
# i = 441 Random start result: 0.64
# i = 442 Random start result: 0.6799999999999999
# i = 443 Random start result: 0.6799999999999999
# i = 444 Random start result: 0.72
# i = 445 Random start result: -1.44
# i = 446 Random start result: 0.64
# i = 447 Random start result: 0.72
# i = 448 Random start result: 0.72
# i = 449 Random start result: 0.4800000000000001
# i = 450 Random start result: 0.76
# i = 451 Random start result: 0.64
# i = 452 Random start result: 0.6799999999999999
# i = 453 Random start result: 0.56
# i = 454 Random start result: 0.76
# i = 455 Random start result: 0.76
# i = 456 Random start result: 0.72
# i = 457 Random start result: 0.72
# i = 458 Random start result: 0.6799999999999999
# i = 459 Random start result: 0.6799999999999999
# i = 460 Random start result: 0.64
# i = 461 Random start result: 0.56
# i = 462 Random start result: 0.76
# i = 463 Random start result: 0.76
# i = 464 Random start result: 0.76
# i = 465 Random start result: 0.72
# i = 466 Random start result: 0.72
# i = 467 Random start result: 0.76
# i = 468 Random start result: 0.72
# i = 469 Random start result: 0.64
# i = 470 Random start result: 0.52
# i = 471 Random start result: 0.6799999999999999
# i = 472 Random start result: 0.4800000000000001
# i = 473 Random start result: 0.56
# i = 474 Random start result: 0.72
# i = 475 Random start result: 0.6799999999999999
# i = 476 Random start result: 0.72
# i = 477 Random start result: 0.6000000000000001
# i = 478 Random start result: 0.76
# i = 479 Random start result: 0.76
# i = 480 Random start result: 0.56
# i = 481 Random start result: 0.72
# i = 482 Random start result: 0.72
# i = 483 Random start result: 0.76
# i = 484 Random start result: 0.76
# i = 485 Random start result: 0.64
# i = 486 Random start result: 0.64
# i = 487 Random start result: 0.72
# i = 488 Random start result: 0.52
# i = 489 Random start result: 0.6000000000000001
# i = 490 Random start result: 0.72
# i = 491 Random start result: 0.72
# i = 492 Random start result: 0.64
# i = 493 Random start result: 0.64
# i = 494 Random start result: 0.6799999999999999
# i = 495 Random start result: 0.76
# i = 496 Random start result: 0.4
# i = 497 Random start result: 0.64
# i = 498 Random start result: 0.72
# i = 499 Random start result: 0.56
# i = 500 Random start result: 0.6799999999999999
# i = 501 Random start result: 0.56
# i = 502 Random start result: 0.76
# i = 503 Random start result: 0.76
# i = 504 Random start result: 0.76
# i = 505 Random start result: 0.72
# i = 506 Random start result: 0.6799999999999999
# i = 507 Random start result: 0.76
# i = 508 Random start result: 0.72
# i = 509 Random start result: 0.76
# i = 510 Random start result: 0.72
# i = 511 Random start result: 0.6000000000000001
# i = 512 Random start result: 0.6799999999999999
# i = 513 Random start result: 0.72
# i = 514 Random start result: 0.6000000000000001
# i = 515 Random start result: 0.6000000000000001
# i = 516 Random start result: 0.64
# i = 517 Random start result: 0.72
# i = 518 Random start result: 0.76
# i = 519 Random start result: 0.76
# i = 520 Random start result: 0.76
# i = 521 Random start result: 0.72
# i = 522 Random start result: 0.72
# i = 523 Random start result: 0.72
# i = 524 Random start result: 0.72
# i = 525 Random start result: 0.72
# i = 526 Random start result: 0.6799999999999999
# i = 527 Random start result: 0.72
# i = 528 Random start result: 0.72
# i = 529 Random start result: 0.76
# i = 530 Random start result: 0.6000000000000001
# i = 531 Random start result: 0.72
# i = 532 Random start result: 0.76
# i = 533 Random start result: 0.72
# i = 534 Random start result: 0.72
# i = 535 Random start result: 0.72
# i = 536 Random start result: 0.72
# i = 537 Random start result: 0.72
# i = 538 Random start result: 0.76
# i = 539 Random start result: 0.72
# i = 540 Random start result: 0.56
# i = 541 Random start result: 0.6799999999999999
# i = 542 Random start result: 0.72
# i = 543 Random start result: 0.76
# i = 544 Random start result: 0.76
# i = 545 Random start result: 0.56
# i = 546 Random start result: 0.76
# i = 547 Random start result: 0.64
# i = 548 Random start result: 0.72
# i = 549 Random start result: 0.4800000000000001
# i = 550 Random start result: 0.72
# i = 551 Random start result: 0.76
# i = 552 Random start result: 0.56
# i = 553 Random start result: 0.6000000000000001
# i = 554 Random start result: 0.6799999999999999
# i = 555 Random start result: 0.6799999999999999
# i = 556 Random start result: 0.76
# i = 557 Random start result: 0.72
# i = 558 Random start result: 0.76
# i = 559 Random start result: 0.76
# i = 560 Random start result: 0.6799999999999999
# i = 561 Random start result: 0.6799999999999999
# i = 562 Random start result: 0.76
# i = 563 Random start result: 0.64
# i = 564 Random start result: 0.76
# i = 565 Random start result: 0.76
# i = 566 Random start result: 0.76
# i = 567 Random start result: 0.6000000000000001
# i = 568 Random start result: 0.72
# i = 569 Random start result: 0.6799999999999999
# i = 570 Random start result: 0.72
# i = 571 Random start result: 0.72
# i = 572 Random start result: 0.64
# i = 573 Random start result: 0.56
# i = 574 Random start result: 0.72
# i = 575 Random start result: 0.76
# i = 576 Random start result: 0.76
# i = 577 Random start result: 0.6799999999999999
# i = 578 Random start result: 0.52
# i = 579 Random start result: 0.64
# i = 580 Random start result: 0.76
# i = 581 Random start result: 0.76
# i = 582 Random start result: 0.72
# i = 583 Random start result: 0.76
# i = 584 Random start result: 0.76
# i = 585 Random start result: 0.64
# i = 586 Random start result: 0.6799999999999999
# i = 587 Random start result: 0.72
# i = 588 Random start result: 0.72
# i = 589 Random start result: 0.72
# i = 590 Random start result: 0.64
# i = 591 Random start result: 0.72
# i = 592 Random start result: 0.52
# i = 593 Random start result: 0.76
# i = 594 Random start result: 0.72
# i = 595 Random start result: 0.76
# i = 596 Random start result: 0.56
# i = 597 Random start result: 0.76
# i = 598 Random start result: 0.6799999999999999
# i = 599 Random start result: 0.76
# i = 600 Random start result: 0.76
# i = 601 Random start result: 0.72
# i = 602 Random start result: 0.6799999999999999
# i = 603 Random start result: 0.72
# i = 604 Random start result: 0.76
# i = 605 Random start result: 0.64
# i = 606 Random start result: 0.72
# i = 607 Random start result: 0.76
# i = 608 Random start result: 0.76
# i = 609 Random start result: 0.72
# i = 610 Random start result: 0.64
# i = 611 Random start result: 0.76
# i = 612 Random start result: 0.6799999999999999
# i = 613 Random start result: 0.64
# i = 614 Random start result: 0.52
# i = 615 Random start result: 0.76
# i = 616 Random start result: 0.72
# i = 617 Random start result: 0.6000000000000001
# i = 618 Random start result: 0.6799999999999999
# i = 619 Random start result: 0.6799999999999999
# i = 620 Random start result: 0.44000000000000006
# i = 621 Random start result: 0.6000000000000001
# i = 622 Random start result: 0.72
# i = 623 Random start result: 0.64
# i = 624 Random start result: 0.76
# i = 625 Random start result: 0.76
# i = 626 Random start result: 0.72
# i = 627 Random start result: 0.72
# i = 628 Random start result: 0.76
# i = 629 Random start result: 0.6799999999999999
# i = 630 Random start result: 0.72
# i = 631 Random start result: 0.6000000000000001
# i = 632 Random start result: 0.64
# i = 633 Random start result: 0.76
# i = 634 Random start result: 0.6000000000000001
# i = 635 Random start result: 0.6799999999999999
# i = 636 Random start result: 0.76
# i = 637 Random start result: 0.76
# i = 638 Random start result: 0.6799999999999999
# i = 639 Random start result: 0.72
# i = 640 Random start result: 0.76
# i = 641 Random start result: 0.64
# i = 642 Random start result: 0.6799999999999999
# i = 643 Random start result: 0.76
# i = 644 Random start result: 0.72
# i = 645 Random start result: 0.72
# i = 646 Random start result: 0.6000000000000001
# i = 647 Random start result: 0.72
# i = 648 Random start result: 0.72
# i = 649 Random start result: 0.64
# i = 650 Random start result: 0.64
# i = 651 Random start result: 0.6000000000000001
# i = 652 Random start result: 0.72
# i = 653 Random start result: 0.76
# i = 654 Random start result: 0.6799999999999999
# i = 655 Random start result: 0.6000000000000001
# i = 656 Random start result: 0.6799999999999999
# i = 657 Random start result: 0.6799999999999999
# i = 658 Random start result: 0.72
# i = 659 Random start result: 0.76
# i = 660 Random start result: 0.6799999999999999
# i = 661 Random start result: 0.76
# i = 662 Random start result: 0.6799999999999999
# i = 663 Random start result: 0.6799999999999999
# i = 664 Random start result: 0.72
# i = 665 Random start result: 0.76
# i = 666 Random start result: 0.6000000000000001
# i = 667 Random start result: 0.76
# i = 668 Random start result: 0.44000000000000006
# i = 669 Random start result: 0.76
# i = 670 Random start result: 0.6799999999999999
# i = 671 Random start result: 0.36
# i = 672 Random start result: 0.76
# i = 673 Random start result: 0.76
# i = 674 Random start result: 0.72
# i = 675 Random start result: 0.76
# i = 676 Random start result: 0.64
# i = 677 Random start result: 0.76
# i = 678 Random start result: 0.72
# i = 679 Random start result: 0.72
# i = 680 Random start result: 0.6799999999999999
# i = 681 Random start result: 0.56
# i = 682 Random start result: 0.6000000000000001
# i = 683 Random start result: 0.52
# i = 684 Random start result: 0.64
# i = 685 Random start result: 0.6000000000000001
# i = 686 Random start result: 0.64
# i = 687 Random start result: 0.76
# i = 688 Random start result: 0.72
# i = 689 Random start result: 0.76
# i = 690 Random start result: 0.64
# i = 691 Random start result: 0.72
# i = 692 Random start result: 0.6799999999999999
# i = 693 Random start result: 0.64
# i = 694 Random start result: 0.64
# i = 695 Random start result: 0.64
# i = 696 Random start result: 0.76
# i = 697 Random start result: 0.72
# i = 698 Random start result: 0.56
# i = 699 Random start result: 0.72
# i = 700 Random start result: 0.72
# i = 701 Random start result: 0.6000000000000001
# i = 702 Random start result: 0.56
# i = 703 Random start result: 0.72
# i = 704 Random start result: 0.56
# i = 705 Random start result: 0.72
# i = 706 Random start result: 0.76
# i = 707 Random start result: 0.6000000000000001
# i = 708 Random start result: 0.76
# i = 709 Random start result: 0.64
# i = 710 Random start result: 0.6000000000000001
# i = 711 Random start result: 0.6000000000000001
# i = 712 Random start result: 0.72
# i = 713 Random start result: 0.76
# i = 714 Random start result: 0.52
# i = 715 Random start result: 0.6799999999999999
# i = 716 Random start result: 0.76
# i = 717 Random start result: 0.6000000000000001
# i = 718 Random start result: 0.6799999999999999
# i = 719 Random start result: 0.64
# i = 720 Random start result: 0.64
# i = 721 Random start result: 0.72
# i = 722 Random start result: -1.4
# i = 723 Random start result: 0.6799999999999999
# i = 724 Random start result: 0.6000000000000001
# i = 725 Random start result: 0.76
# i = 726 Random start result: 0.76
# i = 727 Random start result: 0.72
# i = 728 Random start result: 0.6000000000000001
# i = 729 Random start result: 0.64
# i = 730 Random start result: 0.76
# i = 731 Random start result: 0.76
# i = 732 Random start result: 0.72
# i = 733 Random start result: 0.6000000000000001
# i = 734 Random start result: 0.6799999999999999
# i = 735 Random start result: 0.76
# i = 736 Random start result: 0.76
# i = 737 Random start result: 0.64
# i = 738 Random start result: 0.72
# i = 739 Random start result: 0.6799999999999999
# i = 740 Random start result: 0.4800000000000001
# i = 741 Random start result: 0.6000000000000001
# i = 742 Random start result: 0.72
# i = 743 Random start result: 0.76
# i = 744 Random start result: 0.72
# i = 745 Random start result: 0.6799999999999999
# i = 746 Random start result: 0.76
# i = 747 Random start result: 0.72
# i = 748 Random start result: 0.64
# i = 749 Random start result: 0.76
# i = 750 Random start result: 0.72
# i = 751 Random start result: 0.6799999999999999
# i = 752 Random start result: 0.76
# i = 753 Random start result: 0.76
# i = 754 Random start result: 0.72
# i = 755 Random start result: 0.72
# i = 756 Random start result: 0.76
# i = 757 Random start result: 0.4800000000000001
# i = 758 Random start result: 0.6799999999999999
# i = 759 Random start result: 0.6799999999999999
# i = 760 Random start result: 0.6799999999999999
# i = 761 Random start result: 0.72
# i = 762 Random start result: 0.76
# i = 763 Random start result: 0.6799999999999999
# i = 764 Random start result: 0.76
# i = 765 Random start result: 0.76
# i = 766 Random start result: 0.6799999999999999
# i = 767 Random start result: 0.72
# i = 768 Random start result: 0.6000000000000001
# i = 769 Random start result: 0.6000000000000001
# i = 770 Random start result: 0.6799999999999999
# i = 771 Random start result: 0.6799999999999999
# i = 772 Random start result: 0.76
# i = 773 Random start result: 0.64
# i = 774 Random start result: 0.64
# i = 775 Random start result: 0.72
# i = 776 Random start result: 0.6799999999999999
# i = 777 Random start result: 0.72
# i = 778 Random start result: 0.6799999999999999
# i = 779 Random start result: 0.76
# i = 780 Random start result: 0.72
# i = 781 Random start result: 0.76
# i = 782 Random start result: 0.72
# i = 783 Random start result: 0.56
# i = 784 Random start result: 0.6799999999999999
# i = 785 Random start result: 0.76
# i = 786 Random start result: 0.72
# i = 787 Random start result: 0.6799999999999999
# i = 788 Random start result: 0.72
# i = 789 Random start result: 0.6799999999999999
# i = 790 Random start result: 0.76
# i = 791 Random start result: 0.72
# i = 792 Random start result: 0.6000000000000001
# i = 793 Random start result: 0.64
# i = 794 Random start result: 0.56
# i = 795 Random start result: 0.76
# i = 796 Random start result: 0.4
# i = 797 Random start result: 0.72
# i = 798 Random start result: 0.56
# i = 799 Random start result: 0.72
# i = 800 Random start result: 0.76
# i = 801 Random start result: 0.72
# i = 802 Random start result: 0.76
# i = 803 Random start result: 0.64
# i = 804 Random start result: 0.6000000000000001
# i = 805 Random start result: 0.72
# i = 806 Random start result: 0.76
# i = 807 Random start result: 0.72
# i = 808 Random start result: 0.52
# i = 809 Random start result: 0.76
# i = 810 Random start result: 0.64
# i = 811 Random start result: 0.76
# i = 812 Random start result: -1.52
# i = 813 Random start result: 0.52
# i = 814 Random start result: 0.6799999999999999
# i = 815 Random start result: 0.72
# i = 816 Random start result: 0.6799999999999999
# i = 817 Random start result: 0.6799999999999999
# i = 818 Random start result: 0.56
# i = 819 Random start result: 0.76
# i = 820 Random start result: 0.6799999999999999
# i = 821 Random start result: 0.76
# i = 822 Random start result: 0.72
# i = 823 Random start result: 0.64
# i = 824 Random start result: 0.76
# i = 825 Random start result: 0.6000000000000001
# i = 826 Random start result: 0.6799999999999999
# i = 827 Random start result: 0.76
# i = 828 Random start result: 0.64
# i = 829 Random start result: 0.56
# i = 830 Random start result: 0.6799999999999999
# i = 831 Random start result: 0.76
# i = 832 Random start result: 0.72
# i = 833 Random start result: 0.6799999999999999
# i = 834 Random start result: 0.72
# i = 835 Random start result: 0.76
# i = 836 Random start result: 0.72
# i = 837 Random start result: 0.52
# i = 838 Random start result: 0.6799999999999999
# i = 839 Random start result: 0.76
# i = 840 Random start result: 0.72
# i = 841 Random start result: 0.72
# i = 842 Random start result: 0.6799999999999999
# i = 843 Random start result: 0.72
# i = 844 Random start result: 0.64
# i = 845 Random start result: 0.76
# i = 846 Random start result: 0.6000000000000001
# i = 847 Random start result: -1.44
# i = 848 Random start result: 0.6799999999999999
# i = 849 Random start result: 0.56
# i = 850 Random start result: 0.6799999999999999
# i = 851 Random start result: 0.72
# i = 852 Random start result: 0.76
# i = 853 Random start result: 0.6799999999999999
# i = 854 Random start result: 0.72
# i = 855 Random start result: 0.76
# i = 856 Random start result: 0.64
# i = 857 Random start result: 0.64
# i = 858 Random start result: -1.32
# i = 859 Random start result: 0.6000000000000001
# i = 860 Random start result: 0.72
# i = 861 Random start result: 0.72
# i = 862 Random start result: 0.76
# i = 863 Random start result: 0.6000000000000001
# i = 864 Random start result: 0.72
# i = 865 Random start result: 0.52
# i = 866 Random start result: 0.56
# i = 867 Random start result: 0.6799999999999999
# i = 868 Random start result: 0.76
# i = 869 Random start result: 0.6000000000000001
# i = 870 Random start result: 0.72
# i = 871 Random start result: 0.23999999999999988
# i = 872 Random start result: 0.64
# i = 873 Random start result: 0.64
# i = 874 Random start result: 0.72
# i = 875 Random start result: 0.76
# i = 876 Random start result: 0.72
# i = 877 Random start result: 0.76
# i = 878 Random start result: 0.72
# i = 879 Random start result: 0.6799999999999999
# i = 880 Random start result: 0.76
# i = 881 Random start result: 0.64
# i = 882 Random start result: 0.64
# i = 883 Random start result: 0.6799999999999999
# i = 884 Random start result: 0.6000000000000001
# i = 885 Random start result: 0.6799999999999999
# i = 886 Random start result: 0.72
# i = 887 Random start result: 0.76
# i = 888 Random start result: 0.64
# i = 889 Random start result: 0.76
# i = 890 Random start result: 0.76
# i = 891 Random start result: 0.76
# i = 892 Random start result: 0.76
# i = 893 Random start result: 0.72
# i = 894 Random start result: 0.52
# i = 895 Random start result: 0.72
# i = 896 Random start result: 0.64
# i = 897 Random start result: 0.76
# i = 898 Random start result: 0.64
# i = 899 Random start result: 0.6000000000000001
# i = 900 Random start result: 0.76
# i = 901 Random start result: 0.6799999999999999
# i = 902 Random start result: 0.6799999999999999
# i = 903 Random start result: 0.44000000000000006
# i = 904 Random start result: 0.6799999999999999
# i = 905 Random start result: 0.6799999999999999
# i = 906 Random start result: 0.6799999999999999
# i = 907 Random start result: 0.6799999999999999
# i = 908 Random start result: 0.6000000000000001
# i = 909 Random start result: 0.6799999999999999
# i = 910 Random start result: 0.76
# i = 911 Random start result: 0.6000000000000001
# i = 912 Random start result: 0.76
# i = 913 Random start result: 0.6799999999999999
# i = 914 Random start result: 0.6799999999999999
# i = 915 Random start result: 0.72
# i = 916 Random start result: 0.6000000000000001
# i = 917 Random start result: 0.64
# i = 918 Random start result: 0.6799999999999999
# i = 919 Random start result: 0.72
# i = 920 Random start result: 0.64
# i = 921 Random start result: 0.64
# i = 922 Random start result: 0.64
# i = 923 Random start result: 0.76
# i = 924 Random start result: 0.72
# i = 925 Random start result: 0.72
# i = 926 Random start result: 0.56
# i = 927 Random start result: 0.72
# i = 928 Random start result: 0.64
# i = 929 Random start result: 0.6799999999999999
# i = 930 Random start result: 0.76
# i = 931 Random start result: 0.44000000000000006
# i = 932 Random start result: 0.6000000000000001
# i = 933 Random start result: 0.6000000000000001
# i = 934 Random start result: 0.76
# i = 935 Random start result: 0.76
# i = 936 Random start result: 0.64
# i = 937 Random start result: 0.72
# i = 938 Random start result: 0.72
# i = 939 Random start result: 0.76
# i = 940 Random start result: 0.6799999999999999
# i = 941 Random start result: 0.76
# i = 942 Random start result: 0.72
# i = 943 Random start result: 0.6799999999999999
# i = 944 Random start result: 0.6799999999999999
# i = 945 Random start result: 0.76
# i = 946 Random start result: 0.64
# i = 947 Random start result: 0.72
# i = 948 Random start result: 0.56
# i = 949 Random start result: 0.6000000000000001
# i = 950 Random start result: 0.6799999999999999
# i = 951 Random start result: 0.44000000000000006
# i = 952 Random start result: 0.76
# i = 953 Random start result: 0.76
# i = 954 Random start result: 0.6000000000000001
# i = 955 Random start result: 0.76
# i = 956 Random start result: 0.56
# i = 957 Random start result: 0.72
# i = 958 Random start result: 0.6799999999999999
# i = 959 Random start result: 0.6000000000000001
# i = 960 Random start result: 0.72
# i = 961 Random start result: 0.64
# i = 962 Random start result: 0.6000000000000001
# i = 963 Random start result: 0.76
# i = 964 Random start result: 0.6799999999999999
# i = 965 Random start result: 0.6799999999999999
# i = 966 Random start result: 0.76
# i = 967 Random start result: 0.76
# i = 968 Random start result: 0.6799999999999999
# i = 969 Random start result: 0.6000000000000001
# i = 970 Random start result: 0.56
# i = 971 Random start result: 0.76
# i = 972 Random start result: 0.72
# i = 973 Random start result: 0.4800000000000001
# i = 974 Random start result: 0.6799999999999999
# i = 975 Random start result: 0.72
# i = 976 Random start result: 0.6799999999999999
# i = 977 Random start result: 0.76
# i = 978 Random start result: 0.72
# i = 979 Random start result: 0.72
# i = 980 Random start result: 0.76
# i = 981 Random start result: 0.72
# i = 982 Random start result: 0.76
# i = 983 Random start result: 0.6000000000000001
# i = 984 Random start result: 0.76
# i = 985 Random start result: 0.6799999999999999
# i = 986 Random start result: 0.6799999999999999
# i = 987 Random start result: 0.72
# i = 988 Random start result: 0.6799999999999999
# i = 989 Random start result: 0.56
# i = 990 Random start result: 0.52
# i = 991 Random start result: 0.64
# i = 992 Random start result: 0.72
# i = 993 Random start result: 0.76
# i = 994 Random start result: 0.36
# i = 995 Random start result: 0.72
# i = 996 Random start result: 0.72
# i = 997 Random start result: 0.76
# i = 998 Random start result: 0.64
# i = 999 Random start result: 0.64
# max = 0.76
# min = -1.52
# mean = 0.6582
# std = 0.22862362082689533
# (0.76, -1.52, 0.6582)

# %% [markdown]
# ### Import the grid world map

# %%
# !gdown "1ijOW8crvoIs1soeelWaaSleIYM1Sn_tV"
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1ijOW8crvoIs1soeelWaaSleIYM1Sn_tV
# To: /content/world02.csv
# 100% 1.22k/1.22k [00:00<00:00, 5.61MB/s]

# %% [markdown]
# #### Print the Map

# %%
problem = GridWorld('/content/world02.csv', reward={0: -0.04, 1: 10.0, 2: -2.5, 3: np.NaN}, random_rate=0.2)
problem.plot_map(fig_size=(15, 8))

# %%
# Implement the policy iteration
# YOUR CODE HERE

solver = PolicyIteration(problem.reward_function, problem.transition_model, gamma=0.9, init_policy=None)
solver.train()

problem.visualize_value_policy(policy=solver.policy, values=solver.values)


mdp.random_start_policy(policy=solver.policy, start_pos=(2, 1), n=1000)
# Out:
# # epoch: 22
# eval count = [89, 44, 47, 39, 28, 23, 14, 11, 8, 18, 12, 19, 7, 14, 19, 3, 3, 3, 3, 2, 2, 2]
# policy change = [451, 208, 137, 99, 77, 65, 62, 51, 63, 98, 33, 3, 1, 74, 34, 25, 15, 12, 6, 2, 2, 0]
# <ipython-input-5-ece47fdee11e>:261: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()
# i = 0 Random start result: -1.16
# i = 1 Random start result: -1.28
# i = 2 Random start result: -2.120000000000002
# i = 3 Random start result: -0.24000000000000044
# i = 4 Random start result: 0.4800000000000001
# i = 5 Random start result: -0.28000000000000047
# i = 6 Random start result: 0.72
# i = 7 Random start result: -1.2
# i = 8 Random start result: -1.7200000000000015
# i = 9 Random start result: 0.72
# i = 10 Random start result: -2.320000000000002
# i = 11 Random start result: -0.48000000000000065
# i = 12 Random start result: 0.56
# i = 13 Random start result: -4.560000000000004
# i = 14 Random start result: -1.4
# i = 15 Random start result: -3.1200000000000028
# i = 16 Random start result: -0.36000000000000054
# i = 17 Random start result: -5.280000000000005
# i = 18 Random start result: 0.56
# i = 19 Random start result: -2.6800000000000024
# i = 20 Random start result: 0.8
# i = 21 Random start result: -0.04000000000000026
# i = 22 Random start result: -0.920000000000001
# i = 23 Random start result: 0.52
# i = 24 Random start result: -0.2000000000000004
# i = 25 Random start result: 0.4800000000000001
# i = 26 Random start result: -0.840000000000001
# i = 27 Random start result: -0.24000000000000044
# i = 28 Random start result: 0.76
# i = 29 Random start result: -3.360000000000001
# i = 30 Random start result: -0.04000000000000026
# i = 31 Random start result: -3.8400000000000016
# i = 32 Random start result: 0.64
# i = 33 Random start result: -5.1200000000000045
# i = 34 Random start result: 0.11999999999999977
# i = 35 Random start result: -5.120000000000003
# i = 36 Random start result: -1.7200000000000015
# i = 37 Random start result: 0.84
# i = 38 Random start result: -0.04000000000000026
# i = 39 Random start result: 0.4
# i = 40 Random start result: -3.000000000000001
# i = 41 Random start result: -1.4
# i = 42 Random start result: 0.2799999999999999
# i = 43 Random start result: 0.52
# i = 44 Random start result: 0.52
# i = 45 Random start result: 0.76
# i = 46 Random start result: -1.16
# i = 47 Random start result: -3.5200000000000014
# i = 48 Random start result: 0.52
# i = 49 Random start result: 0.56
# i = 50 Random start result: 0.64
# i = 51 Random start result: -0.48000000000000065
# i = 52 Random start result: -2.4000000000000004
# i = 53 Random start result: 0.56
# i = 54 Random start result: 0.56
# i = 55 Random start result: -3.600000000000003
# i = 56 Random start result: -3.280000000000003
# i = 57 Random start result: -1.12
# i = 58 Random start result: 0.84
# i = 59 Random start result: 0.6000000000000001
# i = 60 Random start result: 0.23999999999999988
# i = 61 Random start result: 0.8
# i = 62 Random start result: 0.2799999999999999
# i = 63 Random start result: 0.6000000000000001
# i = 64 Random start result: 0.6000000000000001
# i = 65 Random start result: -0.5200000000000007
# i = 66 Random start result: 0.84
# i = 67 Random start result: 0.76
# i = 68 Random start result: -1.28
# i = 69 Random start result: -1.3599999999999999
# i = 70 Random start result: 0.31999999999999995
# i = 71 Random start result: 0.07999999999999974
# i = 72 Random start result: -7.5999999999999925
# i = 73 Random start result: 0.52
# i = 74 Random start result: -0.920000000000001
# i = 75 Random start result: 0.19999999999999984
# i = 76 Random start result: 0.6799999999999999
# i = 77 Random start result: -0.2000000000000004
# i = 78 Random start result: -5.600000000000003
# i = 79 Random start result: 0.84
# i = 80 Random start result: 0.1599999999999998
# i = 81 Random start result: 0.76
# i = 82 Random start result: 0.8
# i = 83 Random start result: -3.280000000000003
# i = 84 Random start result: 0.84
# i = 85 Random start result: -12.119999999999896
# i = 86 Random start result: -0.7600000000000009
# i = 87 Random start result: 0.76
# i = 88 Random start result: 0.0399999999999997
# i = 89 Random start result: 0.8
# i = 90 Random start result: 0.76
# i = 91 Random start result: -0.28000000000000047
# i = 92 Random start result: 0.8
# i = 93 Random start result: 0.6799999999999999
# i = 94 Random start result: 0.72
# i = 95 Random start result: -1.7200000000000002
# i = 96 Random start result: -1.28
# i = 97 Random start result: -0.36000000000000054
# i = 98 Random start result: -0.880000000000001
# i = 99 Random start result: -3.320000000000003
# i = 100 Random start result: -2.320000000000002
# i = 101 Random start result: -3.000000000000001
# i = 102 Random start result: -0.12000000000000033
# i = 103 Random start result: -1.28
# i = 104 Random start result: 0.8
# i = 105 Random start result: -1.44
# i = 106 Random start result: -1.6400000000000015
# i = 107 Random start result: 0.56
# i = 108 Random start result: -2.2
# i = 109 Random start result: 0.8
# i = 110 Random start result: -0.8000000000000009
# i = 111 Random start result: 0.64
# i = 112 Random start result: 0.4
# i = 113 Random start result: -0.16000000000000036
# i = 114 Random start result: -0.0800000000000003
# i = 115 Random start result: 0.8
# i = 116 Random start result: -1.7200000000000015
# i = 117 Random start result: 0.84
# i = 118 Random start result: -1.6
# i = 119 Random start result: 0.64
# i = 120 Random start result: -1.12
# i = 121 Random start result: -1.040000000000001
# i = 122 Random start result: -5.320000000000003
# i = 123 Random start result: -3.9200000000000035
# i = 124 Random start result: 0.6799999999999999
# i = 125 Random start result: -1.3200000000000012
# i = 126 Random start result: 0.76
# i = 127 Random start result: 0.56
# i = 128 Random start result: -0.6000000000000008
# i = 129 Random start result: -1.16
# i = 130 Random start result: -1.0000000000000009
# i = 131 Random start result: -1.24
# i = 132 Random start result: -0.7200000000000009
# i = 133 Random start result: 0.72
# i = 134 Random start result: -1.2800000000000011
# i = 135 Random start result: -4.280000000000002
# i = 136 Random start result: -5.400000000000005
# i = 137 Random start result: -0.16000000000000036
# i = 138 Random start result: 0.19999999999999984
# i = 139 Random start result: 0.8
# i = 140 Random start result: 0.6799999999999999
# i = 141 Random start result: 0.84
# i = 142 Random start result: 0.31999999999999995
# i = 143 Random start result: -0.28000000000000047
# i = 144 Random start result: -1.44
# i = 145 Random start result: -2.920000000000001
# i = 146 Random start result: -0.880000000000001
# i = 147 Random start result: -1.9200000000000004
# i = 148 Random start result: -1.5600000000000014
# i = 149 Random start result: 0.4
# i = 150 Random start result: 0.84
# i = 151 Random start result: -7.3199999999999985
# i = 152 Random start result: 0.36
# i = 153 Random start result: 0.11999999999999977
# i = 154 Random start result: -1.3599999999999999
# i = 155 Random start result: -1.6800000000000015
# i = 156 Random start result: 0.72
# i = 157 Random start result: 0.84
# i = 158 Random start result: -10.199999999999937
# i = 159 Random start result: -1.12
# i = 160 Random start result: 0.6799999999999999
# i = 161 Random start result: 0.56
# i = 162 Random start result: -3.280000000000001
# i = 163 Random start result: 0.84
# i = 164 Random start result: -0.0800000000000003
# i = 165 Random start result: -1.4800000000000013
# i = 166 Random start result: -1.8800000000000017
# i = 167 Random start result: -2.8800000000000026
# i = 168 Random start result: -6.040000000000004
# i = 169 Random start result: -3.200000000000001
# i = 170 Random start result: 0.56
# i = 171 Random start result: 0.64
# i = 172 Random start result: 0.2799999999999999
# i = 173 Random start result: 0.72
# i = 174 Random start result: -1.080000000000001
# i = 175 Random start result: -2.6400000000000023
# i = 176 Random start result: -0.8000000000000009
# i = 177 Random start result: 0.6799999999999999
# i = 178 Random start result: 0.8
# i = 179 Random start result: -0.24000000000000044
# i = 180 Random start result: 0.64
# i = 181 Random start result: 0.6799999999999999
# i = 182 Random start result: -1.3600000000000012
# i = 183 Random start result: 0.6799999999999999
# i = 184 Random start result: -1.6
# i = 185 Random start result: -1.240000000000001
# i = 186 Random start result: -1.7200000000000002
# i = 187 Random start result: -2.320000000000002
# i = 188 Random start result: -1.4000000000000012
# i = 189 Random start result: 0.6799999999999999
# i = 190 Random start result: -2.5600000000000005
# i = 191 Random start result: 0.52
# i = 192 Random start result: 0.2799999999999999
# i = 193 Random start result: 0.4
# i = 194 Random start result: -1.9200000000000017
# i = 195 Random start result: -1.3599999999999999
# i = 196 Random start result: -1.56
# i = 197 Random start result: -1.2800000000000011
# i = 198 Random start result: -0.9600000000000011
# i = 199 Random start result: -1.240000000000001
# i = 200 Random start result: -1.44
# i = 201 Random start result: 0.52
# i = 202 Random start result: -0.880000000000001
# i = 203 Random start result: 0.84
# i = 204 Random start result: 0.72
# i = 205 Random start result: -1.8400000000000016
# i = 206 Random start result: -0.04000000000000026
# i = 207 Random start result: 0.6000000000000001
# i = 208 Random start result: -3.0800000000000027
# i = 209 Random start result: 0.44000000000000006
# i = 210 Random start result: -1.9200000000000017
# i = 211 Random start result: -0.5200000000000007
# i = 212 Random start result: -2.5200000000000005
# i = 213 Random start result: -1.16
# i = 214 Random start result: 0.8
# i = 215 Random start result: 0.52
# i = 216 Random start result: 0.56
# i = 217 Random start result: -1.12
# i = 218 Random start result: 0.64
# i = 219 Random start result: -2.6400000000000023
# i = 220 Random start result: 0.84
# i = 221 Random start result: -2.880000000000001
# i = 222 Random start result: 0.76
# i = 223 Random start result: 0.76
# i = 224 Random start result: -0.2000000000000004
# i = 225 Random start result: -3.560000000000003
# i = 226 Random start result: -2.04
# i = 227 Random start result: -3.360000000000001
# i = 228 Random start result: -1.16
# i = 229 Random start result: -1.160000000000001
# i = 230 Random start result: -0.04000000000000026
# i = 231 Random start result: -0.24000000000000044
# i = 232 Random start result: 0.76
# i = 233 Random start result: -1.6000000000000014
# i = 234 Random start result: 0.4
# i = 235 Random start result: -1.200000000000001
# i = 236 Random start result: 0.84
# i = 237 Random start result: -7.519999999999994
# i = 238 Random start result: 0.76
# i = 239 Random start result: -2.480000000000002
# i = 240 Random start result: -0.16000000000000036
# i = 241 Random start result: 0.64
# i = 242 Random start result: 0.0399999999999997
# i = 243 Random start result: -2.8000000000000007
# i = 244 Random start result: 0.19999999999999984
# i = 245 Random start result: -1.16
# i = 246 Random start result: 0.84
# i = 247 Random start result: -1.2800000000000011
# i = 248 Random start result: -2.120000000000002
# i = 249 Random start result: 0.76
# i = 250 Random start result: -3.240000000000003
# i = 251 Random start result: -0.6400000000000008
# i = 252 Random start result: 0.76
# i = 253 Random start result: 0.31999999999999995
# i = 254 Random start result: 0.8
# i = 255 Random start result: 0.8
# i = 256 Random start result: 0.44000000000000006
# i = 257 Random start result: 0.84
# i = 258 Random start result: 0.4800000000000001
# i = 259 Random start result: -1.28
# i = 260 Random start result: 0.0399999999999997
# i = 261 Random start result: -0.12000000000000033
# i = 262 Random start result: -0.0800000000000003
# i = 263 Random start result: 0.56
# i = 264 Random start result: -0.7200000000000009
# i = 265 Random start result: 0.76
# i = 266 Random start result: -3.4400000000000013
# i = 267 Random start result: 0.72
# i = 268 Random start result: -0.6800000000000008
# i = 269 Random start result: 0.64
# i = 270 Random start result: 0.76
# i = 271 Random start result: 0.44000000000000006
# i = 272 Random start result: 0.0399999999999997
# i = 273 Random start result: -0.4400000000000006
# i = 274 Random start result: -4.040000000000004
# i = 275 Random start result: 0.4
# i = 276 Random start result: -0.36000000000000054
# i = 277 Random start result: -1.080000000000001
# i = 278 Random start result: -4.960000000000004
# i = 279 Random start result: 0.31999999999999995
# i = 280 Random start result: -1.16
# i = 281 Random start result: 0.72
# i = 282 Random start result: -1.5600000000000014
# i = 283 Random start result: -0.24000000000000044
# i = 284 Random start result: 0.76
# i = 285 Random start result: 0.11999999999999977
# i = 286 Random start result: -0.5600000000000007
# i = 287 Random start result: -0.36000000000000054
# i = 288 Random start result: -2.320000000000002
# i = 289 Random start result: -3.440000000000003
# i = 290 Random start result: 0.76
# i = 291 Random start result: -7.399999999999997
# i = 292 Random start result: -1.24
# i = 293 Random start result: 0.6000000000000001
# i = 294 Random start result: -1.160000000000001
# i = 295 Random start result: -0.04000000000000026
# i = 296 Random start result: 0.4
# i = 297 Random start result: 0.84
# i = 298 Random start result: 0.6799999999999999
# i = 299 Random start result: -3.320000000000001
# i = 300 Random start result: 0.6799999999999999
# i = 301 Random start result: -1.12
# i = 302 Random start result: 0.76
# i = 303 Random start result: 0.6799999999999999
# i = 304 Random start result: -2.08
# i = 305 Random start result: 0.72
# i = 306 Random start result: 0.4
# i = 307 Random start result: -5.360000000000005
# i = 308 Random start result: 0.23999999999999988
# i = 309 Random start result: -1.4
# i = 310 Random start result: -3.320000000000003
# i = 311 Random start result: -0.04000000000000026
# i = 312 Random start result: 0.8
# i = 313 Random start result: 0.31999999999999995
# i = 314 Random start result: -0.5200000000000007
# i = 315 Random start result: 0.84
# i = 316 Random start result: 0.6799999999999999
# i = 317 Random start result: -0.2000000000000004
# i = 318 Random start result: -1.12
# i = 319 Random start result: -1.6000000000000014
# i = 320 Random start result: -2.6000000000000023
# i = 321 Random start result: 0.72
# i = 322 Random start result: 0.76
# i = 323 Random start result: -0.4400000000000006
# i = 324 Random start result: -1.8400000000000003
# i = 325 Random start result: 0.8
# i = 326 Random start result: 0.4
# i = 327 Random start result: -4.120000000000004
# i = 328 Random start result: -0.840000000000001
# i = 329 Random start result: -0.48000000000000065
# i = 330 Random start result: -0.2000000000000004
# i = 331 Random start result: -1.4000000000000012
# i = 332 Random start result: 0.36
# i = 333 Random start result: -0.9600000000000011
# i = 334 Random start result: -1.9600000000000017
# i = 335 Random start result: -0.0800000000000003
# i = 336 Random start result: 0.4800000000000001
# i = 337 Random start result: -1.6
# i = 338 Random start result: 0.8
# i = 339 Random start result: -0.7600000000000009
# i = 340 Random start result: -0.36000000000000054
# i = 341 Random start result: -5.000000000000003
# i = 342 Random start result: -1.4000000000000012
# i = 343 Random start result: -4.280000000000004
# i = 344 Random start result: -1.2
# i = 345 Random start result: 0.8
# i = 346 Random start result: 0.72
# i = 347 Random start result: -1.7200000000000015
# i = 348 Random start result: -1.3200000000000012
# i = 349 Random start result: 0.19999999999999984
# i = 350 Random start result: -1.8000000000000016
# i = 351 Random start result: 0.52
# i = 352 Random start result: -6.360000000000004
# i = 353 Random start result: 0.1599999999999998
# i = 354 Random start result: 0.76
# i = 355 Random start result: 0.64
# i = 356 Random start result: 0.6799999999999999
# i = 357 Random start result: 0.2799999999999999
# i = 358 Random start result: -1.4
# i = 359 Random start result: 0.8
# i = 360 Random start result: 0.4800000000000001
# i = 361 Random start result: -1.160000000000001
# i = 362 Random start result: 0.8
# i = 363 Random start result: 0.52
# i = 364 Random start result: -0.4000000000000006
# i = 365 Random start result: 0.84
# i = 366 Random start result: 0.6000000000000001
# i = 367 Random start result: 0.84
# i = 368 Random start result: 0.8
# i = 369 Random start result: 0.84
# i = 370 Random start result: -0.920000000000001
# i = 371 Random start result: 0.52
# i = 372 Random start result: 0.6799999999999999
# i = 373 Random start result: 0.19999999999999984
# i = 374 Random start result: -0.4000000000000006
# i = 375 Random start result: 0.76
# i = 376 Random start result: 0.64
# i = 377 Random start result: 0.52
# i = 378 Random start result: -1.16
# i = 379 Random start result: -3.320000000000001
# i = 380 Random start result: 0.8
# i = 381 Random start result: 0.84
# i = 382 Random start result: 0.36
# i = 383 Random start result: 0.84
# i = 384 Random start result: -1.3599999999999999
# i = 385 Random start result: -6.440000000000004
# i = 386 Random start result: 0.72
# i = 387 Random start result: 0.52
# i = 388 Random start result: 0.84
# i = 389 Random start result: -16.079999999999856
# i = 390 Random start result: -1.48
# i = 391 Random start result: 0.64
# i = 392 Random start result: 0.31999999999999995
# i = 393 Random start result: 0.72
# i = 394 Random start result: -4.280000000000004
# i = 395 Random start result: 0.84
# i = 396 Random start result: -0.7200000000000009
# i = 397 Random start result: -0.6800000000000008
# i = 398 Random start result: 0.8
# i = 399 Random start result: 0.72
# i = 400 Random start result: 0.6799999999999999
# i = 401 Random start result: -2.4000000000000004
# i = 402 Random start result: 0.8
# i = 403 Random start result: -0.920000000000001
# i = 404 Random start result: 0.84
# i = 405 Random start result: -1.6400000000000001
# i = 406 Random start result: -1.7200000000000015
# i = 407 Random start result: -0.24000000000000044
# i = 408 Random start result: 0.76
# i = 409 Random start result: 0.8
# i = 410 Random start result: -0.920000000000001
# i = 411 Random start result: -3.200000000000003
# i = 412 Random start result: 0.52
# i = 413 Random start result: 0.52
# i = 414 Random start result: -5.000000000000003
# i = 415 Random start result: -1.3599999999999999
# i = 416 Random start result: -1.8800000000000003
# i = 417 Random start result: -0.6400000000000008
# i = 418 Random start result: -1.4400000000000013
# i = 419 Random start result: -1.2
# i = 420 Random start result: 0.1599999999999998
# i = 421 Random start result: -1.8800000000000003
# i = 422 Random start result: -2.8400000000000007
# i = 423 Random start result: 0.6799999999999999
# i = 424 Random start result: 0.8
# i = 425 Random start result: 0.76
# i = 426 Random start result: -0.28000000000000047
# i = 427 Random start result: 0.36
# i = 428 Random start result: -0.28000000000000047
# i = 429 Random start result: -2.7200000000000024
# i = 430 Random start result: 0.76
# i = 431 Random start result: -7.679999999999991
# i = 432 Random start result: -4.000000000000002
# i = 433 Random start result: -9.59999999999995
# i = 434 Random start result: -1.4800000000000013
# i = 435 Random start result: 0.84
# i = 436 Random start result: -3.5200000000000014
# i = 437 Random start result: 0.76
# i = 438 Random start result: 0.76
# i = 439 Random start result: -0.3200000000000005
# i = 440 Random start result: 0.6000000000000001
# i = 441 Random start result: -2.6000000000000005
# i = 442 Random start result: 0.56
# i = 443 Random start result: -0.04000000000000026
# i = 444 Random start result: 0.4800000000000001
# i = 445 Random start result: -2.480000000000002
# i = 446 Random start result: -2.2800000000000002
# i = 447 Random start result: 0.84
# i = 448 Random start result: 0.84
# i = 449 Random start result: -1.5600000000000014
# i = 450 Random start result: -4.960000000000003
# i = 451 Random start result: -3.560000000000003
# i = 452 Random start result: 0.36
# i = 453 Random start result: -6.000000000000005
# i = 454 Random start result: -0.36000000000000054
# i = 455 Random start result: -3.0000000000000027
# i = 456 Random start result: 0.8
# i = 457 Random start result: 0.4
# i = 458 Random start result: 0.8
# i = 459 Random start result: -2.8000000000000025
# i = 460 Random start result: 0.8
# i = 461 Random start result: 0.31999999999999995
# i = 462 Random start result: 0.6799999999999999
# i = 463 Random start result: 0.84
# i = 464 Random start result: 0.36
# i = 465 Random start result: 0.64
# i = 466 Random start result: -1.4000000000000012
# i = 467 Random start result: 0.84
# i = 468 Random start result: -3.9600000000000035
# i = 469 Random start result: -4.800000000000004
# i = 470 Random start result: -0.04000000000000026
# i = 471 Random start result: -0.12000000000000033
# i = 472 Random start result: 0.36
# i = 473 Random start result: -1.8800000000000003
# i = 474 Random start result: -2.0
# i = 475 Random start result: 0.6799999999999999
# i = 476 Random start result: 0.64
# i = 477 Random start result: -1.040000000000001
# i = 478 Random start result: -1.5600000000000014
# i = 479 Random start result: -1.5600000000000014
# i = 480 Random start result: -5.280000000000005
# i = 481 Random start result: -1.080000000000001
# i = 482 Random start result: 0.76
# i = 483 Random start result: 0.84
# i = 484 Random start result: -2.280000000000002
# i = 485 Random start result: 0.2799999999999999
# i = 486 Random start result: -5.480000000000005
# i = 487 Random start result: 0.8
# i = 488 Random start result: 0.64
# i = 489 Random start result: -0.16000000000000036
# i = 490 Random start result: 0.56
# i = 491 Random start result: 0.1599999999999998
# i = 492 Random start result: -1.8400000000000003
# i = 493 Random start result: 0.56
# i = 494 Random start result: 0.84
# i = 495 Random start result: -2.220446049250313e-16
# i = 496 Random start result: -1.2800000000000011
# i = 497 Random start result: -6.440000000000004
# i = 498 Random start result: -1.6
# i = 499 Random start result: -1.32
# i = 500 Random start result: -4.080000000000004
# i = 501 Random start result: 0.8
# i = 502 Random start result: 0.4800000000000001
# i = 503 Random start result: -2.5600000000000005
# i = 504 Random start result: -1.2
# i = 505 Random start result: 0.84
# i = 506 Random start result: 0.84
# i = 507 Random start result: 0.52
# i = 508 Random start result: -2.400000000000002
# i = 509 Random start result: -1.8800000000000017
# i = 510 Random start result: -7.3199999999999985
# i = 511 Random start result: 0.84
# i = 512 Random start result: -1.240000000000001
# i = 513 Random start result: -1.24
# i = 514 Random start result: -2.360000000000002
# i = 515 Random start result: -5.160000000000003
# i = 516 Random start result: 0.6000000000000001
# i = 517 Random start result: -3.440000000000003
# i = 518 Random start result: 0.56
# i = 519 Random start result: 0.8
# i = 520 Random start result: 0.84
# i = 521 Random start result: -0.12000000000000033
# i = 522 Random start result: -1.6400000000000001
# i = 523 Random start result: 0.8
# i = 524 Random start result: -2.0000000000000018
# i = 525 Random start result: 0.56
# i = 526 Random start result: -3.200000000000003
# i = 527 Random start result: 0.44000000000000006
# i = 528 Random start result: -2.7600000000000007
# i = 529 Random start result: -0.36000000000000054
# i = 530 Random start result: 0.07999999999999974
# i = 531 Random start result: -0.880000000000001
# i = 532 Random start result: 0.52
# i = 533 Random start result: -0.36000000000000054
# i = 534 Random start result: 0.6000000000000001
# i = 535 Random start result: 0.31999999999999995
# i = 536 Random start result: -1.44
# i = 537 Random start result: 0.31999999999999995
# i = 538 Random start result: 0.31999999999999995
# i = 539 Random start result: -2.480000000000002
# i = 540 Random start result: 0.72
# i = 541 Random start result: -1.2
# i = 542 Random start result: 0.64
# i = 543 Random start result: 0.76
# i = 544 Random start result: -1.8800000000000003
# i = 545 Random start result: 0.72
# i = 546 Random start result: -4.160000000000004
# i = 547 Random start result: -1.12
# i = 548 Random start result: -2.320000000000002
# i = 549 Random start result: 0.76
# i = 550 Random start result: 0.8
# i = 551 Random start result: -5.280000000000003
# i = 552 Random start result: -2.440000000000002
# i = 553 Random start result: 0.6000000000000001
# i = 554 Random start result: 0.72
# i = 555 Random start result: 0.8
# i = 556 Random start result: -1.200000000000001
# i = 557 Random start result: 0.19999999999999984
# i = 558 Random start result: -1.2
# i = 559 Random start result: -1.2
# i = 560 Random start result: 0.07999999999999974
# i = 561 Random start result: -0.16000000000000036
# i = 562 Random start result: 0.07999999999999974
# i = 563 Random start result: 0.8
# i = 564 Random start result: -0.24000000000000044
# i = 565 Random start result: -1.2
# i = 566 Random start result: 0.56
# i = 567 Random start result: -0.16000000000000036
# i = 568 Random start result: -2.440000000000002
# i = 569 Random start result: 0.6799999999999999
# i = 570 Random start result: -1.080000000000001
# i = 571 Random start result: 0.52
# i = 572 Random start result: 0.6799999999999999
# i = 573 Random start result: 0.6799999999999999
# i = 574 Random start result: 0.1599999999999998
# i = 575 Random start result: -7.160000000000002
# i = 576 Random start result: -1.4
# i = 577 Random start result: 0.4
# i = 578 Random start result: -0.3200000000000005
# i = 579 Random start result: -4.640000000000002
# i = 580 Random start result: 0.76
# i = 581 Random start result: 0.52
# i = 582 Random start result: -1.4400000000000013
# i = 583 Random start result: -1.2
# i = 584 Random start result: -2.480000000000002
# i = 585 Random start result: -1.16
# i = 586 Random start result: 0.8
# i = 587 Random start result: 0.6000000000000001
# i = 588 Random start result: 0.56
# i = 589 Random start result: 0.11999999999999977
# i = 590 Random start result: -1.7200000000000002
# i = 591 Random start result: 0.64
# i = 592 Random start result: -0.840000000000001
# i = 593 Random start result: 0.44000000000000006
# i = 594 Random start result: 0.76
# i = 595 Random start result: 0.36
# i = 596 Random start result: 0.4800000000000001
# i = 597 Random start result: 0.76
# i = 598 Random start result: 0.4
# i = 599 Random start result: 0.11999999999999977
# i = 600 Random start result: -1.3599999999999999
# i = 601 Random start result: 0.64
# i = 602 Random start result: 0.44000000000000006
# i = 603 Random start result: -4.160000000000004
# i = 604 Random start result: 0.31999999999999995
# i = 605 Random start result: -1.9200000000000004
# i = 606 Random start result: 0.72
# i = 607 Random start result: 0.76
# i = 608 Random start result: -5.080000000000003
# i = 609 Random start result: -3.160000000000003
# i = 610 Random start result: -1.080000000000001
# i = 611 Random start result: -4.240000000000004
# i = 612 Random start result: -8.919999999999964
# i = 613 Random start result: 0.84
# i = 614 Random start result: 0.8
# i = 615 Random start result: -11.279999999999957
# i = 616 Random start result: 0.8
# i = 617 Random start result: 0.76
# i = 618 Random start result: -4.360000000000004
# i = 619 Random start result: 0.64
# i = 620 Random start result: -1.8800000000000003
# i = 621 Random start result: 0.8
# i = 622 Random start result: 0.8
# i = 623 Random start result: -1.2
# i = 624 Random start result: -1.8800000000000003
# i = 625 Random start result: 0.07999999999999974
# i = 626 Random start result: 0.56
# i = 627 Random start result: 0.6000000000000001
# i = 628 Random start result: -0.920000000000001
# i = 629 Random start result: 0.36
# i = 630 Random start result: -0.6400000000000008
# i = 631 Random start result: -1.28
# i = 632 Random start result: 0.6799999999999999
# i = 633 Random start result: -2.9200000000000026
# i = 634 Random start result: -1.5200000000000014
# i = 635 Random start result: 0.72
# i = 636 Random start result: -1.24
# i = 637 Random start result: 0.72
# i = 638 Random start result: -4.0000000000000036
# i = 639 Random start result: -2.04
# i = 640 Random start result: -1.6000000000000014
# i = 641 Random start result: -0.6400000000000008
# i = 642 Random start result: -0.4000000000000006
# i = 643 Random start result: -4.640000000000002
# i = 644 Random start result: 0.6000000000000001
# i = 645 Random start result: -6.720000000000004
# i = 646 Random start result: -4.600000000000004
# i = 647 Random start result: -0.3200000000000005
# i = 648 Random start result: -0.840000000000001
# i = 649 Random start result: -1.32
# i = 650 Random start result: 0.36
# i = 651 Random start result: 0.19999999999999984
# i = 652 Random start result: -3.8800000000000034
# i = 653 Random start result: -2.2800000000000002
# i = 654 Random start result: -2.120000000000002
# i = 655 Random start result: 0.8
# i = 656 Random start result: -6.640000000000004
# i = 657 Random start result: -2.220446049250313e-16
# i = 658 Random start result: -3.7600000000000016
# i = 659 Random start result: 0.64
# i = 660 Random start result: 0.6799999999999999
# i = 661 Random start result: -1.12
# i = 662 Random start result: 0.8
# i = 663 Random start result: 0.8
# i = 664 Random start result: -8.440000000000005
# i = 665 Random start result: -1.6800000000000015
# i = 666 Random start result: -1.44
# i = 667 Random start result: -2.6800000000000024
# i = 668 Random start result: 0.23999999999999988
# i = 669 Random start result: -2.880000000000001
# i = 670 Random start result: -6.960000000000006
# i = 671 Random start result: -4.760000000000004
# i = 672 Random start result: -4.720000000000002
# i = 673 Random start result: 0.6000000000000001
# i = 674 Random start result: -1.040000000000001
# i = 675 Random start result: 0.56
# i = 676 Random start result: 0.6799999999999999
# i = 677 Random start result: 0.0399999999999997
# i = 678 Random start result: 0.8
# i = 679 Random start result: 0.76
# i = 680 Random start result: 0.8
# i = 681 Random start result: 0.84
# i = 682 Random start result: 0.52
# i = 683 Random start result: -2.220446049250313e-16
# i = 684 Random start result: -1.5600000000000014
# i = 685 Random start result: -2.3600000000000003
# i = 686 Random start result: 0.72
# i = 687 Random start result: 0.6000000000000001
# i = 688 Random start result: -0.4000000000000006
# i = 689 Random start result: -5.400000000000005
# i = 690 Random start result: 0.31999999999999995
# i = 691 Random start result: 0.4800000000000001
# i = 692 Random start result: -0.5200000000000007
# i = 693 Random start result: -0.840000000000001
# i = 694 Random start result: 0.72
# i = 695 Random start result: 0.84
# i = 696 Random start result: -4.400000000000002
# i = 697 Random start result: 0.76
# i = 698 Random start result: -2.9200000000000026
# i = 699 Random start result: 0.8
# i = 700 Random start result: -2.7600000000000007
# i = 701 Random start result: -2.8800000000000026
# i = 702 Random start result: 0.72
# i = 703 Random start result: -1.8000000000000016
# i = 704 Random start result: -0.04000000000000026
# i = 705 Random start result: -0.5200000000000007
# i = 706 Random start result: -0.840000000000001
# i = 707 Random start result: -1.48
# i = 708 Random start result: -1.44
# i = 709 Random start result: -4.720000000000002
# i = 710 Random start result: -1.16
# i = 711 Random start result: 0.64
# i = 712 Random start result: -4.120000000000004
# i = 713 Random start result: -0.16000000000000036
# i = 714 Random start result: -0.24000000000000044
# i = 715 Random start result: 0.31999999999999995
# i = 716 Random start result: 0.84
# i = 717 Random start result: -1.6800000000000015
# i = 718 Random start result: 0.23999999999999988
# i = 719 Random start result: 0.76
# i = 720 Random start result: 0.72
# i = 721 Random start result: 0.4
# i = 722 Random start result: 0.56
# i = 723 Random start result: 0.84
# i = 724 Random start result: -1.28
# i = 725 Random start result: -3.4400000000000013
# i = 726 Random start result: 0.52
# i = 727 Random start result: -0.4000000000000006
# i = 728 Random start result: 0.84
# i = 729 Random start result: 0.84
# i = 730 Random start result: -9.959999999999985
# i = 731 Random start result: 0.4
# i = 732 Random start result: 0.84
# i = 733 Random start result: -1.12
# i = 734 Random start result: -2.24
# i = 735 Random start result: -1.8800000000000017
# i = 736 Random start result: 0.6799999999999999
# i = 737 Random start result: -4.760000000000004
# i = 738 Random start result: -2.480000000000002
# i = 739 Random start result: -1.16
# i = 740 Random start result: 0.36
# i = 741 Random start result: -2.320000000000002
# i = 742 Random start result: -1.32
# i = 743 Random start result: -2.2800000000000002
# i = 744 Random start result: -0.7600000000000009
# i = 745 Random start result: -2.0
# i = 746 Random start result: 0.8
# i = 747 Random start result: 0.6000000000000001
# i = 748 Random start result: -2.920000000000001
# i = 749 Random start result: -2.8000000000000007
# i = 750 Random start result: 0.76
# i = 751 Random start result: -8.879999999999965
# i = 752 Random start result: 0.8
# i = 753 Random start result: -1.6800000000000015
# i = 754 Random start result: -1.3599999999999999
# i = 755 Random start result: -1.7600000000000002
# i = 756 Random start result: -8.839999999999966
# i = 757 Random start result: -1.4
# i = 758 Random start result: -3.440000000000003
# i = 759 Random start result: 0.4
# i = 760 Random start result: -1.9200000000000017
# i = 761 Random start result: -6.040000000000004
# i = 762 Random start result: -1.16
# i = 763 Random start result: -0.6800000000000008
# i = 764 Random start result: 0.8
# i = 765 Random start result: -1.56
# i = 766 Random start result: 0.76
# i = 767 Random start result: 0.76
# i = 768 Random start result: -7.680000000000005
# i = 769 Random start result: -0.12000000000000033
# i = 770 Random start result: 0.52
# i = 771 Random start result: 0.1599999999999998
# i = 772 Random start result: 0.6000000000000001
# i = 773 Random start result: -1.4800000000000013
# i = 774 Random start result: 0.72
# i = 775 Random start result: 0.8
# i = 776 Random start result: -4.080000000000004
# i = 777 Random start result: 0.64
# i = 778 Random start result: -3.600000000000003
# i = 779 Random start result: 0.52
# i = 780 Random start result: 0.72
# i = 781 Random start result: -0.6000000000000008
# i = 782 Random start result: -0.24000000000000044
# i = 783 Random start result: -1.16
# i = 784 Random start result: -0.6000000000000008
# i = 785 Random start result: -0.3200000000000005
# i = 786 Random start result: -5.000000000000003
# i = 787 Random start result: -4.400000000000004
# i = 788 Random start result: -1.32
# i = 789 Random start result: -1.4800000000000013
# i = 790 Random start result: -1.7200000000000015
# i = 791 Random start result: -2.4800000000000004
# i = 792 Random start result: -1.4
# i = 793 Random start result: -1.120000000000001
# i = 794 Random start result: 0.36
# i = 795 Random start result: -1.4000000000000012
# i = 796 Random start result: -5.600000000000005
# i = 797 Random start result: -0.0800000000000003
# i = 798 Random start result: 0.76
# i = 799 Random start result: -5.560000000000005
# i = 800 Random start result: -1.080000000000001
# i = 801 Random start result: -1.16
# i = 802 Random start result: 0.84
# i = 803 Random start result: -2.3200000000000003
# i = 804 Random start result: 0.19999999999999984
# i = 805 Random start result: 0.52
# i = 806 Random start result: -1.24
# i = 807 Random start result: -3.4800000000000013
# i = 808 Random start result: 0.76
# i = 809 Random start result: 0.31999999999999995
# i = 810 Random start result: 0.84
# i = 811 Random start result: 0.23999999999999988
# i = 812 Random start result: -1.4800000000000013
# i = 813 Random start result: 0.6799999999999999
# i = 814 Random start result: -0.0800000000000003
# i = 815 Random start result: -1.44
# i = 816 Random start result: 0.6000000000000001
# i = 817 Random start result: -1.2800000000000011
# i = 818 Random start result: -1.5600000000000014
# i = 819 Random start result: 0.4
# i = 820 Random start result: -1.12
# i = 821 Random start result: -5.640000000000005
# i = 822 Random start result: -1.8400000000000016
# i = 823 Random start result: -1.080000000000001
# i = 824 Random start result: 0.76
# i = 825 Random start result: -1.48
# i = 826 Random start result: 0.76
# i = 827 Random start result: -0.4400000000000006
# i = 828 Random start result: 0.4800000000000001
# i = 829 Random start result: -2.200000000000002
# i = 830 Random start result: 0.0399999999999997
# i = 831 Random start result: -1.28
# i = 832 Random start result: -0.880000000000001
# i = 833 Random start result: 0.76
# i = 834 Random start result: 0.8
# i = 835 Random start result: -1.040000000000001
# i = 836 Random start result: -3.240000000000001
# i = 837 Random start result: 0.8
# i = 838 Random start result: -2.8800000000000026
# i = 839 Random start result: -1.5200000000000014
# i = 840 Random start result: -3.240000000000003
# i = 841 Random start result: 0.6799999999999999
# i = 842 Random start result: 0.6799999999999999
# i = 843 Random start result: 0.64
# i = 844 Random start result: -1.2800000000000011
# i = 845 Random start result: -0.880000000000001
# i = 846 Random start result: -2.6400000000000023
# i = 847 Random start result: 0.2799999999999999
# i = 848 Random start result: 0.6799999999999999
# i = 849 Random start result: 0.44000000000000006
# i = 850 Random start result: 0.31999999999999995
# i = 851 Random start result: 0.64
# i = 852 Random start result: -3.0400000000000027
# i = 853 Random start result: -3.000000000000001
# i = 854 Random start result: -4.120000000000002
# i = 855 Random start result: -0.6400000000000008
# i = 856 Random start result: 0.84
# i = 857 Random start result: 0.72
# i = 858 Random start result: 0.23999999999999988
# i = 859 Random start result: 0.76
# i = 860 Random start result: 0.44000000000000006
# i = 861 Random start result: -2.04
# i = 862 Random start result: -4.640000000000004
# i = 863 Random start result: -5.280000000000005
# i = 864 Random start result: 0.76
# i = 865 Random start result: -5.720000000000005
# i = 866 Random start result: 0.56
# i = 867 Random start result: -1.24
# i = 868 Random start result: -3.7600000000000033
# i = 869 Random start result: -7.1200000000000045
# i = 870 Random start result: -0.24000000000000044
# i = 871 Random start result: 0.8
# i = 872 Random start result: 0.6799999999999999
# i = 873 Random start result: 0.72
# i = 874 Random start result: -1.28
# i = 875 Random start result: -0.16000000000000036
# i = 876 Random start result: 0.6799999999999999
# i = 877 Random start result: 0.44000000000000006
# i = 878 Random start result: 0.64
# i = 879 Random start result: 0.76
# i = 880 Random start result: -2.5600000000000005
# i = 881 Random start result: -1.7200000000000015
# i = 882 Random start result: 0.2799999999999999
# i = 883 Random start result: -1.6000000000000014
# i = 884 Random start result: 0.84
# i = 885 Random start result: 0.07999999999999974
# i = 886 Random start result: -1.32
# i = 887 Random start result: -5.320000000000003
# i = 888 Random start result: 0.2799999999999999
# i = 889 Random start result: -1.24
# i = 890 Random start result: -3.160000000000001
# i = 891 Random start result: -0.5600000000000007
# i = 892 Random start result: -0.0800000000000003
# i = 893 Random start result: 0.6799999999999999
# i = 894 Random start result: -1.32
# i = 895 Random start result: 0.76
# i = 896 Random start result: 0.8
# i = 897 Random start result: 0.6799999999999999
# i = 898 Random start result: 0.8
# i = 899 Random start result: -0.4000000000000006
# i = 900 Random start result: -3.440000000000003
# i = 901 Random start result: -5.600000000000005
# i = 902 Random start result: 0.6799999999999999
# i = 903 Random start result: 0.6000000000000001
# i = 904 Random start result: 0.2799999999999999
# i = 905 Random start result: -4.040000000000004
# i = 906 Random start result: 0.31999999999999995
# i = 907 Random start result: 0.6799999999999999
# i = 908 Random start result: 0.6799999999999999
# i = 909 Random start result: 0.84
# i = 910 Random start result: -1.4400000000000013
# i = 911 Random start result: -1.3200000000000012
# i = 912 Random start result: 0.56
# i = 913 Random start result: -1.28
# i = 914 Random start result: 0.72
# i = 915 Random start result: 0.2799999999999999
# i = 916 Random start result: -2.400000000000002
# i = 917 Random start result: -1.0000000000000009
# i = 918 Random start result: -1.4000000000000012
# i = 919 Random start result: 0.52
# i = 920 Random start result: -5.200000000000005
# i = 921 Random start result: -0.16000000000000036
# i = 922 Random start result: -1.24
# i = 923 Random start result: 0.6799999999999999
# i = 924 Random start result: 0.76
# i = 925 Random start result: -2.8800000000000026
# i = 926 Random start result: -1.2
# i = 927 Random start result: 0.84
# i = 928 Random start result: -2.2800000000000002
# i = 929 Random start result: 0.6799999999999999
# i = 930 Random start result: -1.7200000000000002
# i = 931 Random start result: -1.3600000000000012
# i = 932 Random start result: -1.3599999999999999
# i = 933 Random start result: 0.72
# i = 934 Random start result: 0.84
# i = 935 Random start result: -0.7200000000000009
# i = 936 Random start result: 0.31999999999999995
# i = 937 Random start result: -0.4000000000000006
# i = 938 Random start result: -0.7600000000000009
# i = 939 Random start result: -0.6800000000000008
# i = 940 Random start result: -0.920000000000001
# i = 941 Random start result: 0.07999999999999974
# i = 942 Random start result: 0.6000000000000001
# i = 943 Random start result: 0.6799999999999999
# i = 944 Random start result: -2.280000000000002
# i = 945 Random start result: 0.8
# i = 946 Random start result: -5.520000000000003
# i = 947 Random start result: -2.8400000000000025
# i = 948 Random start result: 0.52
# i = 949 Random start result: -1.48
# i = 950 Random start result: -0.24000000000000044
# i = 951 Random start result: 0.64
# i = 952 Random start result: 0.23999999999999988
# i = 953 Random start result: 0.76
# i = 954 Random start result: -1.44
# i = 955 Random start result: -0.880000000000001
# i = 956 Random start result: 0.8
# i = 957 Random start result: -2.480000000000002
# i = 958 Random start result: 0.56
# i = 959 Random start result: 0.84
# i = 960 Random start result: -3.240000000000003
# i = 961 Random start result: -0.04000000000000026
# i = 962 Random start result: 0.76
# i = 963 Random start result: -3.400000000000003
# i = 964 Random start result: 0.4800000000000001
# i = 965 Random start result: -0.2000000000000004
# i = 966 Random start result: 0.76
# i = 967 Random start result: 0.4800000000000001
# i = 968 Random start result: 0.11999999999999977
# i = 969 Random start result: -0.5200000000000007
# i = 970 Random start result: 0.64
# i = 971 Random start result: -1.16
# i = 972 Random start result: -2.220446049250313e-16
# i = 973 Random start result: 0.2799999999999999
# i = 974 Random start result: 0.6000000000000001
# i = 975 Random start result: -2.12
# i = 976 Random start result: 0.8
# i = 977 Random start result: -4.000000000000002
# i = 978 Random start result: 0.52
# i = 979 Random start result: 0.8
# i = 980 Random start result: -0.48000000000000065
# i = 981 Random start result: 0.8
# i = 982 Random start result: 0.56
# i = 983 Random start result: -2.6000000000000005
# i = 984 Random start result: -1.080000000000001
# i = 985 Random start result: -3.080000000000001
# i = 986 Random start result: -1.4
# i = 987 Random start result: 0.84
# i = 988 Random start result: 0.76
# i = 989 Random start result: 0.23999999999999988
# i = 990 Random start result: -1.16
# i = 991 Random start result: -4.360000000000002
# i = 992 Random start result: 0.8
# i = 993 Random start result: 0.8
# i = 994 Random start result: -2.4800000000000004
# i = 995 Random start result: 0.36
# i = 996 Random start result: -2.7200000000000024
# i = 997 Random start result: -2.6000000000000023
# i = 998 Random start result: 0.8
# i = 999 Random start result: -3.0000000000000027
# max = 0.84
# min = -16.079999999999856
# mean = -0.8998400000000001
# std = 2.0364439531693455
# (0.84, -16.079999999999856, -0.8998400000000001)

# %% [markdown]
# ### Please answer the questions below to complete the experiment:

# %%
# @title Which of the following is the goal of reinforcement learning?  { run: "auto", form-width: "500px", display-mode: "form" }
Answer = "To learn a policy that maximizes the expected reward." #@param ["","To learn a policy that maximizes the expected reward.","To learn a value function that estimates the expected cost from each state", "To learn a policy that minimizes the expected cost","To learn a policy that minimizes the expected reward"]

# %%
#@title How was the experiment? { run: "auto", form-width: "500px", display-mode: "form" }
Complexity = "Good and Challenging for me" #@param ["","Too Simple, I am wasting time", "Good, But Not Challenging for me", "Good and Challenging for me", "Was Tough, but I did it", "Too Difficult for me"]

# %%
#@title If it was too easy, what more would you have liked to be added? If it was very difficult, what would you have liked to have been removed? { run: "auto", display-mode: "form" }
Additional = "Good and challenging" #@param {type:"string"}

# %%
#@title Can you identify the concepts from the lecture which this experiment covered? { run: "auto", vertical-output: true, display-mode: "form" }
Concepts = "Yes" #@param ["","Yes", "No"]

# %%
#@title  Text and image description/explanation and code comments within the experiment: { run: "auto", vertical-output: true, display-mode: "form" }
Comments = "Very Useful" #@param ["","Very Useful", "Somewhat Useful", "Not Useful", "Didn't use"]

# %%
#@title Mentor Support: { run: "auto", vertical-output: true, display-mode: "form" }
Mentor_support = "Very Useful" #@param ["","Very Useful", "Somewhat Useful", "Not Useful", "Didn't use"]

# %%
#@title Run this cell to submit your notebook for grading { vertical-output: true }
try:
  if submission_id:
      return_id = submit_notebook()
      if return_id : submission_id = return_id
  else:
      print("Please complete the setup first.")
except NameError:
  print ("Please complete the setup first.")
# Out:
# Your submission is successful.
# Ref Id: 803
# Date of submission:  03 May 2024
# Time of submission:  20:21:42
# View your submissions: https://aias-iisc.talentsprint.com/notebook_submissions
