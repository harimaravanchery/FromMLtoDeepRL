# %% [markdown]
# # Machine Learning and AI for Autonomous Systems
# ## A program by IISc and TalentSprint
# ### Assignment : Medical Image Classification using CNN

# %% [markdown]
# ## Introduction
#
# The use of Artificial Intelligence (AI), and deep Convolutional Neural Networks (CNNs) in particular, has led to improvements in the speed of radiological image processing and diagnosis. This speed-up has not come at the price of accuracy; cutting-edge algorithms are comparable to the current standard of care. The best human experts still outperform AI, so the technologies being developed serve as a complement to doctors and researchers, not as their replacement. Thus, it's important that those using these new tools attain some familiarity with their inner workings.
#
# ## Objective
# <ul>
#     <li>Discussion of deep learning frameworks</li>
#     <li>Creating a dataset for training and testing</li>
#     <li>Transforming and partitioning data</li>
#     <li>Architecting a CNN</li>
#     <li>Training the model</li>
#     <li>Testing on new images</li>
#
# </ul>

# %% [markdown]
# ### What is Convolution?
#
# The 2D convolution operation is a simple operation that can defined by the following steps:
# 1. Start with a kernel, which is simply a small matrix of weights.
# 2. This kernel “slides” over the 2D input data, performing an elementwise multiplication with the part of the input it is currently on, and then summing up the results into a single output pixel.
# * For detailed understanding of CNN please follow this two references
# ** [Basic understanding of CNN](https://cs231n.github.io/convolutional-networks/)
# ** [Pictorial representation of CNN](https://poloclub.github.io/cnn-explainer/)
#
# A visualization is available below.

# %% [markdown]
# ![1_Zx-ZMLKab7VOCQTxdZ1OAw.gif](data:image/gif;base64,...)

# %% [markdown]
# ### Setup Steps:

# %%
#@title Please enter your registration id to start: { run: "auto", display-mode: "form" }
Id = "2302794" #@param {type:"string"}

# %%
#@title Please enter your password (your registered phone number) to continue: { run: "auto", display-mode: "form" }
password = "9008710123" #@param {type:"string"}

# %%
#@title Run this cell to complete the setup for this Notebook
from IPython import get_ipython

ipython = get_ipython()

notebook= "AIAS_B2_M2_AST_02_Medical_Image_Classification_using_CNN_C" #name of the notebook

def setup():
#  ipython.magic("sx pip3 install torch")
    ipython.magic("sx wget -q https://cdn.extras.talentsprint.com/DHAI/Datasets/Medmnist.zip")
    from IPython.display import HTML, display
    display(HTML('<script src="https://dashboard.talentsprint.com/aiml/record_ip.html?traineeId={0}&recordId={1}"></script>'.format(getId(),submission_id)))
    print("Setup completed successfully")
    return

def submit_notebook():
    ipython.magic("notebook -e "+ notebook + ".ipynb")

    import requests, json, base64, datetime

    url = "https://dashboard.talentsprint.com/xp/app/save_notebook_attempts"
    if not submission_id:
      data = {"id" : getId(), "notebook" : notebook, "mobile" : getPassword()}
      r = requests.post(url, data = data)
      r = json.loads(r.text)

      if r["status"] == "Success":
          return r["record_id"]
      elif "err" in r:
        print(r["err"])
        return None
      else:
        print ("Something is wrong, the notebook will not be submitted for grading")
        return None

    elif getAnswer() and getComplexity() and getAdditional() and getConcepts() and getComments() and getMentorSupport():
      f = open(notebook + ".ipynb", "rb")
      file_hash = base64.b64encode(f.read())

      data = {"complexity" : Complexity, "additional" :Additional,
              "concepts" : Concepts, "record_id" : submission_id,
              "answer" : Answer, "id" : Id, "file_hash" : file_hash,
              "notebook" : notebook,
              "feedback_experiments_input" : Comments,
              "feedback_mentor_support": Mentor_support}
      r = requests.post(url, data = data)
      r = json.loads(r.text)
      if "err" in r:
        print(r["err"])
        return None
      else:
        print("Your submission is successful.")
        print("Ref Id:", submission_id)
        print("Date of submission: ", r["date"])
        print("Time of submission: ", r["time"])
        print("View your submissions: https://mlaias-iisc.talentsprint.com/notebook_submissions")
        #print("For any queries/discrepancies, please connect with mentors through the chat icon in LMS dashboard.")
        return submission_id
    else: submission_id


def getAdditional():
  try:
    if not Additional:
      raise NameError
    else:
      return Additional
  except NameError:
    print ("Please answer Additional Question")
    return None

def getComplexity():
  try:
    if not Complexity:
      raise NameError
    else:
      return Complexity
  except NameError:
    print ("Please answer Complexity Question")
    return None

def getConcepts():
  try:
    if not Concepts:
      raise NameError
    else:
      return Concepts
  except NameError:
    print ("Please answer Concepts Question")
    return None


# def getWalkthrough():
#   try:
#     if not Walkthrough:
#       raise NameError
#     else:
#       return Walkthrough
#   except NameError:
#     print ("Please answer Walkthrough Question")
#     return None

def getComments():
  try:
    if not Comments:
      raise NameError
    else:
      return Comments
  except NameError:
    print ("Please answer Comments Question")
    return None


def getMentorSupport():
  try:
    if not Mentor_support:
      raise NameError
    else:
      return Mentor_support
  except NameError:
    print ("Please answer Mentor support Question")
    return None

def getAnswer():
  try:
    if not Answer:
      raise NameError
    else:
      return Answer
  except NameError:
    print ("Please answer Question")
    return None


def getId():
  try:
    return Id if Id else None
  except NameError:
    return None

def getPassword():
  try:
    return password if password else None
  except NameError:
    return None

submission_id = None
### Setup
if getPassword() and getId():
  submission_id = submit_notebook()
  if submission_id:
    setup()
else:
  print ("Please complete Id and Password cells before running setup")
# Out:
# <script src="https://dashboard.talentsprint.com/aiml/record_ip.html?traineeId=2302794&recordId=632"></script>
# Setup completed successfully

# %% [markdown]
# ### Deep Learning and Frameworks
# A generic deep neural network consists of a series of <em>layers</em>, running between the input and output layers. Each layer is comprised of <em>nodes</em>, which store intermediate numerical values. The values from each layer are fed to the next after linear transformation by a tensor of <em>weights</em> and a nonlinear <em>activation function</em>. This overall structure is called the <em>architecture</em>.
#
# In <em>supervised learning</em>, which we will be studying here, each input datum (X value) is provided along with a target output or label (Y value). The inputs can be very general types of data: images, sentences, video clips, etc. The outputs are often things like image classes, text sentiments, or object locations.
#
# The X values are mapped through the network to outputs (Y predictions). The Y predictions are compared to the actual Y values, and the difference between them is quantified through a <em>loss function</em>. An <em>optimizer</em> varies the weights of the network over several iterations through the dataset, or <em>epochs</em>, in order to minimize the loss. This process is called <em>training</em> the network.
#
# By providing a large and detailed training dataset, creating an adequately complex network architecture, and training for a sufficient amount of time, the model should be able to predict the correct label for inputs that it has never seen before. Feeding new input into a trained model and making use of its predictions is known as <em>deployment</em>.
#
# The overhead to create and train networks with standard programming libraries is quite large. Fortunately, deep learning enthusiasts have done the heavy lifting in this process by creating specialized libraries, or <em>frameworks</em>, that allow us to condense what would be thousands of lines of tangled code down into a few dozen straightforward and readable ones. The framework used in this lab is PyTorch, which is on the beginner-friendly side while having its own technical advantages of interest to power users, too. Other popular frameworks include TensorFlow, MS Cognitive Toolkit, and MXNet, each of which has unique tradeoffs between ease of use, flexibility, speed, and accuracy.
#
# There are also higher-level frameworks called <em>wrappers</em> that can be set up with simpler code or even graphical interfaces, that in turn are able to switch between several different lower-level frameworks with the setting of a single toggle. A popular code-based wrapper is Keras, while DIGITS is a graphical one.
#
# In the code below, we load the PyTorch framework and other useful libraries. Due to the mathematically intensive nature of training, the code runs much faster on a GPU than on a conventional CPU, so we set parameters allowing for GPU acceleration.

# %% [markdown]
# ### Importing Libraries and Packages

# %%
import numpy as np
import os
import time
# %matplotlib inline
import matplotlib.pyplot as mp
from PIL import Image
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as om
import torchvision as tv
import torch.utils.data as dat

if torch.cuda.is_available():     # Make sure GPU is available
    dev = torch.device("cuda:0")
    kwar = {'num_workers': 8, 'pin_memory': True}
    cpu = torch.device("cpu")
else:
    print("Warning: CUDA not found, CPU only.")
    dev = torch.device("cpu")
    kwar = {}
    cpu = torch.device("cpu")

np.random.seed(551)

# %% [markdown]
# ### Loading Data and Creating Datasets
# Due to cost, privacy restrictions, and the rarity of certain conditions, gathering medical datasets can be particularly challenging. Once gathered from disparate sources, these data will need to be standardized for training. Preparing data at this level is beyond the scope of this short introductory primer. We have gathered images from several sets at TCIA, the RSNA Bone Age Challenge, and the NIH Chest X-ray dataset and standardized them to the same size.
#
# The code below examines our image set, organizes the filenames, and displays some statistics about them.

# %% [markdown]
# To download the data in colab, just run your setup cells. After that, you have to run the below cell to unzip the dowloaded zip file.

# %%
# !unzip '/content/Medmnist.zip' -d Medmnist/
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: Medmnist/HeadCT/005000.jpeg
#   inflating: Medmnist/HeadCT/005001.jpeg
#   inflating: Medmnist/HeadCT/005002.jpeg
#   inflating: Medmnist/HeadCT/005003.jpeg
#   inflating: Medmnist/HeadCT/005004.jpeg
#   inflating: Medmnist/HeadCT/005005.jpeg
#   inflating: Medmnist/HeadCT/005006.jpeg
#   inflating: Medmnist/HeadCT/005007.jpeg
#   inflating: Medmnist/HeadCT/005008.jpeg
#   inflating: Medmnist/HeadCT/005009.jpeg
#   inflating: Medmnist/HeadCT/005010.jpeg
#   inflating: Medmnist/HeadCT/005011.jpeg
#   inflating: Medmnist/HeadCT/005012.jpeg
#   inflating: Medmnist/HeadCT/005013.jpeg
#   inflating: Medmnist/HeadCT/005014.jpeg
#   inflating: Medmnist/HeadCT/005015.jpeg
#   inflating: Medmnist/HeadCT/005016.jpeg
#   inflating: Medmnist/HeadCT/005017.jpeg
#   inflating: Medmnist/HeadCT/005018.jpeg
#   inflating: Medmnist/HeadCT/005019.jpeg
#   inflating: Medmnist/HeadCT/005020.jpeg
#   inflating: Medmnist/HeadCT/005021.jpeg
#   inflating: Medmnist/HeadCT/005022.jpeg
#   inflating: Medmnist/HeadCT/005023.jpeg
#   inflating: Medmnist/HeadCT/005024.jpeg
#   inflating: Medmnist/HeadCT/005025.jpeg
#   inflating: Medmnist/HeadCT/005026.jpeg
#   inflating: Medmnist/HeadCT/005027.jpeg
#   inflating: Medmnist/HeadCT/005028.jpeg
#   inflating: Medmnist/HeadCT/005029.jpeg
#   inflating: Medmnist/HeadCT/005030.jpeg
#   inflating: Medmnist/HeadCT/005031.jpeg
#   inflating: Medmnist/HeadCT/005032.jpeg
#   inflating: Medmnist/HeadCT/005033.jpeg
#   inflating: Medmnist/HeadCT/005034.jpeg
#   inflating: Medmnist/HeadCT/005035.jpeg
#   inflating: Medmnist/HeadCT/005036.jpeg
#   inflating: Medmnist/HeadCT/005037.jpeg
#   inflating: Medmnist/HeadCT/005038.jpeg
#   inflating: Medmnist/HeadCT/005039.jpeg
#   inflating: Medmnist/HeadCT/005040.jpeg
#   inflating: Medmnist/HeadCT/005041.jpeg
#   inflating: Medmnist/HeadCT/005042.jpeg
#   inflating: Medmnist/HeadCT/005043.jpeg
#   inflating: Medmnist/HeadCT/005044.jpeg
#   inflating: Medmnist/HeadCT/005045.jpeg
#   inflating: Medmnist/HeadCT/005046.jpeg
#   inflating: Medmnist/HeadCT/005047.jpeg
#   inflating: Medmnist/HeadCT/005048.jpeg
#   inflating: Medmnist/HeadCT/005049.jpeg
#   inflating: Medmnist/HeadCT/005050.jpeg
#   inflating: Medmnist/HeadCT/005051.jpeg
#   inflating: Medmnist/HeadCT/005052.jpeg
#   inflating: Medmnist/HeadCT/005053.jpeg
#   inflating: Medmnist/HeadCT/005054.jpeg
#   inflating: Medmnist/HeadCT/005055.jpeg
#   inflating: Medmnist/HeadCT/005056.jpeg
#   inflating: Medmnist/HeadCT/005057.jpeg
#   inflating: Medmnist/HeadCT/005058.jpeg
#   inflating: Medmnist/HeadCT/005059.jpeg
#   inflating: Medmnist/HeadCT/005060.jpeg
#   inflating: Medmnist/HeadCT/005061.jpeg
#   inflating: Medmnist/HeadCT/005062.jpeg
#   inflating: Medmnist/HeadCT/005063.jpeg
#   inflating: Medmnist/HeadCT/005064.jpeg
#   inflating: Medmnist/HeadCT/005065.jpeg
#   inflating: Medmnist/HeadCT/005066.jpeg
#   inflating: Medmnist/HeadCT/005067.jpeg
#   inflating: Medmnist/HeadCT/005068.jpeg
#   inflating: Medmnist/HeadCT/005069.jpeg
#   inflating: Medmnist/HeadCT/005070.jpeg
#   inflating: Medmnist/HeadCT/005071.jpeg
#   inflating: Medmnist/HeadCT/005072.jpeg
#   inflating: Medmnist/HeadCT/005073.jpeg
#   inflating: Medmnist/HeadCT/005074.jpeg
#   inflating: Medmnist/HeadCT/005075.jpeg
#   inflating: Medmnist/HeadCT/005076.jpeg
#   inflating: Medmnist/HeadCT/005077.jpeg
#   inflating: Medmnist/HeadCT/005078.jpeg
#   inflating: Medmnist/HeadCT/005079.jpeg
#   inflating: Medmnist/HeadCT/005080.jpeg
#   inflating: Medmnist/HeadCT/005081.jpeg
#   inflating: Medmnist/HeadCT/005082.jpeg
#   inflating: Medmnist/HeadCT/005083.jpeg
#   inflating: Medmnist/HeadCT/005084.jpeg
#   inflating: Medmnist/HeadCT/005085.jpeg
#   inflating: Medmnist/HeadCT/005086.jpeg
#   inflating: Medmnist/HeadCT/005087.jpeg
#   inflating: Medmnist/HeadCT/005088.jpeg
#   inflating: Medmnist/HeadCT/005089.jpeg
#   inflating: Medmnist/HeadCT/005090.jpeg
#   inflating: Medmnist/HeadCT/005091.jpeg
#   inflating: Medmnist/HeadCT/005092.jpeg
#   inflating: Medmnist/HeadCT/005093.jpeg
#   inflating: Medmnist/HeadCT/005094.jpeg
#   inflating: Medmnist/HeadCT/005095.jpeg
#   inflating: Medmnist/HeadCT/005096.jpeg
#   inflating: Medmnist/HeadCT/005097.jpeg
#   inflating: Medmnist/HeadCT/005098.jpeg
#   inflating: Medmnist/HeadCT/005099.jpeg
#   inflating: Medmnist/HeadCT/005100.jpeg
#   inflating: Medmnist/HeadCT/005101.jpeg
#   inflating: Medmnist/HeadCT/005102.jpeg
#   inflating: Medmnist/HeadCT/005103.jpeg
#   inflating: Medmnist/HeadCT/005104.jpeg
#   inflating: Medmnist/HeadCT/005105.jpeg
#   inflating: Medmnist/HeadCT/005106.jpeg
#   inflating: Medmnist/HeadCT/005107.jpeg
#   inflating: Medmnist/HeadCT/005108.jpeg
#   inflating: Medmnist/HeadCT/005109.jpeg
#   inflating: Medmnist/HeadCT/005110.jpeg
#   inflating: Medmnist/HeadCT/005111.jpeg
#   inflating: Medmnist/HeadCT/005112.jpeg
#   inflating: Medmnist/HeadCT/005113.jpeg
#   inflating: Medmnist/HeadCT/005114.jpeg
#   inflating: Medmnist/HeadCT/005115.jpeg
#   inflating: Medmnist/HeadCT/005116.jpeg
#   inflating: Medmnist/HeadCT/005117.jpeg
#   inflating: Medmnist/HeadCT/005118.jpeg
#   inflating: Medmnist/HeadCT/005119.jpeg
#   inflating: Medmnist/HeadCT/005120.jpeg
#   inflating: Medmnist/HeadCT/005121.jpeg
#   inflating: Medmnist/HeadCT/005122.jpeg
#   inflating: Medmnist/HeadCT/005123.jpeg
#   inflating: Medmnist/HeadCT/005124.jpeg
#   inflating: Medmnist/HeadCT/005125.jpeg
#   inflating: Medmnist/HeadCT/005126.jpeg
#   inflating: Medmnist/HeadCT/005127.jpeg
#   inflating: Medmnist/HeadCT/005128.jpeg
#   inflating: Medmnist/HeadCT/005129.jpeg
#   inflating: Medmnist/HeadCT/005130.jpeg
#   inflating: Medmnist/HeadCT/005131.jpeg
#   inflating: Medmnist/HeadCT/005132.jpeg
#   inflating: Medmnist/HeadCT/005133.jpeg
#   inflating: Medmnist/HeadCT/005134.jpeg
#   inflating: Medmnist/HeadCT/005135.jpeg
#   inflating: Medmnist/HeadCT/005136.jpeg
#   inflating: Medmnist/HeadCT/005137.jpeg
#   inflating: Medmnist/HeadCT/005138.jpeg
#   inflating: Medmnist/HeadCT/005139.jpeg
#   inflating: Medmnist/HeadCT/005140.jpeg
#   inflating: Medmnist/HeadCT/005141.jpeg
#   inflating: Medmnist/HeadCT/005142.jpeg
#   inflating: Medmnist/HeadCT/005143.jpeg
#   inflating: Medmnist/HeadCT/005144.jpeg
#   inflating: Medmnist/HeadCT/005145.jpeg
#   inflating: Medmnist/HeadCT/005146.jpeg
#   inflating: Medmnist/HeadCT/005147.jpeg
#   inflating: Medmnist/HeadCT/005148.jpeg
#   inflating: Medmnist/HeadCT/005149.jpeg
#   inflating: Medmnist/HeadCT/005150.jpeg
#   inflating: Medmnist/HeadCT/005151.jpeg
#   inflating: Medmnist/HeadCT/005152.jpeg
#   inflating: Medmnist/HeadCT/005153.jpeg
#   inflating: Medmnist/HeadCT/005154.jpeg
#   inflating: Medmnist/HeadCT/005155.jpeg
#   inflating: Medmnist/HeadCT/005156.jpeg
#   inflating: Medmnist/HeadCT/005157.jpeg
#   inflating: Medmnist/HeadCT/005158.jpeg
#   inflating: Medmnist/HeadCT/005159.jpeg
#   inflating: Medmnist/HeadCT/005160.jpeg
#   inflating: Medmnist/HeadCT/005161.jpeg
#   inflating: Medmnist/HeadCT/005162.jpeg
#   inflating: Medmnist/HeadCT/005163.jpeg
#   inflating: Medmnist/HeadCT/005164.jpeg
#   inflating: Medmnist/HeadCT/005165.jpeg
#   inflating: Medmnist/HeadCT/005166.jpeg
#   inflating: Medmnist/HeadCT/005167.jpeg
#   inflating: Medmnist/HeadCT/005168.jpeg
#   inflating: Medmnist/HeadCT/005169.jpeg
#   inflating: Medmnist/HeadCT/005170.jpeg
#   inflating: Medmnist/HeadCT/005171.jpeg
#   inflating: Medmnist/HeadCT/005172.jpeg
#   inflating: Medmnist/HeadCT/005173.jpeg
#   inflating: Medmnist/HeadCT/005174.jpeg
#   inflating: Medmnist/HeadCT/005175.jpeg
#   inflating: Medmnist/HeadCT/005176.jpeg
#   inflating: Medmnist/HeadCT/005177.jpeg
#   inflating: Medmnist/HeadCT/005178.jpeg
#   inflating: Medmnist/HeadCT/005179.jpeg
#   inflating: Medmnist/HeadCT/005180.jpeg
#   inflating: Medmnist/HeadCT/005181.jpeg
#   inflating: Medmnist/HeadCT/005182.jpeg
#   inflating: Medmnist/HeadCT/005183.jpeg
#   inflating: Medmnist/HeadCT/005184.jpeg
#   inflating: Medmnist/HeadCT/005185.jpeg
#   inflating: Medmnist/HeadCT/005186.jpeg
#   inflating: Medmnist/HeadCT/005187.jpeg
#   inflating: Medmnist/HeadCT/005188.jpeg
#   inflating: Medmnist/HeadCT/005189.jpeg
#   inflating: Medmnist/HeadCT/005190.jpeg
#   inflating: Medmnist/HeadCT/005191.jpeg
#   inflating: Medmnist/HeadCT/005192.jpeg
#   inflating: Medmnist/HeadCT/005193.jpeg
#   inflating: Medmnist/HeadCT/005194.jpeg
#   inflating: Medmnist/HeadCT/005195.jpeg
#   inflating: Medmnist/HeadCT/005196.jpeg
#   inflating: Medmnist/HeadCT/005197.jpeg
#   inflating: Medmnist/HeadCT/005198.jpeg
#   inflating: Medmnist/HeadCT/005199.jpeg
#   inflating: Medmnist/HeadCT/005200.jpeg
#   inflating: Medmnist/HeadCT/005201.jpeg
#   inflating: Medmnist/HeadCT/005202.jpeg
#   inflating: Medmnist/HeadCT/005203.jpeg
#   inflating: Medmnist/HeadCT/005204.jpeg
#   inflating: Medmnist/HeadCT/005205.jpeg
#   inflating: Medmnist/HeadCT/005206.jpeg
#   inflating: Medmnist/HeadCT/005207.jpeg
#   inflating: Medmnist/HeadCT/005208.jpeg
#   inflating: Medmnist/HeadCT/005209.jpeg
#   inflating: Medmnist/HeadCT/005210.jpeg
#   inflating: Medmnist/HeadCT/005211.jpeg
#   inflating: Medmnist/HeadCT/005212.jpeg
#   inflating: Medmnist/HeadCT/005213.jpeg
#   inflating: Medmnist/HeadCT/005214.jpeg
#   inflating: Medmnist/HeadCT/005215.jpeg
#   inflating: Medmnist/HeadCT/005216.jpeg
#   inflating: Medmnist/HeadCT/005217.jpeg
#   inflating: Medmnist/HeadCT/005218.jpeg
#   inflating: Medmnist/HeadCT/005219.jpeg
#   inflating: Medmnist/HeadCT/005220.jpeg
#   inflating: Medmnist/HeadCT/005221.jpeg
#   inflating: Medmnist/HeadCT/005222.jpeg
#   inflating: Medmnist/HeadCT/005223.jpeg
#   inflating: Medmnist/HeadCT/005224.jpeg
#   inflating: Medmnist/HeadCT/005225.jpeg
#   inflating: Medmnist/HeadCT/005226.jpeg
#   inflating: Medmnist/HeadCT/005227.jpeg
#   inflating: Medmnist/HeadCT/005228.jpeg
#   inflating: Medmnist/HeadCT/005229.jpeg
#   inflating: Medmnist/HeadCT/005230.jpeg
#   inflating: Medmnist/HeadCT/005231.jpeg
#   inflating: Medmnist/HeadCT/005232.jpeg
#   inflating: Medmnist/HeadCT/005233.jpeg
#   inflating: Medmnist/HeadCT/005234.jpeg
#   inflating: Medmnist/HeadCT/005235.jpeg
#   inflating: Medmnist/HeadCT/005236.jpeg
#   inflating: Medmnist/HeadCT/005237.jpeg
#   inflating: Medmnist/HeadCT/005238.jpeg
#   inflating: Medmnist/HeadCT/005239.jpeg
#   inflating: Medmnist/HeadCT/005240.jpeg
#   inflating: Medmnist/HeadCT/005241.jpeg
#   inflating: Medmnist/HeadCT/005242.jpeg
#   inflating: Medmnist/HeadCT/005243.jpeg
#   inflating: Medmnist/HeadCT/005244.jpeg
#   inflating: Medmnist/HeadCT/005245.jpeg
#   inflating: Medmnist/HeadCT/005246.jpeg
#   inflating: Medmnist/HeadCT/005247.jpeg
#   inflating: Medmnist/HeadCT/005248.jpeg
#   inflating: Medmnist/HeadCT/005249.jpeg
#   inflating: Medmnist/HeadCT/005250.jpeg
#   inflating: Medmnist/HeadCT/005251.jpeg
#   inflating: Medmnist/HeadCT/005252.jpeg
#   inflating: Medmnist/HeadCT/005253.jpeg
#   inflating: Medmnist/HeadCT/005254.jpeg
#   inflating: Medmnist/HeadCT/005255.jpeg
#   inflating: Medmnist/HeadCT/005256.jpeg
#   inflating: Medmnist/HeadCT/005257.jpeg
#   inflating: Medmnist/HeadCT/005258.jpeg
#   inflating: Medmnist/HeadCT/005259.jpeg
#   inflating: Medmnist/HeadCT/005260.jpeg
#   inflating: Medmnist/HeadCT/005261.jpeg
#   inflating: Medmnist/HeadCT/005262.jpeg
#   inflating: Medmnist/HeadCT/005263.jpeg
#   inflating: Medmnist/HeadCT/005264.jpeg
#   inflating: Medmnist/HeadCT/005265.jpeg
#   inflating: Medmnist/HeadCT/005266.jpeg
#   inflating: Medmnist/HeadCT/005267.jpeg
#   inflating: Medmnist/HeadCT/005268.jpeg
#   inflating: Medmnist/HeadCT/005269.jpeg
#   inflating: Medmnist/HeadCT/005270.jpeg
#   inflating: Medmnist/HeadCT/005271.jpeg
#   inflating: Medmnist/HeadCT/005272.jpeg
#   inflating: Medmnist/HeadCT/005273.jpeg
#   inflating: Medmnist/HeadCT/005274.jpeg
#   inflating: Medmnist/HeadCT/005275.jpeg
#   inflating: Medmnist/HeadCT/005276.jpeg
#   inflating: Medmnist/HeadCT/005277.jpeg
#   inflating: Medmnist/HeadCT/005278.jpeg
#   inflating: Medmnist/HeadCT/005279.jpeg
#   inflating: Medmnist/HeadCT/005280.jpeg
#   inflating: Medmnist/HeadCT/005281.jpeg
#   inflating: Medmnist/HeadCT/005282.jpeg
#   inflating: Medmnist/HeadCT/005283.jpeg
#   inflating: Medmnist/HeadCT/005284.jpeg
#   inflating: Medmnist/HeadCT/005285.jpeg
#   inflating: Medmnist/HeadCT/005286.jpeg
#   inflating: Medmnist/HeadCT/005287.jpeg
#   inflating: Medmnist/HeadCT/005288.jpeg
#   inflating: Medmnist/HeadCT/005289.jpeg
#   inflating: Medmnist/HeadCT/005290.jpeg
#   inflating: Medmnist/HeadCT/005291.jpeg
#   inflating: Medmnist/HeadCT/005292.jpeg
#   inflating: Medmnist/HeadCT/005293.jpeg
#   inflating: Medmnist/HeadCT/005294.jpeg
#   inflating: Medmnist/HeadCT/005295.jpeg
#   inflating: Medmnist/HeadCT/005296.jpeg
#   inflating: Medmnist/HeadCT/005297.jpeg
#   inflating: Medmnist/HeadCT/005298.jpeg
#   inflating: Medmnist/HeadCT/005299.jpeg
#   inflating: Medmnist/HeadCT/005300.jpeg
#   inflating: Medmnist/HeadCT/005301.jpeg
#   inflating: Medmnist/HeadCT/005302.jpeg
#   inflating: Medmnist/HeadCT/005303.jpeg
#   inflating: Medmnist/HeadCT/005304.jpeg
#   inflating: Medmnist/HeadCT/005305.jpeg
#   inflating: Medmnist/HeadCT/005306.jpeg
#   inflating: Medmnist/HeadCT/005307.jpeg
#   inflating: Medmnist/HeadCT/005308.jpeg
#   inflating: Medmnist/HeadCT/005309.jpeg
#   inflating: Medmnist/HeadCT/005310.jpeg
#   inflating: Medmnist/HeadCT/005311.jpeg
#   inflating: Medmnist/HeadCT/005312.jpeg
#   inflating: Medmnist/HeadCT/005313.jpeg
#   inflating: Medmnist/HeadCT/005314.jpeg
#   inflating: Medmnist/HeadCT/005315.jpeg
#   inflating: Medmnist/HeadCT/005316.jpeg
#   inflating: Medmnist/HeadCT/005317.jpeg
#   inflating: Medmnist/HeadCT/005318.jpeg
#   inflating: Medmnist/HeadCT/005319.jpeg
#   inflating: Medmnist/HeadCT/005320.jpeg
#   inflating: Medmnist/HeadCT/005321.jpeg
#   inflating: Medmnist/HeadCT/005322.jpeg
#   inflating: Medmnist/HeadCT/005323.jpeg
#   inflating: Medmnist/HeadCT/005324.jpeg
#   inflating: Medmnist/HeadCT/005325.jpeg
#   inflating: Medmnist/HeadCT/005326.jpeg
#   inflating: Medmnist/HeadCT/005327.jpeg
#   inflating: Medmnist/HeadCT/005328.jpeg
#   inflating: Medmnist/HeadCT/005329.jpeg
#   inflating: Medmnist/HeadCT/005330.jpeg
#   inflating: Medmnist/HeadCT/005331.jpeg
#   inflating: Medmnist/HeadCT/005332.jpeg
#   inflating: Medmnist/HeadCT/005333.jpeg
#   inflating: Medmnist/HeadCT/005334.jpeg
#   inflating: Medmnist/HeadCT/005335.jpeg
#   inflating: Medmnist/HeadCT/005336.jpeg
#   inflating: Medmnist/HeadCT/005337.jpeg
#   inflating: Medmnist/HeadCT/005338.jpeg
#   inflating: Medmnist/HeadCT/005339.jpeg
#   inflating: Medmnist/HeadCT/005340.jpeg
#   inflating: Medmnist/HeadCT/005341.jpeg
#   inflating: Medmnist/HeadCT/005342.jpeg
#   inflating: Medmnist/HeadCT/005343.jpeg
#   inflating: Medmnist/HeadCT/005344.jpeg
#   inflating: Medmnist/HeadCT/005345.jpeg
#   inflating: Medmnist/HeadCT/005346.jpeg
#   inflating: Medmnist/HeadCT/005347.jpeg
#   inflating: Medmnist/HeadCT/005348.jpeg
#   inflating: Medmnist/HeadCT/005349.jpeg
#   inflating: Medmnist/HeadCT/005350.jpeg
#   inflating: Medmnist/HeadCT/005351.jpeg
#   inflating: Medmnist/HeadCT/005352.jpeg
#   inflating: Medmnist/HeadCT/005353.jpeg
#   inflating: Medmnist/HeadCT/005354.jpeg
#   inflating: Medmnist/HeadCT/005355.jpeg
#   inflating: Medmnist/HeadCT/005356.jpeg
#   inflating: Medmnist/HeadCT/005357.jpeg
#   inflating: Medmnist/HeadCT/005358.jpeg
#   inflating: Medmnist/HeadCT/005359.jpeg
#   inflating: Medmnist/HeadCT/005360.jpeg
#   inflating: Medmnist/HeadCT/005361.jpeg
#   inflating: Medmnist/HeadCT/005362.jpeg
#   inflating: Medmnist/HeadCT/005363.jpeg
#   inflating: Medmnist/HeadCT/005364.jpeg
#   inflating: Medmnist/HeadCT/005365.jpeg
#   inflating: Medmnist/HeadCT/005366.jpeg
#   inflating: Medmnist/HeadCT/005367.jpeg
#   inflating: Medmnist/HeadCT/005368.jpeg
#   inflating: Medmnist/HeadCT/005369.jpeg
#   inflating: Medmnist/HeadCT/005370.jpeg
#   inflating: Medmnist/HeadCT/005371.jpeg
#   inflating: Medmnist/HeadCT/005372.jpeg
#   inflating: Medmnist/HeadCT/005373.jpeg
#   inflating: Medmnist/HeadCT/005374.jpeg
#   inflating: Medmnist/HeadCT/005375.jpeg
#   inflating: Medmnist/HeadCT/005376.jpeg
#   inflating: Medmnist/HeadCT/005377.jpeg
#   inflating: Medmnist/HeadCT/005378.jpeg
#   inflating: Medmnist/HeadCT/005379.jpeg
#   inflating: Medmnist/HeadCT/005380.jpeg
#   inflating: Medmnist/HeadCT/005381.jpeg
#   inflating: Medmnist/HeadCT/005382.jpeg
#   inflating: Medmnist/HeadCT/005383.jpeg
#   inflating: Medmnist/HeadCT/005384.jpeg
#   inflating: Medmnist/HeadCT/005385.jpeg
#   inflating: Medmnist/HeadCT/005386.jpeg
#   inflating: Medmnist/HeadCT/005387.jpeg
#   inflating: Medmnist/HeadCT/005388.jpeg
#   inflating: Medmnist/HeadCT/005389.jpeg
#   inflating: Medmnist/HeadCT/005390.jpeg
#   inflating: Medmnist/HeadCT/005391.jpeg
#   inflating: Medmnist/HeadCT/005392.jpeg
#   inflating: Medmnist/HeadCT/005393.jpeg
#   inflating: Medmnist/HeadCT/005394.jpeg
#   inflating: Medmnist/HeadCT/005395.jpeg
#   inflating: Medmnist/HeadCT/005396.jpeg
#   inflating: Medmnist/HeadCT/005397.jpeg
#   inflating: Medmnist/HeadCT/005398.jpeg
#   inflating: Medmnist/HeadCT/005399.jpeg
#   inflating: Medmnist/HeadCT/005400.jpeg
#   inflating: Medmnist/HeadCT/005401.jpeg
#   inflating: Medmnist/HeadCT/005402.jpeg
#   inflating: Medmnist/HeadCT/005403.jpeg
#   inflating: Medmnist/HeadCT/005404.jpeg
#   inflating: Medmnist/HeadCT/005405.jpeg
#   inflating: Medmnist/HeadCT/005406.jpeg
#   inflating: Medmnist/HeadCT/005407.jpeg
#   inflating: Medmnist/HeadCT/005408.jpeg
#   inflating: Medmnist/HeadCT/005409.jpeg
#   inflating: Medmnist/HeadCT/005410.jpeg
#   inflating: Medmnist/HeadCT/005411.jpeg
#   inflating: Medmnist/HeadCT/005412.jpeg
#   inflating: Medmnist/HeadCT/005413.jpeg
#   inflating: Medmnist/HeadCT/005414.jpeg
#   inflating: Medmnist/HeadCT/005415.jpeg
#   inflating: Medmnist/HeadCT/005416.jpeg
#   inflating: Medmnist/HeadCT/005417.jpeg
#   inflating: Medmnist/HeadCT/005418.jpeg
#   inflating: Medmnist/HeadCT/005419.jpeg
#   inflating: Medmnist/HeadCT/005420.jpeg
#   inflating: Medmnist/HeadCT/005421.jpeg
#   inflating: Medmnist/HeadCT/005422.jpeg
#   inflating: Medmnist/HeadCT/005423.jpeg
#   inflating: Medmnist/HeadCT/005424.jpeg
#   inflating: Medmnist/HeadCT/005425.jpeg
#   inflating: Medmnist/HeadCT/005426.jpeg
#   inflating: Medmnist/HeadCT/005427.jpeg
#   inflating: Medmnist/HeadCT/005428.jpeg
#   inflating: Medmnist/HeadCT/005429.jpeg
#   inflating: Medmnist/HeadCT/005430.jpeg
#   inflating: Medmnist/HeadCT/005431.jpeg
#   inflating: Medmnist/HeadCT/005432.jpeg
#   inflating: Medmnist/HeadCT/005433.jpeg
#   inflating: Medmnist/HeadCT/005434.jpeg
#   inflating: Medmnist/HeadCT/005435.jpeg
#   inflating: Medmnist/HeadCT/005436.jpeg
#   inflating: Medmnist/HeadCT/005437.jpeg
#   inflating: Medmnist/HeadCT/005438.jpeg
#   inflating: Medmnist/HeadCT/005439.jpeg
#   inflating: Medmnist/HeadCT/005440.jpeg
#   inflating: Medmnist/HeadCT/005441.jpeg
#   inflating: Medmnist/HeadCT/005442.jpeg
#   inflating: Medmnist/HeadCT/005443.jpeg
#   inflating: Medmnist/HeadCT/005444.jpeg
#   inflating: Medmnist/HeadCT/005445.jpeg
#   inflating: Medmnist/HeadCT/005446.jpeg
#   inflating: Medmnist/HeadCT/005447.jpeg
#   inflating: Medmnist/HeadCT/005448.jpeg
#   inflating: Medmnist/HeadCT/005449.jpeg
#   inflating: Medmnist/HeadCT/005450.jpeg
#   inflating: Medmnist/HeadCT/005451.jpeg
#   inflating: Medmnist/HeadCT/005452.jpeg
#   inflating: Medmnist/HeadCT/005453.jpeg
#   inflating: Medmnist/HeadCT/005454.jpeg
#   inflating: Medmnist/HeadCT/005455.jpeg
#   inflating: Medmnist/HeadCT/005456.jpeg
#   inflating: Medmnist/HeadCT/005457.jpeg
#   inflating: Medmnist/HeadCT/005458.jpeg
#   inflating: Medmnist/HeadCT/005459.jpeg
#   inflating: Medmnist/HeadCT/005460.jpeg
#   inflating: Medmnist/HeadCT/005461.jpeg
#   inflating: Medmnist/HeadCT/005462.jpeg
#   inflating: Medmnist/HeadCT/005463.jpeg
#   inflating: Medmnist/HeadCT/005464.jpeg
#   inflating: Medmnist/HeadCT/005465.jpeg
#   inflating: Medmnist/HeadCT/005466.jpeg
#   inflating: Medmnist/HeadCT/005467.jpeg
#   inflating: Medmnist/HeadCT/005468.jpeg
#   inflating: Medmnist/HeadCT/005469.jpeg
#   inflating: Medmnist/HeadCT/005470.jpeg
#   inflating: Medmnist/HeadCT/005471.jpeg
#   inflating: Medmnist/HeadCT/005472.jpeg
#   inflating: Medmnist/HeadCT/005473.jpeg
#   inflating: Medmnist/HeadCT/005474.jpeg
#   inflating: Medmnist/HeadCT/005475.jpeg
#   inflating: Medmnist/HeadCT/005476.jpeg
#   inflating: Medmnist/HeadCT/005477.jpeg
#   inflating: Medmnist/HeadCT/005478.jpeg
#   inflating: Medmnist/HeadCT/005479.jpeg
#   inflating: Medmnist/HeadCT/005480.jpeg
#   inflating: Medmnist/HeadCT/005481.jpeg
#   inflating: Medmnist/HeadCT/005482.jpeg
#   inflating: Medmnist/HeadCT/005483.jpeg
#   inflating: Medmnist/HeadCT/005484.jpeg
#   inflating: Medmnist/HeadCT/005485.jpeg
#   inflating: Medmnist/HeadCT/005486.jpeg
#   inflating: Medmnist/HeadCT/005487.jpeg
#   inflating: Medmnist/HeadCT/005488.jpeg
#   inflating: Medmnist/HeadCT/005489.jpeg
#   inflating: Medmnist/HeadCT/005490.jpeg
#   inflating: Medmnist/HeadCT/005491.jpeg
#   inflating: Medmnist/HeadCT/005492.jpeg
#   inflating: Medmnist/HeadCT/005493.jpeg
#   inflating: Medmnist/HeadCT/005494.jpeg
#   inflating: Medmnist/HeadCT/005495.jpeg
#   inflating: Medmnist/HeadCT/005496.jpeg
#   inflating: Medmnist/HeadCT/005497.jpeg
#   inflating: Medmnist/HeadCT/005498.jpeg
#   inflating: Medmnist/HeadCT/005499.jpeg
#   inflating: Medmnist/HeadCT/005500.jpeg
#   inflating: Medmnist/HeadCT/005501.jpeg
#   inflating: Medmnist/HeadCT/005502.jpeg
#   inflating: Medmnist/HeadCT/005503.jpeg
#   inflating: Medmnist/HeadCT/005504.jpeg
#   inflating: Medmnist/HeadCT/005505.jpeg
#   inflating: Medmnist/HeadCT/005506.jpeg
#   inflating: Medmnist/HeadCT/005507.jpeg
#   inflating: Medmnist/HeadCT/005508.jpeg
#   inflating: Medmnist/HeadCT/005509.jpeg
#   inflating: Medmnist/HeadCT/005510.jpeg
#   inflating: Medmnist/HeadCT/005511.jpeg
#   inflating: Medmnist/HeadCT/005512.jpeg
#   inflating: Medmnist/HeadCT/005513.jpeg
#   inflating: Medmnist/HeadCT/005514.jpeg
#   inflating: Medmnist/HeadCT/005515.jpeg
#   inflating: Medmnist/HeadCT/005516.jpeg
#   inflating: Medmnist/HeadCT/005517.jpeg
#   inflating: Medmnist/HeadCT/005518.jpeg
#   inflating: Medmnist/HeadCT/005519.jpeg
#   inflating: Medmnist/HeadCT/005520.jpeg
#   inflating: Medmnist/HeadCT/005521.jpeg
#   inflating: Medmnist/HeadCT/005522.jpeg
#   inflating: Medmnist/HeadCT/005523.jpeg
#   inflating: Medmnist/HeadCT/005524.jpeg
#   inflating: Medmnist/HeadCT/005525.jpeg
#   inflating: Medmnist/HeadCT/005526.jpeg
#   inflating: Medmnist/HeadCT/005527.jpeg
#   inflating: Medmnist/HeadCT/005528.jpeg
#   inflating: Medmnist/HeadCT/005529.jpeg
#   inflating: Medmnist/HeadCT/005530.jpeg
#   inflating: Medmnist/HeadCT/005531.jpeg
#   inflating: Medmnist/HeadCT/005532.jpeg
#   inflating: Medmnist/HeadCT/005533.jpeg
#   inflating: Medmnist/HeadCT/005534.jpeg
#   inflating: Medmnist/HeadCT/005535.jpeg
#   inflating: Medmnist/HeadCT/005536.jpeg
#   inflating: Medmnist/HeadCT/005537.jpeg
#   inflating: Medmnist/HeadCT/005538.jpeg
#   inflating: Medmnist/HeadCT/005539.jpeg
#   inflating: Medmnist/HeadCT/005540.jpeg
#   inflating: Medmnist/HeadCT/005541.jpeg
#   inflating: Medmnist/HeadCT/005542.jpeg
#   inflating: Medmnist/HeadCT/005543.jpeg
#   inflating: Medmnist/HeadCT/005544.jpeg
#   inflating: Medmnist/HeadCT/005545.jpeg
#   inflating: Medmnist/HeadCT/005546.jpeg
#   inflating: Medmnist/HeadCT/005547.jpeg
#   inflating: Medmnist/HeadCT/005548.jpeg
#   inflating: Medmnist/HeadCT/005549.jpeg
#   inflating: Medmnist/HeadCT/005550.jpeg
#   inflating: Medmnist/HeadCT/005551.jpeg
#   inflating: Medmnist/HeadCT/005552.jpeg
#   inflating: Medmnist/HeadCT/005553.jpeg
#   inflating: Medmnist/HeadCT/005554.jpeg
#   inflating: Medmnist/HeadCT/005555.jpeg
#   inflating: Medmnist/HeadCT/005556.jpeg
#   inflating: Medmnist/HeadCT/005557.jpeg
#   inflating: Medmnist/HeadCT/005558.jpeg
#   inflating: Medmnist/HeadCT/005559.jpeg
#   inflating: Medmnist/HeadCT/005560.jpeg
#   inflating: Medmnist/HeadCT/005561.jpeg
#   inflating: Medmnist/HeadCT/005562.jpeg
#   inflating: Medmnist/HeadCT/005563.jpeg
#   inflating: Medmnist/HeadCT/005564.jpeg
#   inflating: Medmnist/HeadCT/005565.jpeg
#   inflating: Medmnist/HeadCT/005566.jpeg
#   inflating: Medmnist/HeadCT/005567.jpeg
#   inflating: Medmnist/HeadCT/005568.jpeg
#   inflating: Medmnist/HeadCT/005569.jpeg
#   inflating: Medmnist/HeadCT/005570.jpeg
#   inflating: Medmnist/HeadCT/005571.jpeg
#   inflating: Medmnist/HeadCT/005572.jpeg
#   inflating: Medmnist/HeadCT/005573.jpeg
#   inflating: Medmnist/HeadCT/005574.jpeg
#   inflating: Medmnist/HeadCT/005575.jpeg
#   inflating: Medmnist/HeadCT/005576.jpeg
#   inflating: Medmnist/HeadCT/005577.jpeg
#   inflating: Medmnist/HeadCT/005578.jpeg
#   inflating: Medmnist/HeadCT/005579.jpeg
#   inflating: Medmnist/HeadCT/005580.jpeg
#   inflating: Medmnist/HeadCT/005581.jpeg
#   inflating: Medmnist/HeadCT/005582.jpeg
#   inflating: Medmnist/HeadCT/005583.jpeg
#   inflating: Medmnist/HeadCT/005584.jpeg
#   inflating: Medmnist/HeadCT/005585.jpeg
#   inflating: Medmnist/HeadCT/005586.jpeg
#   inflating: Medmnist/HeadCT/005587.jpeg
#   inflating: Medmnist/HeadCT/005588.jpeg
#   inflating: Medmnist/HeadCT/005589.jpeg
#   inflating: Medmnist/HeadCT/005590.jpeg
#   inflating: Medmnist/HeadCT/005591.jpeg
#   inflating: Medmnist/HeadCT/005592.jpeg
#   inflating: Medmnist/HeadCT/005593.jpeg
#   inflating: Medmnist/HeadCT/005594.jpeg
#   inflating: Medmnist/HeadCT/005595.jpeg
#   inflating: Medmnist/HeadCT/005596.jpeg
#   inflating: Medmnist/HeadCT/005597.jpeg
#   inflating: Medmnist/HeadCT/005598.jpeg
#   inflating: Medmnist/HeadCT/005599.jpeg
#   inflating: Medmnist/HeadCT/005600.jpeg
#   inflating: Medmnist/HeadCT/005601.jpeg
#   inflating: Medmnist/HeadCT/005602.jpeg
#   inflating: Medmnist/HeadCT/005603.jpeg
#   inflating: Medmnist/HeadCT/005604.jpeg
#   inflating: Medmnist/HeadCT/005605.jpeg
#   inflating: Medmnist/HeadCT/005606.jpeg
#   inflating: Medmnist/HeadCT/005607.jpeg
#   inflating: Medmnist/HeadCT/005608.jpeg
#   inflating: Medmnist/HeadCT/005609.jpeg
#   inflating: Medmnist/HeadCT/005610.jpeg
#   inflating: Medmnist/HeadCT/005611.jpeg
#   inflating: Medmnist/HeadCT/005612.jpeg
#   inflating: Medmnist/HeadCT/005613.jpeg
#   inflating: Medmnist/HeadCT/005614.jpeg
#   inflating: Medmnist/HeadCT/005615.jpeg
#   inflating: Medmnist/HeadCT/005616.jpeg
#   inflating: Medmnist/HeadCT/005617.jpeg
#   inflating: Medmnist/HeadCT/005618.jpeg
#   inflating: Medmnist/HeadCT/005619.jpeg
#   inflating: Medmnist/HeadCT/005620.jpeg
#   inflating: Medmnist/HeadCT/005621.jpeg
#   inflating: Medmnist/HeadCT/005622.jpeg
#   inflating: Medmnist/HeadCT/005623.jpeg
#   inflating: Medmnist/HeadCT/005624.jpeg
#   inflating: Medmnist/HeadCT/005625.jpeg
#   inflating: Medmnist/HeadCT/005626.jpeg
#   inflating: Medmnist/HeadCT/005627.jpeg
#   inflating: Medmnist/HeadCT/005628.jpeg
#   inflating: Medmnist/HeadCT/005629.jpeg
#   inflating: Medmnist/HeadCT/005630.jpeg
#   inflating: Medmnist/HeadCT/005631.jpeg
#   inflating: Medmnist/HeadCT/005632.jpeg
#   inflating: Medmnist/HeadCT/005633.jpeg
#   inflating: Medmnist/HeadCT/005634.jpeg
#   inflating: Medmnist/HeadCT/005635.jpeg
#   inflating: Medmnist/HeadCT/005636.jpeg
#   inflating: Medmnist/HeadCT/005637.jpeg
#   inflating: Medmnist/HeadCT/005638.jpeg
#   inflating: Medmnist/HeadCT/005639.jpeg
#   inflating: Medmnist/HeadCT/005640.jpeg
#   inflating: Medmnist/HeadCT/005641.jpeg
#   inflating: Medmnist/HeadCT/005642.jpeg
#   inflating: Medmnist/HeadCT/005643.jpeg
#   inflating: Medmnist/HeadCT/005644.jpeg
#   inflating: Medmnist/HeadCT/005645.jpeg
#   inflating: Medmnist/HeadCT/005646.jpeg
#   inflating: Medmnist/HeadCT/005647.jpeg
#   inflating: Medmnist/HeadCT/005648.jpeg
#   inflating: Medmnist/HeadCT/005649.jpeg
#   inflating: Medmnist/HeadCT/005650.jpeg
#   inflating: Medmnist/HeadCT/005651.jpeg
#   inflating: Medmnist/HeadCT/005652.jpeg
#   inflating: Medmnist/HeadCT/005653.jpeg
#   inflating: Medmnist/HeadCT/005654.jpeg
#   inflating: Medmnist/HeadCT/005655.jpeg
#   inflating: Medmnist/HeadCT/005656.jpeg
#   inflating: Medmnist/HeadCT/005657.jpeg
#   inflating: Medmnist/HeadCT/005658.jpeg
#   inflating: Medmnist/HeadCT/005659.jpeg
#   inflating: Medmnist/HeadCT/005660.jpeg
#   inflating: Medmnist/HeadCT/005661.jpeg
#   inflating: Medmnist/HeadCT/005662.jpeg
#   inflating: Medmnist/HeadCT/005663.jpeg
#   inflating: Medmnist/HeadCT/005664.jpeg
#   inflating: Medmnist/HeadCT/005665.jpeg
#   inflating: Medmnist/HeadCT/005666.jpeg
#   inflating: Medmnist/HeadCT/005667.jpeg
#   inflating: Medmnist/HeadCT/005668.jpeg
#   inflating: Medmnist/HeadCT/005669.jpeg
#   inflating: Medmnist/HeadCT/005670.jpeg
#   inflating: Medmnist/HeadCT/005671.jpeg
#   inflating: Medmnist/HeadCT/005672.jpeg
#   inflating: Medmnist/HeadCT/005673.jpeg
#   inflating: Medmnist/HeadCT/005674.jpeg
#   inflating: Medmnist/HeadCT/005675.jpeg
#   inflating: Medmnist/HeadCT/005676.jpeg
#   inflating: Medmnist/HeadCT/005677.jpeg
#   inflating: Medmnist/HeadCT/005678.jpeg
#   inflating: Medmnist/HeadCT/005679.jpeg
#   inflating: Medmnist/HeadCT/005680.jpeg
#   inflating: Medmnist/HeadCT/005681.jpeg
#   inflating: Medmnist/HeadCT/005682.jpeg
#   inflating: Medmnist/HeadCT/005683.jpeg
#   inflating: Medmnist/HeadCT/005684.jpeg
#   inflating: Medmnist/HeadCT/005685.jpeg
#   inflating: Medmnist/HeadCT/005686.jpeg
#   inflating: Medmnist/HeadCT/005687.jpeg
#   inflating: Medmnist/HeadCT/005688.jpeg
#   inflating: Medmnist/HeadCT/005689.jpeg
#   inflating: Medmnist/HeadCT/005690.jpeg
#   inflating: Medmnist/HeadCT/005691.jpeg
#   inflating: Medmnist/HeadCT/005692.jpeg
#   inflating: Medmnist/HeadCT/005693.jpeg
#   inflating: Medmnist/HeadCT/005694.jpeg
#   inflating: Medmnist/HeadCT/005695.jpeg
#   inflating: Medmnist/HeadCT/005696.jpeg
#   inflating: Medmnist/HeadCT/005697.jpeg
#   inflating: Medmnist/HeadCT/005698.jpeg
#   inflating: Medmnist/HeadCT/005699.jpeg
#   inflating: Medmnist/HeadCT/005700.jpeg
#   inflating: Medmnist/HeadCT/005701.jpeg
#   inflating: Medmnist/HeadCT/005702.jpeg
#   inflating: Medmnist/HeadCT/005703.jpeg
#   inflating: Medmnist/HeadCT/005704.jpeg
#   inflating: Medmnist/HeadCT/005705.jpeg
#   inflating: Medmnist/HeadCT/005706.jpeg
#   inflating: Medmnist/HeadCT/005707.jpeg
#   inflating: Medmnist/HeadCT/005708.jpeg
#   inflating: Medmnist/HeadCT/005709.jpeg
#   inflating: Medmnist/HeadCT/005710.jpeg
#   inflating: Medmnist/HeadCT/005711.jpeg
#   inflating: Medmnist/HeadCT/005712.jpeg
#   inflating: Medmnist/HeadCT/005713.jpeg
#   inflating: Medmnist/HeadCT/005714.jpeg
#   inflating: Medmnist/HeadCT/005715.jpeg
#   inflating: Medmnist/HeadCT/005716.jpeg
#   inflating: Medmnist/HeadCT/005717.jpeg
#   inflating: Medmnist/HeadCT/005718.jpeg
#   inflating: Medmnist/HeadCT/005719.jpeg
#   inflating: Medmnist/HeadCT/005720.jpeg
#   inflating: Medmnist/HeadCT/005721.jpeg
#   inflating: Medmnist/HeadCT/005722.jpeg
#   inflating: Medmnist/HeadCT/005723.jpeg
#   inflating: Medmnist/HeadCT/005724.jpeg
#   inflating: Medmnist/HeadCT/005725.jpeg
#   inflating: Medmnist/HeadCT/005726.jpeg
#   inflating: Medmnist/HeadCT/005727.jpeg
#   inflating: Medmnist/HeadCT/005728.jpeg
#   inflating: Medmnist/HeadCT/005729.jpeg
#   inflating: Medmnist/HeadCT/005730.jpeg
#   inflating: Medmnist/HeadCT/005731.jpeg
#   inflating: Medmnist/HeadCT/005732.jpeg
#   inflating: Medmnist/HeadCT/005733.jpeg
#   inflating: Medmnist/HeadCT/005734.jpeg
#   inflating: Medmnist/HeadCT/005735.jpeg
#   inflating: Medmnist/HeadCT/005736.jpeg
#   inflating: Medmnist/HeadCT/005737.jpeg
#   inflating: Medmnist/HeadCT/005738.jpeg
#   inflating: Medmnist/HeadCT/005739.jpeg
#   inflating: Medmnist/HeadCT/005740.jpeg
#   inflating: Medmnist/HeadCT/005741.jpeg
#   inflating: Medmnist/HeadCT/005742.jpeg
#   inflating: Medmnist/HeadCT/005743.jpeg
#   inflating: Medmnist/HeadCT/005744.jpeg
#   inflating: Medmnist/HeadCT/005745.jpeg
#   inflating: Medmnist/HeadCT/005746.jpeg
#   inflating: Medmnist/HeadCT/005747.jpeg
#   inflating: Medmnist/HeadCT/005748.jpeg
#   inflating: Medmnist/HeadCT/005749.jpeg
#   inflating: Medmnist/HeadCT/005750.jpeg
#   inflating: Medmnist/HeadCT/005751.jpeg
#   inflating: Medmnist/HeadCT/005752.jpeg
#   inflating: Medmnist/HeadCT/005753.jpeg
#   inflating: Medmnist/HeadCT/005754.jpeg
#   inflating: Medmnist/HeadCT/005755.jpeg
#   inflating: Medmnist/HeadCT/005756.jpeg
#   inflating: Medmnist/HeadCT/005757.jpeg
#   inflating: Medmnist/HeadCT/005758.jpeg
#   inflating: Medmnist/HeadCT/005759.jpeg
#   inflating: Medmnist/HeadCT/005760.jpeg
#   inflating: Medmnist/HeadCT/005761.jpeg
#   inflating: Medmnist/HeadCT/005762.jpeg
#   inflating: Medmnist/HeadCT/005763.jpeg
#   inflating: Medmnist/HeadCT/005764.jpeg
#   inflating: Medmnist/HeadCT/005765.jpeg
#   inflating: Medmnist/HeadCT/005766.jpeg
#   inflating: Medmnist/HeadCT/005767.jpeg
#   inflating: Medmnist/HeadCT/005768.jpeg
#   inflating: Medmnist/HeadCT/005769.jpeg
#   inflating: Medmnist/HeadCT/005770.jpeg
#   inflating: Medmnist/HeadCT/005771.jpeg
#   inflating: Medmnist/HeadCT/005772.jpeg
#   inflating: Medmnist/HeadCT/005773.jpeg
#   inflating: Medmnist/HeadCT/005774.jpeg
#   inflating: Medmnist/HeadCT/005775.jpeg
#   inflating: Medmnist/HeadCT/005776.jpeg
#   inflating: Medmnist/HeadCT/005777.jpeg
#   inflating: Medmnist/HeadCT/005778.jpeg
#   inflating: Medmnist/HeadCT/005779.jpeg
#   inflating: Medmnist/HeadCT/005780.jpeg
#   inflating: Medmnist/HeadCT/005781.jpeg
#   inflating: Medmnist/HeadCT/005782.jpeg
#   inflating: Medmnist/HeadCT/005783.jpeg
#   inflating: Medmnist/HeadCT/005784.jpeg
#   inflating: Medmnist/HeadCT/005785.jpeg
#   inflating: Medmnist/HeadCT/005786.jpeg
#   inflating: Medmnist/HeadCT/005787.jpeg
#   inflating: Medmnist/HeadCT/005788.jpeg
#   inflating: Medmnist/HeadCT/005789.jpeg
#   inflating: Medmnist/HeadCT/005790.jpeg
#   inflating: Medmnist/HeadCT/005791.jpeg
#   inflating: Medmnist/HeadCT/005792.jpeg
#   inflating: Medmnist/HeadCT/005793.jpeg
#   inflating: Medmnist/HeadCT/005794.jpeg
#   inflating: Medmnist/HeadCT/005795.jpeg
#   inflating: Medmnist/HeadCT/005796.jpeg
#   inflating: Medmnist/HeadCT/005797.jpeg
#   inflating: Medmnist/HeadCT/005798.jpeg
#   inflating: Medmnist/HeadCT/005799.jpeg
#   inflating: Medmnist/HeadCT/005800.jpeg
#   inflating: Medmnist/HeadCT/005801.jpeg
#   inflating: Medmnist/HeadCT/005802.jpeg
#   inflating: Medmnist/HeadCT/005803.jpeg
#   inflating: Medmnist/HeadCT/005804.jpeg
#   inflating: Medmnist/HeadCT/005805.jpeg
#   inflating: Medmnist/HeadCT/005806.jpeg
#   inflating: Medmnist/HeadCT/005807.jpeg
#   inflating: Medmnist/HeadCT/005808.jpeg
#   inflating: Medmnist/HeadCT/005809.jpeg
#   inflating: Medmnist/HeadCT/005810.jpeg
#   inflating: Medmnist/HeadCT/005811.jpeg
#   inflating: Medmnist/HeadCT/005812.jpeg
#   inflating: Medmnist/HeadCT/005813.jpeg
#   inflating: Medmnist/HeadCT/005814.jpeg
#   inflating: Medmnist/HeadCT/005815.jpeg
#   inflating: Medmnist/HeadCT/005816.jpeg
#   inflating: Medmnist/HeadCT/005817.jpeg
#   inflating: Medmnist/HeadCT/005818.jpeg
#   inflating: Medmnist/HeadCT/005819.jpeg
#   inflating: Medmnist/HeadCT/005820.jpeg
#   inflating: Medmnist/HeadCT/005821.jpeg
#   inflating: Medmnist/HeadCT/005822.jpeg
#   inflating: Medmnist/HeadCT/005823.jpeg
#   inflating: Medmnist/HeadCT/005824.jpeg
#   inflating: Medmnist/HeadCT/005825.jpeg
#   inflating: Medmnist/HeadCT/005826.jpeg
#   inflating: Medmnist/HeadCT/005827.jpeg
#   inflating: Medmnist/HeadCT/005828.jpeg
#   inflating: Medmnist/HeadCT/005829.jpeg
#   inflating: Medmnist/HeadCT/005830.jpeg
#   inflating: Medmnist/HeadCT/005831.jpeg
#   inflating: Medmnist/HeadCT/005832.jpeg
#   inflating: Medmnist/HeadCT/005833.jpeg
#   inflating: Medmnist/HeadCT/005834.jpeg
#   inflating: Medmnist/HeadCT/005835.jpeg
#   inflating: Medmnist/HeadCT/005836.jpeg
#   inflating: Medmnist/HeadCT/005837.jpeg
#   inflating: Medmnist/HeadCT/005838.jpeg
#   inflating: Medmnist/HeadCT/005839.jpeg
#   inflating: Medmnist/HeadCT/005840.jpeg
#   inflating: Medmnist/HeadCT/005841.jpeg
#   inflating: Medmnist/HeadCT/005842.jpeg
#   inflating: Medmnist/HeadCT/005843.jpeg
#   inflating: Medmnist/HeadCT/005844.jpeg
#   inflating: Medmnist/HeadCT/005845.jpeg
#   inflating: Medmnist/HeadCT/005846.jpeg
#   inflating: Medmnist/HeadCT/005847.jpeg
#   inflating: Medmnist/HeadCT/005848.jpeg
#   inflating: Medmnist/HeadCT/005849.jpeg
#   inflating: Medmnist/HeadCT/005850.jpeg
#   inflating: Medmnist/HeadCT/005851.jpeg
#   inflating: Medmnist/HeadCT/005852.jpeg
#   inflating: Medmnist/HeadCT/005853.jpeg
#   inflating: Medmnist/HeadCT/005854.jpeg
#   inflating: Medmnist/HeadCT/005855.jpeg
#   inflating: Medmnist/HeadCT/005856.jpeg
#   inflating: Medmnist/HeadCT/005857.jpeg
#   inflating: Medmnist/HeadCT/005858.jpeg
#   inflating: Medmnist/HeadCT/005859.jpeg
#   inflating: Medmnist/HeadCT/005860.jpeg
#   inflating: Medmnist/HeadCT/005861.jpeg
#   inflating: Medmnist/HeadCT/005862.jpeg
#   inflating: Medmnist/HeadCT/005863.jpeg
#   inflating: Medmnist/HeadCT/005864.jpeg
#   inflating: Medmnist/HeadCT/005865.jpeg
#   inflating: Medmnist/HeadCT/005866.jpeg
#   inflating: Medmnist/HeadCT/005867.jpeg
#   inflating: Medmnist/HeadCT/005868.jpeg
#   inflating: Medmnist/HeadCT/005869.jpeg
#   inflating: Medmnist/HeadCT/005870.jpeg
#   inflating: Medmnist/HeadCT/005871.jpeg
#   inflating: Medmnist/HeadCT/005872.jpeg
#   inflating: Medmnist/HeadCT/005873.jpeg
#   inflating: Medmnist/HeadCT/005874.jpeg
#   inflating: Medmnist/HeadCT/005875.jpeg
#   inflating: Medmnist/HeadCT/005876.jpeg
#   inflating: Medmnist/HeadCT/005877.jpeg
#   inflating: Medmnist/HeadCT/005878.jpeg
#   inflating: Medmnist/HeadCT/005879.jpeg
#   inflating: Medmnist/HeadCT/005880.jpeg
#   inflating: Medmnist/HeadCT/005881.jpeg
#   inflating: Medmnist/HeadCT/005882.jpeg
#   inflating: Medmnist/HeadCT/005883.jpeg
#   inflating: Medmnist/HeadCT/005884.jpeg
#   inflating: Medmnist/HeadCT/005885.jpeg
#   inflating: Medmnist/HeadCT/005886.jpeg
#   inflating: Medmnist/HeadCT/005887.jpeg
#   inflating: Medmnist/HeadCT/005888.jpeg
#   inflating: Medmnist/HeadCT/005889.jpeg
#   inflating: Medmnist/HeadCT/005890.jpeg
#   inflating: Medmnist/HeadCT/005891.jpeg
#   inflating: Medmnist/HeadCT/005892.jpeg
#   inflating: Medmnist/HeadCT/005893.jpeg
#   inflating: Medmnist/HeadCT/005894.jpeg
#   inflating: Medmnist/HeadCT/005895.jpeg
#   inflating: Medmnist/HeadCT/005896.jpeg
#   inflating: Medmnist/HeadCT/005897.jpeg
#   inflating: Medmnist/HeadCT/005898.jpeg
#   inflating: Medmnist/HeadCT/005899.jpeg
#   inflating: Medmnist/HeadCT/005900.jpeg
#   inflating: Medmnist/HeadCT/005901.jpeg
#   inflating: Medmnist/HeadCT/005902.jpeg
#   inflating: Medmnist/HeadCT/005903.jpeg
#   inflating: Medmnist/HeadCT/005904.jpeg
#   inflating: Medmnist/HeadCT/005905.jpeg
#   inflating: Medmnist/HeadCT/005906.jpeg
#   inflating: Medmnist/HeadCT/005907.jpeg
#   inflating: Medmnist/HeadCT/005908.jpeg
#   inflating: Medmnist/HeadCT/005909.jpeg
#   inflating: Medmnist/HeadCT/005910.jpeg
#   inflating: Medmnist/HeadCT/005911.jpeg
#   inflating: Medmnist/HeadCT/005912.jpeg
#   inflating: Medmnist/HeadCT/005913.jpeg
#   inflating: Medmnist/HeadCT/005914.jpeg
#   inflating: Medmnist/HeadCT/005915.jpeg
#   inflating: Medmnist/HeadCT/005916.jpeg
#   inflating: Medmnist/HeadCT/005917.jpeg
#   inflating: Medmnist/HeadCT/005918.jpeg
#   inflating: Medmnist/HeadCT/005919.jpeg
#   inflating: Medmnist/HeadCT/005920.jpeg
#   inflating: Medmnist/HeadCT/005921.jpeg
#   inflating: Medmnist/HeadCT/005922.jpeg
#   inflating: Medmnist/HeadCT/005923.jpeg
#   inflating: Medmnist/HeadCT/005924.jpeg
#   inflating: Medmnist/HeadCT/005925.jpeg
#   inflating: Medmnist/HeadCT/005926.jpeg
#   inflating: Medmnist/HeadCT/005927.jpeg
#   inflating: Medmnist/HeadCT/005928.jpeg
#   inflating: Medmnist/HeadCT/005929.jpeg
#   inflating: Medmnist/HeadCT/005930.jpeg
#   inflating: Medmnist/HeadCT/005931.jpeg
#   inflating: Medmnist/HeadCT/005932.jpeg
#   inflating: Medmnist/HeadCT/005933.jpeg
#   inflating: Medmnist/HeadCT/005934.jpeg
#   inflating: Medmnist/HeadCT/005935.jpeg
#   inflating: Medmnist/HeadCT/005936.jpeg
#   inflating: Medmnist/HeadCT/005937.jpeg
#   inflating: Medmnist/HeadCT/005938.jpeg
#   inflating: Medmnist/HeadCT/005939.jpeg
#   inflating: Medmnist/HeadCT/005940.jpeg
#   inflating: Medmnist/HeadCT/005941.jpeg
#   inflating: Medmnist/HeadCT/005942.jpeg
#   inflating: Medmnist/HeadCT/005943.jpeg
#   inflating: Medmnist/HeadCT/005944.jpeg
#   inflating: Medmnist/HeadCT/005945.jpeg
#   inflating: Medmnist/HeadCT/005946.jpeg
#   inflating: Medmnist/HeadCT/005947.jpeg
#   inflating: Medmnist/HeadCT/005948.jpeg
#   inflating: Medmnist/HeadCT/005949.jpeg
#   inflating: Medmnist/HeadCT/005950.jpeg
#   inflating: Medmnist/HeadCT/005951.jpeg
#   inflating: Medmnist/HeadCT/005952.jpeg
#   inflating: Medmnist/HeadCT/005953.jpeg
#   inflating: Medmnist/HeadCT/005954.jpeg
#   inflating: Medmnist/HeadCT/005955.jpeg
#   inflating: Medmnist/HeadCT/005956.jpeg
#   inflating: Medmnist/HeadCT/005957.jpeg
#   inflating: Medmnist/HeadCT/005958.jpeg
#   inflating: Medmnist/HeadCT/005959.jpeg
#   inflating: Medmnist/HeadCT/005960.jpeg
#   inflating: Medmnist/HeadCT/005961.jpeg
#   inflating: Medmnist/HeadCT/005962.jpeg
#   inflating: Medmnist/HeadCT/005963.jpeg
#   inflating: Medmnist/HeadCT/005964.jpeg
#   inflating: Medmnist/HeadCT/005965.jpeg
#   inflating: Medmnist/HeadCT/005966.jpeg
#   inflating: Medmnist/HeadCT/005967.jpeg
#   inflating: Medmnist/HeadCT/005968.jpeg
#   inflating: Medmnist/HeadCT/005969.jpeg
#   inflating: Medmnist/HeadCT/005970.jpeg
#   inflating: Medmnist/HeadCT/005971.jpeg
#   inflating: Medmnist/HeadCT/005972.jpeg
#   inflating: Medmnist/HeadCT/005973.jpeg
#   inflating: Medmnist/HeadCT/005974.jpeg
#   inflating: Medmnist/HeadCT/005975.jpeg
#   inflating: Medmnist/HeadCT/005976.jpeg
#   inflating: Medmnist/HeadCT/005977.jpeg
#   inflating: Medmnist/HeadCT/005978.jpeg
#   inflating: Medmnist/HeadCT/005979.jpeg
#   inflating: Medmnist/HeadCT/005980.jpeg
#   inflating: Medmnist/HeadCT/005981.jpeg
#   inflating: Medmnist/HeadCT/005982.jpeg
#   inflating: Medmnist/HeadCT/005983.jpeg
#   inflating: Medmnist/HeadCT/005984.jpeg
#   inflating: Medmnist/HeadCT/005985.jpeg
#   inflating: Medmnist/HeadCT/005986.jpeg
#   inflating: Medmnist/HeadCT/005987.jpeg
#   inflating: Medmnist/HeadCT/005988.jpeg
#   inflating: Medmnist/HeadCT/005989.jpeg
#   inflating: Medmnist/HeadCT/005990.jpeg
#   inflating: Medmnist/HeadCT/005991.jpeg
#   inflating: Medmnist/HeadCT/005992.jpeg
#   inflating: Medmnist/HeadCT/005993.jpeg
#   inflating: Medmnist/HeadCT/005994.jpeg
#   inflating: Medmnist/HeadCT/005995.jpeg
#   inflating: Medmnist/HeadCT/005996.jpeg
#   inflating: Medmnist/HeadCT/005997.jpeg
#   inflating: Medmnist/HeadCT/005998.jpeg
#   inflating: Medmnist/HeadCT/005999.jpeg
#   inflating: Medmnist/HeadCT/006000.jpeg
#   inflating: Medmnist/HeadCT/006001.jpeg
#   inflating: Medmnist/HeadCT/006002.jpeg
#   inflating: Medmnist/HeadCT/006003.jpeg
#   inflating: Medmnist/HeadCT/006004.jpeg
#   inflating: Medmnist/HeadCT/006005.jpeg
#   inflating: Medmnist/HeadCT/006006.jpeg
#   inflating: Medmnist/HeadCT/006007.jpeg
#   inflating: Medmnist/HeadCT/006008.jpeg
#   inflating: Medmnist/HeadCT/006009.jpeg
#   inflating: Medmnist/HeadCT/006010.jpeg
#   inflating: Medmnist/HeadCT/006011.jpeg
#   inflating: Medmnist/HeadCT/006012.jpeg
#   inflating: Medmnist/HeadCT/006013.jpeg
#   inflating: Medmnist/HeadCT/006014.jpeg
#   inflating: Medmnist/HeadCT/006015.jpeg
#   inflating: Medmnist/HeadCT/006016.jpeg
#   inflating: Medmnist/HeadCT/006017.jpeg
#   inflating: Medmnist/HeadCT/006018.jpeg
#   inflating: Medmnist/HeadCT/006019.jpeg
#   inflating: Medmnist/HeadCT/006020.jpeg
#   inflating: Medmnist/HeadCT/006021.jpeg
#   inflating: Medmnist/HeadCT/006022.jpeg
#   inflating: Medmnist/HeadCT/006023.jpeg
#   inflating: Medmnist/HeadCT/006024.jpeg
#   inflating: Medmnist/HeadCT/006025.jpeg
#   inflating: Medmnist/HeadCT/006026.jpeg
#   inflating: Medmnist/HeadCT/006027.jpeg
#   inflating: Medmnist/HeadCT/006028.jpeg
#   inflating: Medmnist/HeadCT/006029.jpeg
#   inflating: Medmnist/HeadCT/006030.jpeg
#   inflating: Medmnist/HeadCT/006031.jpeg
#   inflating: Medmnist/HeadCT/006032.jpeg
#   inflating: Medmnist/HeadCT/006033.jpeg
#   inflating: Medmnist/HeadCT/006034.jpeg
#   inflating: Medmnist/HeadCT/006035.jpeg
#   inflating: Medmnist/HeadCT/006036.jpeg
#   inflating: Medmnist/HeadCT/006037.jpeg
#   inflating: Medmnist/HeadCT/006038.jpeg
#   inflating: Medmnist/HeadCT/006039.jpeg
#   inflating: Medmnist/HeadCT/006040.jpeg
#   inflating: Medmnist/HeadCT/006041.jpeg
#   inflating: Medmnist/HeadCT/006042.jpeg
#   inflating: Medmnist/HeadCT/006043.jpeg
#   inflating: Medmnist/HeadCT/006044.jpeg
#   inflating: Medmnist/HeadCT/006045.jpeg
#   inflating: Medmnist/HeadCT/006046.jpeg
#   inflating: Medmnist/HeadCT/006047.jpeg
#   inflating: Medmnist/HeadCT/006048.jpeg
#   inflating: Medmnist/HeadCT/006049.jpeg
#   inflating: Medmnist/HeadCT/006050.jpeg
#   inflating: Medmnist/HeadCT/006051.jpeg
#   inflating: Medmnist/HeadCT/006052.jpeg
#   inflating: Medmnist/HeadCT/006053.jpeg
#   inflating: Medmnist/HeadCT/006054.jpeg
#   inflating: Medmnist/HeadCT/006055.jpeg
#   inflating: Medmnist/HeadCT/006056.jpeg
#   inflating: Medmnist/HeadCT/006057.jpeg
#   inflating: Medmnist/HeadCT/006058.jpeg
#   inflating: Medmnist/HeadCT/006059.jpeg
#   inflating: Medmnist/HeadCT/006060.jpeg
#   inflating: Medmnist/HeadCT/006061.jpeg
#   inflating: Medmnist/HeadCT/006062.jpeg
#   inflating: Medmnist/HeadCT/006063.jpeg
#   inflating: Medmnist/HeadCT/006064.jpeg
#   inflating: Medmnist/HeadCT/006065.jpeg
#   inflating: Medmnist/HeadCT/006066.jpeg
#   inflating: Medmnist/HeadCT/006067.jpeg
#   inflating: Medmnist/HeadCT/006068.jpeg
#   inflating: Medmnist/HeadCT/006069.jpeg
#   inflating: Medmnist/HeadCT/006070.jpeg
#   inflating: Medmnist/HeadCT/006071.jpeg
#   inflating: Medmnist/HeadCT/006072.jpeg
#   inflating: Medmnist/HeadCT/006073.jpeg
#   inflating: Medmnist/HeadCT/006074.jpeg
#   inflating: Medmnist/HeadCT/006075.jpeg
#   inflating: Medmnist/HeadCT/006076.jpeg
#   inflating: Medmnist/HeadCT/006077.jpeg
#   inflating: Medmnist/HeadCT/006078.jpeg
#   inflating: Medmnist/HeadCT/006079.jpeg
#   inflating: Medmnist/HeadCT/006080.jpeg
#   inflating: Medmnist/HeadCT/006081.jpeg
#   inflating: Medmnist/HeadCT/006082.jpeg
#   inflating: Medmnist/HeadCT/006083.jpeg
#   inflating: Medmnist/HeadCT/006084.jpeg
#   inflating: Medmnist/HeadCT/006085.jpeg
#   inflating: Medmnist/HeadCT/006086.jpeg
#   inflating: Medmnist/HeadCT/006087.jpeg
#   inflating: Medmnist/HeadCT/006088.jpeg
#   inflating: Medmnist/HeadCT/006089.jpeg
#   inflating: Medmnist/HeadCT/006090.jpeg
#   inflating: Medmnist/HeadCT/006091.jpeg
#   inflating: Medmnist/HeadCT/006092.jpeg
#   inflating: Medmnist/HeadCT/006093.jpeg
#   inflating: Medmnist/HeadCT/006094.jpeg
#   inflating: Medmnist/HeadCT/006095.jpeg
#   inflating: Medmnist/HeadCT/006096.jpeg
#   inflating: Medmnist/HeadCT/006097.jpeg
#   inflating: Medmnist/HeadCT/006098.jpeg
#   inflating: Medmnist/HeadCT/006099.jpeg
#   inflating: Medmnist/HeadCT/006100.jpeg
#   inflating: Medmnist/HeadCT/006101.jpeg
#   inflating: Medmnist/HeadCT/006102.jpeg
#   inflating: Medmnist/HeadCT/006103.jpeg
#   inflating: Medmnist/HeadCT/006104.jpeg
#   inflating: Medmnist/HeadCT/006105.jpeg
#   inflating: Medmnist/HeadCT/006106.jpeg
#   inflating: Medmnist/HeadCT/006107.jpeg
#   inflating: Medmnist/HeadCT/006108.jpeg
#   inflating: Medmnist/HeadCT/006109.jpeg
#   inflating: Medmnist/HeadCT/006110.jpeg
#   inflating: Medmnist/HeadCT/006111.jpeg
#   inflating: Medmnist/HeadCT/006112.jpeg
#   inflating: Medmnist/HeadCT/006113.jpeg
#   inflating: Medmnist/HeadCT/006114.jpeg
# ...
#   inflating: Medmnist/HeadCT/009628.jpeg
#   inflating: Medmnist/HeadCT/009629.jpeg
#   inflating: Medmnist/HeadCT/009630.jpeg
#   inflating: Medmnist/HeadCT/009631.jpeg
#   inflating: Medmnist/HeadCT/009632.jpeg
#   inflating: Medmnist/HeadCT/009633.jpeg
#   inflating: Medmnist/HeadCT/009634.jpeg
#   inflating: Medmnist/HeadCT/009635.jpeg
#   inflating: Medmnist/HeadCT/009636.jpeg
#   inflating: Medmnist/HeadCT/009637.jpeg
#   inflating: Medmnist/HeadCT/009638.jpeg
#   inflating: Medmnist/HeadCT/009639.jpeg
#   inflating: Medmnist/HeadCT/009640.jpeg
#   inflating: Medmnist/HeadCT/009641.jpeg
#   inflating: Medmnist/HeadCT/009642.jpeg
#   inflating: Medmnist/HeadCT/009643.jpeg
#   inflating: Medmnist/HeadCT/009644.jpeg
#   inflating: Medmnist/HeadCT/009645.jpeg
#   inflating: Medmnist/HeadCT/009646.jpeg
#   inflating: Medmnist/HeadCT/009647.jpeg
#   inflating: Medmnist/HeadCT/009648.jpeg
#   inflating: Medmnist/HeadCT/009649.jpeg
#   inflating: Medmnist/HeadCT/009650.jpeg
#   inflating: Medmnist/HeadCT/009651.jpeg
#   inflating: Medmnist/HeadCT/009652.jpeg
#   inflating: Medmnist/HeadCT/009653.jpeg
#   inflating: Medmnist/HeadCT/009654.jpeg
#   inflating: Medmnist/HeadCT/009655.jpeg
#   inflating: Medmnist/HeadCT/009656.jpeg
#   inflating: Medmnist/HeadCT/009657.jpeg
#   inflating: Medmnist/HeadCT/009658.jpeg
#   inflating: Medmnist/HeadCT/009659.jpeg
#   inflating: Medmnist/HeadCT/009660.jpeg
#   inflating: Medmnist/HeadCT/009661.jpeg
#   inflating: Medmnist/HeadCT/009662.jpeg
#   inflating: Medmnist/HeadCT/009663.jpeg
#   inflating: Medmnist/HeadCT/009664.jpeg
#   inflating: Medmnist/HeadCT/009665.jpeg
#   inflating: Medmnist/HeadCT/009666.jpeg
#   inflating: Medmnist/HeadCT/009667.jpeg
#   inflating: Medmnist/HeadCT/009668.jpeg
#   inflating: Medmnist/HeadCT/009669.jpeg
#   inflating: Medmnist/HeadCT/009670.jpeg
#   inflating: Medmnist/HeadCT/009671.jpeg
#   inflating: Medmnist/HeadCT/009672.jpeg
#   inflating: Medmnist/HeadCT/009673.jpeg
#   inflating: Medmnist/HeadCT/009674.jpeg
#   inflating: Medmnist/HeadCT/009675.jpeg
#   inflating: Medmnist/HeadCT/009676.jpeg
#   inflating: Medmnist/HeadCT/009677.jpeg
#   inflating: Medmnist/HeadCT/009678.jpeg
#   inflating: Medmnist/HeadCT/009679.jpeg
#   inflating: Medmnist/HeadCT/009680.jpeg
#   inflating: Medmnist/HeadCT/009681.jpeg
#   inflating: Medmnist/HeadCT/009682.jpeg
#   inflating: Medmnist/HeadCT/009683.jpeg
#   inflating: Medmnist/HeadCT/009684.jpeg
#   inflating: Medmnist/HeadCT/009685.jpeg
#   inflating: Medmnist/HeadCT/009686.jpeg
#   inflating: Medmnist/HeadCT/009687.jpeg
#   inflating: Medmnist/HeadCT/009688.jpeg
#   inflating: Medmnist/HeadCT/009689.jpeg
#   inflating: Medmnist/HeadCT/009690.jpeg
#   inflating: Medmnist/HeadCT/009691.jpeg
#   inflating: Medmnist/HeadCT/009692.jpeg
#   inflating: Medmnist/HeadCT/009693.jpeg
#   inflating: Medmnist/HeadCT/009694.jpeg
#   inflating: Medmnist/HeadCT/009695.jpeg
#   inflating: Medmnist/HeadCT/009696.jpeg
#   inflating: Medmnist/HeadCT/009697.jpeg
#   inflating: Medmnist/HeadCT/009698.jpeg
#   inflating: Medmnist/HeadCT/009699.jpeg
#   inflating: Medmnist/HeadCT/009700.jpeg
#   inflating: Medmnist/HeadCT/009701.jpeg
#   inflating: Medmnist/HeadCT/009702.jpeg
#   inflating: Medmnist/HeadCT/009703.jpeg
#   inflating: Medmnist/HeadCT/009704.jpeg
#   inflating: Medmnist/HeadCT/009705.jpeg
#   inflating: Medmnist/HeadCT/009706.jpeg
#   inflating: Medmnist/HeadCT/009707.jpeg
#   inflating: Medmnist/HeadCT/009708.jpeg
#   inflating: Medmnist/HeadCT/009709.jpeg
#   inflating: Medmnist/HeadCT/009710.jpeg
#   inflating: Medmnist/HeadCT/009711.jpeg
#   inflating: Medmnist/HeadCT/009712.jpeg
#   inflating: Medmnist/HeadCT/009713.jpeg
#   inflating: Medmnist/HeadCT/009714.jpeg
#   inflating: Medmnist/HeadCT/009715.jpeg
#   inflating: Medmnist/HeadCT/009716.jpeg
#   inflating: Medmnist/HeadCT/009717.jpeg
#   inflating: Medmnist/HeadCT/009718.jpeg
#   inflating: Medmnist/HeadCT/009719.jpeg
#   inflating: Medmnist/HeadCT/009720.jpeg
#   inflating: Medmnist/HeadCT/009721.jpeg
#   inflating: Medmnist/HeadCT/009722.jpeg
#   inflating: Medmnist/HeadCT/009723.jpeg
#   inflating: Medmnist/HeadCT/009724.jpeg
#   inflating: Medmnist/HeadCT/009725.jpeg
#   inflating: Medmnist/HeadCT/009726.jpeg
#   inflating: Medmnist/HeadCT/009727.jpeg
#   inflating: Medmnist/HeadCT/009728.jpeg
#   inflating: Medmnist/HeadCT/009729.jpeg
#   inflating: Medmnist/HeadCT/009730.jpeg
#   inflating: Medmnist/HeadCT/009731.jpeg
#   inflating: Medmnist/HeadCT/009732.jpeg
#   inflating: Medmnist/HeadCT/009733.jpeg
#   inflating: Medmnist/HeadCT/009734.jpeg
#   inflating: Medmnist/HeadCT/009735.jpeg
#   inflating: Medmnist/HeadCT/009736.jpeg
#   inflating: Medmnist/HeadCT/009737.jpeg
#   inflating: Medmnist/HeadCT/009738.jpeg
#   inflating: Medmnist/HeadCT/009739.jpeg
#   inflating: Medmnist/HeadCT/009740.jpeg
#   inflating: Medmnist/HeadCT/009741.jpeg
#   inflating: Medmnist/HeadCT/009742.jpeg
#   inflating: Medmnist/HeadCT/009743.jpeg
#   inflating: Medmnist/HeadCT/009744.jpeg
#   inflating: Medmnist/HeadCT/009745.jpeg
#   inflating: Medmnist/HeadCT/009746.jpeg
#   inflating: Medmnist/HeadCT/009747.jpeg
#   inflating: Medmnist/HeadCT/009748.jpeg
#   inflating: Medmnist/HeadCT/009749.jpeg
#   inflating: Medmnist/HeadCT/009750.jpeg
#   inflating: Medmnist/HeadCT/009751.jpeg
#   inflating: Medmnist/HeadCT/009752.jpeg
#   inflating: Medmnist/HeadCT/009753.jpeg
#   inflating: Medmnist/HeadCT/009754.jpeg
#   inflating: Medmnist/HeadCT/009755.jpeg
#   inflating: Medmnist/HeadCT/009756.jpeg
#   inflating: Medmnist/HeadCT/009757.jpeg
#   inflating: Medmnist/HeadCT/009758.jpeg
#   inflating: Medmnist/HeadCT/009759.jpeg
#   inflating: Medmnist/HeadCT/009760.jpeg
#   inflating: Medmnist/HeadCT/009761.jpeg
#   inflating: Medmnist/HeadCT/009762.jpeg
#   inflating: Medmnist/HeadCT/009763.jpeg
#   inflating: Medmnist/HeadCT/009764.jpeg
#   inflating: Medmnist/HeadCT/009765.jpeg
#   inflating: Medmnist/HeadCT/009766.jpeg
#   inflating: Medmnist/HeadCT/009767.jpeg
#   inflating: Medmnist/HeadCT/009768.jpeg
#   inflating: Medmnist/HeadCT/009769.jpeg
#   inflating: Medmnist/HeadCT/009770.jpeg
#   inflating: Medmnist/HeadCT/009771.jpeg
#   inflating: Medmnist/HeadCT/009772.jpeg
#   inflating: Medmnist/HeadCT/009773.jpeg
#   inflating: Medmnist/HeadCT/009774.jpeg
#   inflating: Medmnist/HeadCT/009775.jpeg
#   inflating: Medmnist/HeadCT/009776.jpeg
#   inflating: Medmnist/HeadCT/009777.jpeg
#   inflating: Medmnist/HeadCT/009778.jpeg
#   inflating: Medmnist/HeadCT/009779.jpeg
#   inflating: Medmnist/HeadCT/009780.jpeg
#   inflating: Medmnist/HeadCT/009781.jpeg
#   inflating: Medmnist/HeadCT/009782.jpeg
#   inflating: Medmnist/HeadCT/009783.jpeg
#   inflating: Medmnist/HeadCT/009784.jpeg
#   inflating: Medmnist/HeadCT/009785.jpeg
#   inflating: Medmnist/HeadCT/009786.jpeg
#   inflating: Medmnist/HeadCT/009787.jpeg
#   inflating: Medmnist/HeadCT/009788.jpeg
#   inflating: Medmnist/HeadCT/009789.jpeg
#   inflating: Medmnist/HeadCT/009790.jpeg
#   inflating: Medmnist/HeadCT/009791.jpeg
#   inflating: Medmnist/HeadCT/009792.jpeg
#   inflating: Medmnist/HeadCT/009793.jpeg
#   inflating: Medmnist/HeadCT/009794.jpeg
#   inflating: Medmnist/HeadCT/009795.jpeg
#   inflating: Medmnist/HeadCT/009796.jpeg
#   inflating: Medmnist/HeadCT/009797.jpeg
#   inflating: Medmnist/HeadCT/009798.jpeg
#   inflating: Medmnist/HeadCT/009799.jpeg
#   inflating: Medmnist/HeadCT/009800.jpeg
#   inflating: Medmnist/HeadCT/009801.jpeg
#   inflating: Medmnist/HeadCT/009802.jpeg
#   inflating: Medmnist/HeadCT/009803.jpeg
#   inflating: Medmnist/HeadCT/009804.jpeg
#   inflating: Medmnist/HeadCT/009805.jpeg
#   inflating: Medmnist/HeadCT/009806.jpeg
#   inflating: Medmnist/HeadCT/009807.jpeg
#   inflating: Medmnist/HeadCT/009808.jpeg
#   inflating: Medmnist/HeadCT/009809.jpeg
#   inflating: Medmnist/HeadCT/009810.jpeg
#   inflating: Medmnist/HeadCT/009811.jpeg
#   inflating: Medmnist/HeadCT/009812.jpeg
#   inflating: Medmnist/HeadCT/009813.jpeg
#   inflating: Medmnist/HeadCT/009814.jpeg
#   inflating: Medmnist/HeadCT/009815.jpeg
#   inflating: Medmnist/HeadCT/009816.jpeg
#   inflating: Medmnist/HeadCT/009817.jpeg
#   inflating: Medmnist/HeadCT/009818.jpeg
#   inflating: Medmnist/HeadCT/009819.jpeg
#   inflating: Medmnist/HeadCT/009820.jpeg
#   inflating: Medmnist/HeadCT/009821.jpeg
#   inflating: Medmnist/HeadCT/009822.jpeg
#   inflating: Medmnist/HeadCT/009823.jpeg
#   inflating: Medmnist/HeadCT/009824.jpeg
#   inflating: Medmnist/HeadCT/009825.jpeg
#   inflating: Medmnist/HeadCT/009826.jpeg
#   inflating: Medmnist/HeadCT/009827.jpeg
#   inflating: Medmnist/HeadCT/009828.jpeg
#   inflating: Medmnist/HeadCT/009829.jpeg
#   inflating: Medmnist/HeadCT/009830.jpeg
#   inflating: Medmnist/HeadCT/009831.jpeg
#   inflating: Medmnist/HeadCT/009832.jpeg
#   inflating: Medmnist/HeadCT/009833.jpeg
#   inflating: Medmnist/HeadCT/009834.jpeg
#   inflating: Medmnist/HeadCT/009835.jpeg
#   inflating: Medmnist/HeadCT/009836.jpeg
#   inflating: Medmnist/HeadCT/009837.jpeg
#   inflating: Medmnist/HeadCT/009838.jpeg
#   inflating: Medmnist/HeadCT/009839.jpeg
#   inflating: Medmnist/HeadCT/009840.jpeg
#   inflating: Medmnist/HeadCT/009841.jpeg
#   inflating: Medmnist/HeadCT/009842.jpeg
#   inflating: Medmnist/HeadCT/009843.jpeg
#   inflating: Medmnist/HeadCT/009844.jpeg
#   inflating: Medmnist/HeadCT/009845.jpeg
#   inflating: Medmnist/HeadCT/009846.jpeg
#   inflating: Medmnist/HeadCT/009847.jpeg
#   inflating: Medmnist/HeadCT/009848.jpeg
#   inflating: Medmnist/HeadCT/009849.jpeg
#   inflating: Medmnist/HeadCT/009850.jpeg
#   inflating: Medmnist/HeadCT/009851.jpeg
#   inflating: Medmnist/HeadCT/009852.jpeg
#   inflating: Medmnist/HeadCT/009853.jpeg
#   inflating: Medmnist/HeadCT/009854.jpeg
#   inflating: Medmnist/HeadCT/009855.jpeg
#   inflating: Medmnist/HeadCT/009856.jpeg
#   inflating: Medmnist/HeadCT/009857.jpeg
#   inflating: Medmnist/HeadCT/009858.jpeg
#   inflating: Medmnist/HeadCT/009859.jpeg
#   inflating: Medmnist/HeadCT/009860.jpeg
#   inflating: Medmnist/HeadCT/009861.jpeg
#   inflating: Medmnist/HeadCT/009862.jpeg
#   inflating: Medmnist/HeadCT/009863.jpeg
#   inflating: Medmnist/HeadCT/009864.jpeg
#   inflating: Medmnist/HeadCT/009865.jpeg
#   inflating: Medmnist/HeadCT/009866.jpeg
#   inflating: Medmnist/HeadCT/009867.jpeg
#   inflating: Medmnist/HeadCT/009868.jpeg
#   inflating: Medmnist/HeadCT/009869.jpeg
#   inflating: Medmnist/HeadCT/009870.jpeg
#   inflating: Medmnist/HeadCT/009871.jpeg
#   inflating: Medmnist/HeadCT/009872.jpeg
#   inflating: Medmnist/HeadCT/009873.jpeg
#   inflating: Medmnist/HeadCT/009874.jpeg
#   inflating: Medmnist/HeadCT/009875.jpeg
#   inflating: Medmnist/HeadCT/009876.jpeg
#   inflating: Medmnist/HeadCT/009877.jpeg
#   inflating: Medmnist/HeadCT/009878.jpeg
#   inflating: Medmnist/HeadCT/009879.jpeg
#   inflating: Medmnist/HeadCT/009880.jpeg
#   inflating: Medmnist/HeadCT/009881.jpeg
#   inflating: Medmnist/HeadCT/009882.jpeg
#   inflating: Medmnist/HeadCT/009883.jpeg
#   inflating: Medmnist/HeadCT/009884.jpeg
#   inflating: Medmnist/HeadCT/009885.jpeg
#   inflating: Medmnist/HeadCT/009886.jpeg
#   inflating: Medmnist/HeadCT/009887.jpeg
#   inflating: Medmnist/HeadCT/009888.jpeg
#   inflating: Medmnist/HeadCT/009889.jpeg
#   inflating: Medmnist/HeadCT/009890.jpeg
#   inflating: Medmnist/HeadCT/009891.jpeg
#   inflating: Medmnist/HeadCT/009892.jpeg
#   inflating: Medmnist/HeadCT/009893.jpeg
#   inflating: Medmnist/HeadCT/009894.jpeg
#   inflating: Medmnist/HeadCT/009895.jpeg
#   inflating: Medmnist/HeadCT/009896.jpeg
#   inflating: Medmnist/HeadCT/009897.jpeg
#   inflating: Medmnist/HeadCT/009898.jpeg
#   inflating: Medmnist/HeadCT/009899.jpeg
#   inflating: Medmnist/HeadCT/009900.jpeg
#   inflating: Medmnist/HeadCT/009901.jpeg
#   inflating: Medmnist/HeadCT/009902.jpeg
#   inflating: Medmnist/HeadCT/009903.jpeg
#   inflating: Medmnist/HeadCT/009904.jpeg
#   inflating: Medmnist/HeadCT/009905.jpeg
#   inflating: Medmnist/HeadCT/009906.jpeg
#   inflating: Medmnist/HeadCT/009907.jpeg
#   inflating: Medmnist/HeadCT/009908.jpeg
#   inflating: Medmnist/HeadCT/009909.jpeg
#   inflating: Medmnist/HeadCT/009910.jpeg
#   inflating: Medmnist/HeadCT/009911.jpeg
#   inflating: Medmnist/HeadCT/009912.jpeg
#   inflating: Medmnist/HeadCT/009913.jpeg
#   inflating: Medmnist/HeadCT/009914.jpeg
#   inflating: Medmnist/HeadCT/009915.jpeg
#   inflating: Medmnist/HeadCT/009916.jpeg
#   inflating: Medmnist/HeadCT/009917.jpeg
#   inflating: Medmnist/HeadCT/009918.jpeg
#   inflating: Medmnist/HeadCT/009919.jpeg
#   inflating: Medmnist/HeadCT/009920.jpeg
#   inflating: Medmnist/HeadCT/009921.jpeg
#   inflating: Medmnist/HeadCT/009922.jpeg
#   inflating: Medmnist/HeadCT/009923.jpeg
#   inflating: Medmnist/HeadCT/009924.jpeg
#   inflating: Medmnist/HeadCT/009925.jpeg
#   inflating: Medmnist/HeadCT/009926.jpeg
#   inflating: Medmnist/HeadCT/009927.jpeg
#   inflating: Medmnist/HeadCT/009928.jpeg
#   inflating: Medmnist/HeadCT/009929.jpeg
#   inflating: Medmnist/HeadCT/009930.jpeg
#   inflating: Medmnist/HeadCT/009931.jpeg
#   inflating: Medmnist/HeadCT/009932.jpeg
#   inflating: Medmnist/HeadCT/009933.jpeg
#   inflating: Medmnist/HeadCT/009934.jpeg
#   inflating: Medmnist/HeadCT/009935.jpeg
#   inflating: Medmnist/HeadCT/009936.jpeg
#   inflating: Medmnist/HeadCT/009937.jpeg
#   inflating: Medmnist/HeadCT/009938.jpeg
#   inflating: Medmnist/HeadCT/009939.jpeg
#   inflating: Medmnist/HeadCT/009940.jpeg
#   inflating: Medmnist/HeadCT/009941.jpeg
#   inflating: Medmnist/HeadCT/009942.jpeg
#   inflating: Medmnist/HeadCT/009943.jpeg
#   inflating: Medmnist/HeadCT/009944.jpeg
#   inflating: Medmnist/HeadCT/009945.jpeg
#   inflating: Medmnist/HeadCT/009946.jpeg
#   inflating: Medmnist/HeadCT/009947.jpeg
#   inflating: Medmnist/HeadCT/009948.jpeg
#   inflating: Medmnist/HeadCT/009949.jpeg
#   inflating: Medmnist/HeadCT/009950.jpeg
#   inflating: Medmnist/HeadCT/009951.jpeg
#   inflating: Medmnist/HeadCT/009952.jpeg
#   inflating: Medmnist/HeadCT/009953.jpeg
#   inflating: Medmnist/HeadCT/009954.jpeg
#   inflating: Medmnist/HeadCT/009955.jpeg
#   inflating: Medmnist/HeadCT/009956.jpeg
#   inflating: Medmnist/HeadCT/009957.jpeg
#   inflating: Medmnist/HeadCT/009958.jpeg
#   inflating: Medmnist/HeadCT/009959.jpeg
#   inflating: Medmnist/HeadCT/009960.jpeg
#   inflating: Medmnist/HeadCT/009961.jpeg
#   inflating: Medmnist/HeadCT/009962.jpeg
#   inflating: Medmnist/HeadCT/009963.jpeg
#   inflating: Medmnist/HeadCT/009964.jpeg
#   inflating: Medmnist/HeadCT/009965.jpeg
#   inflating: Medmnist/HeadCT/009966.jpeg
#   inflating: Medmnist/HeadCT/009967.jpeg
#   inflating: Medmnist/HeadCT/009968.jpeg
#   inflating: Medmnist/HeadCT/009969.jpeg
#   inflating: Medmnist/HeadCT/009970.jpeg
#   inflating: Medmnist/HeadCT/009971.jpeg
#   inflating: Medmnist/HeadCT/009972.jpeg
#   inflating: Medmnist/HeadCT/009973.jpeg
#   inflating: Medmnist/HeadCT/009974.jpeg
#   inflating: Medmnist/HeadCT/009975.jpeg
#   inflating: Medmnist/HeadCT/009976.jpeg
#   inflating: Medmnist/HeadCT/009977.jpeg
#   inflating: Medmnist/HeadCT/009978.jpeg
#   inflating: Medmnist/HeadCT/009979.jpeg
#   inflating: Medmnist/HeadCT/009980.jpeg
#   inflating: Medmnist/HeadCT/009981.jpeg
#   inflating: Medmnist/HeadCT/009982.jpeg
#   inflating: Medmnist/HeadCT/009983.jpeg
#   inflating: Medmnist/HeadCT/009984.jpeg
#   inflating: Medmnist/HeadCT/009985.jpeg
#   inflating: Medmnist/HeadCT/009986.jpeg
#   inflating: Medmnist/HeadCT/009987.jpeg
#   inflating: Medmnist/HeadCT/009988.jpeg
#   inflating: Medmnist/HeadCT/009989.jpeg
#   inflating: Medmnist/HeadCT/009990.jpeg
#   inflating: Medmnist/HeadCT/009991.jpeg
#   inflating: Medmnist/HeadCT/009992.jpeg
#   inflating: Medmnist/HeadCT/009993.jpeg
#   inflating: Medmnist/HeadCT/009994.jpeg
#   inflating: Medmnist/HeadCT/009995.jpeg
#   inflating: Medmnist/HeadCT/009996.jpeg
#   inflating: Medmnist/HeadCT/009997.jpeg
#   inflating: Medmnist/HeadCT/009998.jpeg
#   inflating: Medmnist/HeadCT/009999.jpeg

# %% [markdown]
# Now, let us futher look into some details of the data.

# %%
dataDir =  '/content/Medmnist'             # The main data directory
classNames = os.listdir(dataDir)  # Each type of image can be found in its own subdirectory
numClass = len(classNames)        # Number of types = number of subdirectories
imageFiles = [[os.path.join(dataDir,classNames[i],x) for x in os.listdir(os.path.join(dataDir,classNames[i]))]
              for i in range(numClass)]                     # A nested list of filenames
numEach = [len(imageFiles[i]) for i in range(numClass)]     # A count of each type of image
imageFilesList = []               # Created an un-nested list of filenames
imageClass = []                   # The labels -- the type of each individual image in the list
for i in range(numClass):
    imageFilesList.extend(imageFiles[i])
    imageClass.extend([i]*numEach[i])
numTotal = len(imageClass)        # Total number of images
imageWidth, imageHeight = Image.open(imageFilesList[0]).size         # The dimensions of each image

print("There are",numTotal,"images in",numClass,"distinct categories")
print("Label names:",classNames)
print("Label counts:",numEach)
print("Image dimensions:",imageWidth,"x",imageHeight)
# Out:
# There are 58954 images in 6 distinct categories
# Label names: ['Hand', 'HeadCT', 'CXR', 'ChestCT', 'BreastMRI', 'AbdomenCT']
# Label counts: [10000, 10000, 10000, 10000, 8954, 10000]
# Image dimensions: 64 x 64

# %% [markdown]
# Because it is comparable to the <a href="http://yann.lecun.com/exdb/mnist/">MNIST dataset</a>, which has 70,000 total 28 x 28 images of handwritten digits from 0 - 9, we call this the MedNIST dataset. Notice, however, that the data aren't perfectly balanced. We'll address that while training the model.
#
# As the saying goes, a picture is worth 1,000 ± 32 statistics, so let's examine a few random sample images. The following cell can be run repeatedly.

# %%
mp.subplots(3,3,figsize=(8,8))
for i,k in enumerate(np.random.randint(numTotal, size=9)):  # Take a random sample of 9 images and
    im = Image.open(imageFilesList[k])                      #      plot and label them
    arr = np.array(im)
    mp.subplot(3,3,i+1)
    mp.xlabel(classNames[imageClass[k]])
    mp.imshow(arr,cmap='gray',vmin=0,vmax=255)
mp.tight_layout()
mp.show()

# %% [markdown]
# ### Transforming Data and Partitioning into Training, Validation, and Testing Sets
#
# Depending on the images shown, you may notice a few things. There are definitely higher and lower quality images. Also, some images also have a different scale - the background isn't black but gray. Because there's a smaller difference between pixels, our model might have a harder time extracting information from them. Thus, to increase the contrast, we first rescale every image so the pixel values run from 0 to 1.
#
# Next, we subtract the mean pixel value of each individual image from the rest. The network could in principle learn to do this through training. However, the activation functions tend to be most sensitive / nonlinear near zero. Therefore, shifting our data to have an average input value of zero will improve the sensitivity and stability of initial training steps and tends to speed things up a little. While it doesn't matter much for the simple model we use here, such tricks can make a noticeable difference in complex models.
#
# Also, before doing any of these, we'll need to convert the JPEG images into tensors. We define a function below that combines all these steps.

# %%
toTensor = tv.transforms.ToTensor()
def scaleImage(x):          # Pass a PIL image, return a tensor
    y = toTensor(x)
    if(y.min() < y.max()):  # Assuming the image isn't empty, rescale so its values run from 0 to 1
        y = (y - y.min())/(y.max() - y.min())
    z = y - y.mean()        # Subtract the mean value of the image
    return z

# %% [markdown]
# With the image-to-tensor transformation function defined, we now create a master tensor out of all these images. We also create a tensor for the labels. Execution of this code takes a moment. We double check the final range of scaled pixel values and verify that the mean is (practically) zero.

# %%
imageTensor = torch.stack([scaleImage(Image.open(x)) for x in imageFilesList])  # Load, scale, and stack image (X) tensor
classTensor = torch.tensor(imageClass)  # Create label (Y) tensor
print("Rescaled min pixel value = {:1.3}; Max = {:1.3}; Mean = {:1.3}"
      .format(imageTensor.min().item(),imageTensor.max().item(),imageTensor.mean().item()))
# Out:
# Rescaled min pixel value = -0.786; Max = 0.972; Mean = -2.98e-09

# %% [markdown]
# With everything in order so far, we move on to partitioning these master tensors into three datatsets.
#
# Because a model may have millions of free parameters, it is quite possible for it to <em>overfit</em> to the data provided. That is, it may adjust its weights to the precise values needed to predict every given image correctly, yet fail to recognize even slight variations on the original images, let alone brand new ones.
#
# A common solution is to separate data into a training set, used to minimize the loss function, and a validation set, evaluated separately during training without directly affecting the model's weights. However, the validation set may be used to modify the <em>hyperparameters</em> (parameters outside the model governing its training), select the best model every epoch, or indirectly impact the training in some other way. For this reason, a third, independent testing set is usually created for final evaluation once the training is complete.
#
# Because the more data the model sees, the more accurate it tends to become, we usually reserve relatively small fractions for validation and testing.
#
# PyTorch has a built in <a href="https://pytorch.org/docs/stable/_modules/torch/utils/data/dataset.html">Dataset</a> object that can simplify these steps when working with more complex types of data, but in this case, they would require more effort than they save.
#
# The code below will randomly assign approximately 10% of the indices to lists corresponding to the validation and testing sets. Once this is done, we can create these datasets by slicing the master image and label tensors using these lists.

# %%
validFrac = 0.1   # Define the fraction of images to move to validation dataset
testFrac = 0.1    # Define the fraction of images to move to test dataset
validList = []
testList = []
trainList = []

for i in range(numTotal):
    rann = np.random.random() # Randomly reassign images
    if rann < validFrac:
        validList.append(i)
    elif rann < testFrac + validFrac:
        testList.append(i)
    else:
        trainList.append(i)

nTrain = len(trainList)  # Count the number in each set
nValid = len(validList)
nTest = len(testList)
print("Training images =",nTrain,"Validation =",nValid,"Testing =",nTest)
# Out:
# Training images = 47381 Validation = 5833 Testing = 5740

# %% [markdown]
# If we're satisfied with the breakdown into training, validation, and testing, we can now use these lists to slice the master tensors with the code below. If not, we can rerun the cell above with different fractions set aside.

# %%
trainIds = torch.tensor(trainList)    # Slice the big image and label tensors up into
validIds = torch.tensor(validList)    #       training, validation, and testing tensors
testIds = torch.tensor(testList)
trainX = imageTensor[trainIds,:,:,:]
trainY = classTensor[trainIds]
validX = imageTensor[validIds,:,:,:]
validY = classTensor[validIds]
testX = imageTensor[testIds,:,:,:]
testY = classTensor[testIds]

# %% [markdown]
# ### Model Architecture
#
# The details of the architecture are explained in the comments within the code, but here we give an overview of the two types of layers encountered.
#
# The first is the <em>convolutional</em> layer. When interpreting an image, the eye first identifies edges and boundaries. Then, one can make out curves, shapes, and more complex structures at higher levels of abstraction. By only combining information from nearby pixels at first, a series of convolutional layers mimics this organic process. The size of the convolution is how many adjacent pixels are weighted and added up when moving to the next layer, and we can apply multiple convolutions to every pixel in an image (or in a higher layer). Pictured below is a single 3 × 3 convolution. The value of each pixel of the convolutional kernel - these are the weights that are trained - is multiplied with the corresponding pixel value within the neighborhood of the original, central image pixel. These products are summed up, and the total is placed in the central pixel (node, to use the nomenclature) of the new layer. The process is repeated for each pixel and each convolution within the layer. Several convolutional layers can be stacked on top of each other; this has the effect of finding increasingly complex features.
#
# ![CNN_kernel.png](data:image/png;base64,...)

# %% [markdown]
# After several convolutional layers, it is typical to have a few fully connected layers. First, all the information from the last layer is "flattened" into a vector. In a fully connected layer, there are weights connecting every single node (place to store a value) of the input layer to every single node of the output layer - no special preference is given to neighboring nodes as in the pixels of a convolutional layer. The weights multiply the values in the nodes of the input layer, are summed together, and then placed in a node of the output layer. This is repeated for each node in the output layer.
#
# Now, there is one additional step in each of these that has been omitted: appication of the activation function. If the linear function `y = 3x + 2` is composed with `z = 4y - 7`, then z is still a linear function of x: `z = 12x + 1`. The same thing is true for linear functions in higher dimensions (multiplication by weights and summing, as we have been doing). Without the activation function, no matter how many layers we stack together, it could ultimately be replaced by a single one. To avoid this, at each output layer, we apply a nonlinear activation function. This need not be the same function at every layer. In this architecture, we choose a functions,  <a href="https://en.wikipedia.org/wiki/Rectifier_(neural_networks)">ReLU</a>.

# %%
class MedNet(nn.Module):
    def __init__(self,xDim,yDim,numC): # Pass image dimensions and number of labels when initializing a model
        super(MedNet,self).__init__()  # Extends the basic nn.Module to the MedNet class
        # The parameters here define the architecture of the convolutional portion of the CNN. Each image pixel
        # has numConvs convolutions applied to it, and convSize is the number of surrounding pixels included
        # in each convolution. Lastly, the numNodesToFC formula calculates the final, remaining nodes at the last
        # level of convolutions so that this can be "flattened" and fed into the fully connected layers subsequently.
        # Each convolution makes the image a little smaller (convolutions do not, by default, "hang over" the edges
        # of the image), and this makes the effective image dimension decreases.

        numConvs1 = 5
        convSize1 = 7
        numConvs2 = 10
        convSize2 = 7
        numNodesToFC = numConvs2*(xDim-(convSize1-1)-(convSize2-1))*(yDim-(convSize1-1)-(convSize2-1))

        # nn.Conv2d(channels in, channels out, convolution height/width)
        # 1 channel -- grayscale -- feeds into the first convolution. The same number output from one layer must be
        # fed into the next. These variables actually store the weights between layers for the model.

        self.cnv1 = nn.Conv2d(1, numConvs1, convSize1)
        self.cnv2 = nn.Conv2d(numConvs1, numConvs2, convSize2)

        # These parameters define the number of output nodes of each fully connected layer.
        # Each layer must output the same number of nodes as the next layer begins with.
        # The final layer must have output nodes equal to the number of labels used.

        fcSize1 = 400
        fcSize2 = 80

        # nn.Linear(nodes in, nodes out)
        # Stores the weights between the fully connected layers

        self.ful1 = nn.Linear(numNodesToFC,fcSize1)
        self.ful2 = nn.Linear(fcSize1, fcSize2)
        self.ful3 = nn.Linear(fcSize2,numC)

    def forward(self,x):
        # This defines the steps used in the computation of output from input.
        # It makes uses of the weights defined in the __init__ method.
        # Each assignment of x here is the result of feeding the input up through one layer.
        # Here we use the activation function elu, which is a smoother version of the popular relu function.

        x = F.relu(self.cnv1(x)) # Feed through first convolutional layer, then apply activation
        x = F.relu(self.cnv2(x)) # Feed through second convolutional layer, apply activation
        x = x.view(-1,self.num_flat_features(x)) # Flatten convolutional layer into fully connected layer
        x = F.relu(self.ful1(x)) # Feed through first fully connected layer, apply activation
        x = F.relu(self.ful2(x)) # Feed through second FC layer, apply output
        x = self.ful3(x)        # Final FC layer to output. No activation, because it's used to calculate loss
        return x

    def num_flat_features(self, x):  # Count the individual nodes in a layer
        size = x.size()[1:]
        num_features = 1
        for s in size:
            num_features *= s
        return num_features

# %% [markdown]
# With the architecture defined, we create an instance of the model. This single line is separated out so that we can continue or repeat the training code below without resetting the model from scratch, if needed.

# %%
model = MedNet(imageWidth,imageHeight,numClass).to(dev)

# %% [markdown]
# ### Training the Model
#
# Now, it's time to train the model. The next code block does so.
#
# First, we define the hyperparameters of the training. The learning rate reflects how much the model is updated per batch. If it is too small, the training proceeds slowly. If it's too large, the weights will be adjusted too much and miss the true minimum loss, or even become unstable. An epoch is a full run through the training data. Some models require thousands of epochs to train; this one will produce high accuracy with just a handful.
#
# We use validation data to prevent overtraining in our model. The training and validation data are drawn from the same set of data; therefore, the model ought to have similar loss for both. Thus, we set a limit on how much larger the validation loss can be than the training loss. Because random fluctuation might account for some discrepancy, we require a few epochs pass with high validation loss before halting.
#
# The memory overhead required to feed large datasets through the model can be prohibitive. <em>Batches</em> are an important workaround for this problem. By loading smaller data subsets onto the GPU and training off of them, we can not only save memory, but also speed up the training by making more adjustments to the model per epoch. Smaller batches generally require smaller learning rates to avoid instability, however, so there is some tradeoff.
#
# Imagine that a dataset had only a handful of examples of a particular label. The model could still acheive high accuracy overall while totally ignoring these. Using weights in the loss function, with larger weights for less numerous classes, is one strategy to combat this. If a class is particularly tiny, however, it is preferable to use data augmentation to generate new images rather than using weights alone, which are equivalent to feeding the same image over and over again through the network.
#
# Now, we move on to the actual training loop. The first real step is to shuffle the data before slicing it into batches. Once again, PyTorch provides a <a href="https://pytorch.org/docs/stable/_modules/torch/utils/data/dataloader.html#DataLoader">DataLoader</a> class that can automate this, but it's about the same difficulty in this example to implement by hand.
#
# Next, we iterate through the batches. We zero out the accumulated information in the optimizer, feed the batch through the model, and compute the loss for a batch. We use the <a href="https://en.wikipedia.org/wiki/Cross_entropy">cross entropy</a>, a common metric for classifiers. This loss is added to a running total for the epoch, and then we <em>backpropagate</em> it. Backpropagation is a mathematical determination of how much each weight in the model should be changed relative to the others to reduce the loss. The optimizer then takes a step and updates the weights.
#
# After all the training batches are complete, the same process happens for the validation data, without the backpropagation and optimization steps. The average loss is calculated, and we compare the validation loss relative to the training loss to test for overfitting.
#
# Run the cell to train the model.

# %%
learnRate = 0.01          # Define a learning rate.
maxEpochs = 20            # Maximum training epochs
t2vRatio = 1.2            # Maximum allowed ratio of validation to training loss
t2vEpochs = 3             # Number of consecutive epochs before halting if validation loss exceeds above limit
batchSize = 300           # Batch size. Going too large will cause an out-of-memory error.
trainBats = nTrain // batchSize       # Number of training batches per epoch. Round down to simplify last batch
validBats = nValid // batchSize       # Validation batches. Round down
testBats = -(-nTest // batchSize)     # Testing batches. Round up to include all
CEweights = torch.zeros(numClass)     # This takes into account the imbalanced dataset.
for i in trainY.tolist():             #      By making rarer images count more to the loss,
    CEweights[i].add_(1)              #      we prevent the model from ignoring them.
CEweights = 1. / CEweights.clamp_(min=1.)                     # Weights should be inversely related to count
CEweights = (CEweights * numClass / CEweights.sum()).to(dev)  # The weights average to 1
opti = om.SGD(model.parameters(), lr = learnRate)   # Initialize an optimizer


for i in range(maxEpochs):
    model.train()                     # Set model to training mode
    epochLoss = 0.
    permute = torch.randperm(nTrain)  # Shuffle data to randomize batches
    trainX = trainX[permute,:,:,:]
    trainY = trainY[permute]
    for j in range(trainBats):        # Iterate over batches
        opti.zero_grad()              # Zero out gradient accumulated in optimizer
        batX = trainX[j*batchSize:(j+1)*batchSize,:,:,:].to(dev)   # Slice shuffled data into batches
        batY = trainY[j*batchSize:(j+1)*batchSize].to(dev)         # .to(dev) moves these batches to the GPU
        yOut = model(batX)            # Evalute predictions
        loss = F.cross_entropy(yOut, batY,weight=CEweights)        # Compute loss
        epochLoss += loss.item()      # Add loss
        loss.backward()               # Backpropagate loss
        opti.step()                   # Update model weights using optimizer
    validLoss = 0.
    permute = torch.randperm(nValid)  # We go through the exact same steps, without backprop / optimization
    validX = validX[permute,:,:,:]    # in order to evaluate the validation loss
    validY = validY[permute]
    model.eval()                      # Set model to evaluation mode
    with torch.no_grad():             # Temporarily turn off gradient descent
        for j in range(validBats):
            opti.zero_grad()
            batX = validX[j*batchSize:(j+1)*batchSize,:,:,:].to(dev)
            batY = validY[j*batchSize:(j+1)*batchSize].to(dev)
            yOut = model(batX)
            validLoss += F.cross_entropy(yOut, batY,weight=CEweights).item()
    epochLoss /= trainBats            # Average loss over batches and print
    validLoss /= validBats
    print("Epoch = {:-3}; Training loss = {:.4f}; Validation loss = {:.4f}".format(i,epochLoss,validLoss))
    if validLoss > t2vRatio * epochLoss:
        t2vEpochs -= 1                # Test if validation loss exceeds halting threshold
        if t2vEpochs < 1:
            print("Validation loss too high; halting to prevent overfitting")
            break
# Out:
# Epoch =   0; Training loss = 1.7742; Validation loss = 1.6854
# Epoch =   1; Training loss = 0.7213; Validation loss = 0.3024
# Epoch =   2; Training loss = 0.2745; Validation loss = 0.3370
# Epoch =   3; Training loss = 0.1958; Validation loss = 0.1615
# Epoch =   4; Training loss = 0.1492; Validation loss = 0.1539
# Epoch =   5; Training loss = 0.1134; Validation loss = 0.0925
# Epoch =   6; Training loss = 0.0873; Validation loss = 0.0737
# Epoch =   7; Training loss = 0.0755; Validation loss = 0.0701
# Epoch =   8; Training loss = 0.0609; Validation loss = 0.0527
# Epoch =   9; Training loss = 0.0516; Validation loss = 0.0579
# Epoch =  10; Training loss = 0.0690; Validation loss = 0.0489
# Epoch =  11; Training loss = 0.0418; Validation loss = 0.0908
# Epoch =  12; Training loss = 0.0361; Validation loss = 0.0387
# Epoch =  13; Training loss = 0.0341; Validation loss = 0.0329
# Epoch =  14; Training loss = 0.0299; Validation loss = 0.0320
# Epoch =  15; Training loss = 0.0252; Validation loss = 0.0347
# Validation loss too high; halting to prevent overfitting

# %% [markdown]
# It is most likely that training was halted early to prevent overfitting. Still, the final loss should be roughly 0.01, a huge improvement on the random guessing that the model begins with. (These are slightly dependent on how the random numbers pan out based on how many times earlier cells were executed)
#
# You may have also noticed that the training loss is quite a bit larger than the validation loss for the first several training steps. <b>Based on what you've learned about the training process, can you explain why this happens?</b>
#
# ### Testing the Model on New Data
#
# With the model fully trained, it's time to apply it to generate predictions from the test dataset. The model outputs a 6 element vector for each image. The individual values of this vector can be thought of, roughly, as relative probabilities that the image belongs in each class. Thus, we consider the class with the maximum value to be the prediction of the model.
#
# We'll use these predictions to generate a confusion matrix. Despite its name, the confusion matrix is easily understood. The rows in the matrix represent the correct classifications, while the columns represent the predictions of the model. When the row and the column agree (i.e., along the diagonal), the model predicted correctly.
#
# The short code snippet below iterates through the test batches and fills the confusion matrix.

# %%
confuseMtx = np.zeros((numClass,numClass),dtype=int)    # Create empty confusion matrix
model.eval()
with torch.no_grad():
    permute = torch.randperm(nTest)                     # Shuffle test data
    testX = testX[permute,:,:,:]
    testY = testY[permute]
    for j in range(testBats):                           # Iterate over test batches
        batX = testX[j*batchSize:(j+1)*batchSize,:,:,:].to(dev)
        batY = testY[j*batchSize:(j+1)*batchSize].to(dev)
        yOut = model(batX)                              # Pass test batch through model
        pred = yOut.max(1,keepdim=True)[1]              # Generate predictions by finding the max Y values
        for j in torch.cat((batY.view_as(pred), pred),dim=1).tolist(): # Glue together Actual and Predicted to
            confuseMtx[j[0],j[1]] += 1                  # make (row, col) pairs, and increment confusion matrix
correct = sum([confuseMtx[i,i] for i in range(numClass)])   # Sum over diagonal elements to count correct predictions
print("Correct predictions: ",correct,"of",nTest)
print("Confusion Matrix:")
print(confuseMtx)
print(classNames)
# Out:
# Correct predictions:  5670 of 5740
# Confusion Matrix:
# [[ 969    1    1    1    0    0]
#  [   3 1000    0    0    0    0]
#  [   7    1  976    0    1    0]
#  [   0    0    0  954    1    4]
#  [   0    0    0    1  844    0]
#  [   0    4    0   45    0  927]]
# ['Hand', 'HeadCT', 'CXR', 'ChestCT', 'BreastMRI', 'AbdomenCT']

# %% [markdown]
# You're likely to see 99%+ accuracy. Not bad for a fairly minimal model that trains in just a couple minutes. Now look at the confusion matrix. Notice that some mistakes are more common than others - <b>does this type of confusion make sense to you?</b>
#
# Before we get to the exercises, let's take a look at some of the images that confused the model. This cell can be rerun to produce more examples.

# %%
def scaleBack(x):               # Pass a tensor, return a numpy array from 0 to 1
    if(x.min() < x.max()):      # Assuming the image isn't empty, rescale so its values run from 0 to 1
        x = (x - x.min())/(x.max() - x.min())
    return x[0].to(cpu).numpy() # Remove channel (grayscale anyway)

model.eval()
mp.subplots(3,3,figsize=(8,8))
imagesLeft = 9
permute = torch.randperm(nTest)        # Shuffle test data
testX = testX[permute,:,:,:]
testY = testY[permute]
for j in range(testBats):              # Iterate over test batches
    batX = testX[j*batchSize:(j+1)*batchSize,:,:,:].to(dev)
    batY = testY[j*batchSize:(j+1)*batchSize].to(dev)
    yOut = model(batX)                 # Pass test batch through model
    pred = yOut.max(1)[1].tolist()     # Generate predictions by finding the max Y values
    for i, y in enumerate(batY.tolist()):
        if imagesLeft and y != pred[i]:         # Compare the actual y value to the prediction
            imagesLeft -= 1
            mp.subplot(3,3,9-imagesLeft)
            mp.xlabel(classNames[pred[i]])      # Label image with what the model thinks it is
            mp.imshow(scaleBack(batX[i]),cmap='gray',vmin=0,vmax=1)
mp.tight_layout()
mp.show()

# %% [markdown]
# ### Please answer the questions below to complete the experiment:

# %%
# @title Q.1. Which of the following functions can be used as an activation function in the output layer of a CNN, if we wish to predict the probabilities of n(n>2) classes? { run: "auto", form-width: "500px", display-mode: "form" }
Answer = "Softmax" #@param ["","ReLu","Softmax", "Sigmoid","Tanh"]

# %%
#@title How was the experiment? { run: "auto", form-width: "500px", display-mode: "form" }
Complexity = "Good and Challenging for me" #@param ["","Too Simple, I am wasting time", "Good, But Not Challenging for me", "Good and Challenging for me", "Was Tough, but I did it", "Too Difficult for me"]

# %%
#@title If it was too easy, what more would you have liked to be added? If it was very difficult, what would you have liked to have been removed? { run: "auto", display-mode: "form" }
Additional = "Good and challenging" #@param {type:"string"}

# %%
#@title Can you identify the concepts from the lecture which this experiment covered? { run: "auto", vertical-output: true, display-mode: "form" }
Concepts = "Yes" #@param ["","Yes", "No"]

# %%
#@title  Text and image description/explanation and code comments within the experiment: { run: "auto", vertical-output: true, display-mode: "form" }
Comments = "Very Useful" #@param ["","Very Useful", "Somewhat Useful", "Not Useful", "Didn't use"]

# %%
#@title Mentor Support: { run: "auto", vertical-output: true, display-mode: "form" }
Mentor_support = "Very Useful" #@param ["","Very Useful", "Somewhat Useful", "Not Useful", "Didn't use"]

# %%
#@title Run this cell to submit your notebook for grading { vertical-output: true }
try:
  if submission_id:
      return_id = submit_notebook()
      if return_id : submission_id = return_id
  else:
      print("Please complete the setup first.")
except NameError:
  print ("Please complete the setup first.")
# Out:
# Your submission is successful.
# Ref Id: 569
# Date of submission:  14 Mar 2024
# Time of submission:  10:59:03
# View your submissions: https://mlaias-iisc.talentsprint.com/notebook_submissions
